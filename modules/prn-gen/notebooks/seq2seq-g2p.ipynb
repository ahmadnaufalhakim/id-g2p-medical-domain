# %% [markdown]
# ## Import libraries

# %%
print("importing os")
import os
print("importing random")
import random

print("importing torch")
import torch
print("from torch.autograd import Variable")
from torch.autograd import Variable
print("importing torch.nn as nn")
import torch.nn as nn
print("from torch import optim")
from torch import optim
print("importing torch.nn.functional as F")
import torch.nn.functional as F
print("from torch.utils.data import Dataset, DataLoader")
from torch.utils.data import Dataset, DataLoader

# Constants
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
USE_CUDA = (str(DEVICE)=="cuda")
print(f"Using device: {DEVICE}")

CURR_DIR = globals()['_dh'][0]
DATA_DIR = os.path.join(CURR_DIR, "..", "data")

SOS_TOKEN = 0
EOS_TOKEN = 1
# Out:
# importing os
# importing random
# importing torch
# from torch.autograd import Variable
# importing torch.nn as nn
# from torch import optim
# importing torch.nn.functional as F
# from torch.utils.data import Dataset, DataLoader
# Using device: cuda

# %% [markdown]
# ## Preparing dataset

# %%
class G2PDataset(Dataset) :
  def __init__(self, graphemes_list, phonemes_list) -> None :
    assert len(graphemes_list) == len(phonemes_list)
    self.graphemes_list = graphemes_list
    self.grapheme2index = {}
    self.grapheme2count = {}
    self.index2grapheme = {0: "<SOS>", 1: "<EOS>"}
    self.n_graphemes = 2
    for graphemes in graphemes_list :
      for grapheme in graphemes :
        self.add_grapheme(grapheme)

    self.phonemes_list = phonemes_list
    self.phoneme2index = {}
    self.phoneme2count = {}
    self.index2phoneme = {0: "<SOS>", 1: "<EOS>"}
    self.n_phonemes = 2
    for phonemes in phonemes_list :
      for phoneme in phonemes :
        self.add_phoneme(phoneme)

  def add_grapheme(self, grapheme) :
    if grapheme not in self.grapheme2index :
      self.grapheme2index[grapheme] = self.n_graphemes
      self.grapheme2count[grapheme] = 1
      self.index2grapheme[self.n_graphemes] = grapheme
      self.n_graphemes += 1
    else :
      self.grapheme2count[grapheme] += 1

  def add_phoneme(self, phoneme) :
    if phoneme not in self.phoneme2index :
      self.phoneme2index[phoneme] = self.n_phonemes
      self.phoneme2count[phoneme] = 1
      self.index2phoneme[self.n_phonemes] = phoneme
      self.n_phonemes += 1
    else :
      self.phoneme2count[phoneme] += 1

  def __len__(self) :
    return len(self.graphemes_list)

  def __getitem__(self, index) -> str:
    graphemes = self.graphemes_list[index]
    phonemes = self.phonemes_list[index]
    return ' '.join(graphemes), ' '.join(phonemes)

# %%
def prepare_dataset() :
  print("Reading entries ..")

  # Read the file and split into lines
  with open(os.path.join(DATA_DIR, "ma/train.csv"), encoding="utf-8") as f_csv :
    next(f_csv, None)

    # Split every row into pairs
    pairs = [[s.strip('\n') for s in row.split(',')] for row in f_csv]

    #TODO: Add train val test split logic
    #TODO: Add experimentation on different types of grapheme (i.e. letters, morphemes, subword, syllables, etc.)
    train_graphemes_list = [[*pair[0]] for pair in pairs] # Split grapheme as desired
    train_phonemes_list = [[*pair[1]] for pair in pairs] # Split phoneme as desired

  train_g2p_dataset = G2PDataset(train_graphemes_list, train_phonemes_list)
  #TODO: add valid and test split
  # valid_g2p_dataset = G2PDataset(valid_graphemes_list, valid_phonemes_list)
  # test_g2p_dataset = G2PDataset(test_graphemes_list, test_phonemes_list)

  max_length = -999
  for graphemes in train_g2p_dataset.graphemes_list :
    if max_length < len(graphemes) :
      max_length = len(graphemes)
  for phonemes in train_g2p_dataset.phonemes_list :
    if max_length < len(phonemes) :
      max_length = len(phonemes)
  # for graphemes in valid_g2p_dataset.graphemes_list :
  #   if max_length < len(graphemes) :
  #     max_length = len(graphemes)
  # for phonemes in valid_g2p_dataset.phonemes_list :
  #   if max_length < len(phonemes) :
  #     max_length = len(phonemes)
  # for graphemes in test_g2p_dataset.graphemes_list :
  #   if max_length < len(graphemes) :
  #     max_length = len(graphemes)
  # for phonemes in test_g2p_dataset.phonemes_list :
  #   if max_length < len(phonemes) :
  #     max_length = len(phonemes)

  return train_g2p_dataset, max_length

train_g2p_dataset, MAX_LENGTH = prepare_dataset()

BATCH_SIZE = 32
train_dataloader = DataLoader(train_g2p_dataset, batch_size=BATCH_SIZE, shuffle=True)
#TODO: Add train val test split
# valid_dataloader = DataLoader(valid_g2p_dataset, batch_size=BATCH_SIZE, shuffle=True)
# test_dataloader = DataLoader(test_g2p_dataset, batch_size=BATCH_SIZE, shuffle=True)

print((train_dataloader.dataset[0]))
# print(train_dataloader.dataset.phonemes_list)
for batch, (a,b) in enumerate(train_dataloader) :
  print(len(a), a)
  print(b)
  print()
# Out:
# Reading entries ..
# ('a b a', 'a b a')
# 32 ('b e r g a m b a r', 'a n g a n k a n', 'b e s e k', 'b e g i t u', 'b e r m a t a', 'b e r d e g u m', 'b a n c a n g', 'a d i r a t n a', 'b e r a k a d', 'b a d a n g', 'b e r u j a r', 'b e l u k u t', 'b a k i r', 'b e r k e s i n a m b u n g a n', 'a u t o b i o g r a f i', 'b e r d e g i l', 'a t e n s i', 'b e b e r', 'a j i', 'a n g g a i', 'b e s a l e n', 'a r o g a n s i', 'b e r g a b u n g', 'b e t', 'b i l a s', 'b e r d u r h a k a', 'b e r b o h o n g', 'a n a r k i s', 'b i n a r a g a', 'b e r o n g s o n g', 'b e r s i t e g a n g', 'a e r o b i k')
# ('b ə r g a m b a r', 'a ŋ a n k a n', 'b e s e ʔ', 'b ə g i t u', 'b ə r m a t a', 'b ə r d ə g u m', 'b a n t ʃ a ŋ', 'a d i r a t n a', 'b ə r a k a d', 'b a d a ŋ', 'b ə r u d ʒ a r', 'b ə l u k u t', 'b a k i r', 'b ə r k ə s i n a m b u ŋ a n', 'a u t o b i o g r a f i', 'b ə r d ə g i l', 'a t e n s i', 'b ə b ə r', 'a d ʒ i', 'a ŋ g a i', 'b ə s a l e n', 'a r o g a n s i', 'b ə r g a b u ŋ', 'b ə t', 'b i l a s', 'b ə r d u r h a k a', 'b ə r b o h o ŋ', 'a n a r k i s', 'b i n a r a g a', 'b ə r o ŋ s o ŋ', 'b ə r s i t ə g a ŋ', 'a e r o b i ʔ')
#
# 32 ('b e r a l i a n s i', 'b e k a k a k', 'a n i o n', 'b e r n o d a', 'b u l u k', 'a s p i r i n', 'a c a k', 'b e r g e l u m a n g', 'b e r s e r o b o k', 'b e l a h a n', 'a r a i', 'b e k e r t a k', 'a b a k u s', 'b e r s a r a', 'b e r t e l a n j a n g', 'b e s a r n y a', 'a r o m a', 'b e r n i l a i', 'b a r z a n j i', 'b a s', 'b i l i o n', 'b e l a s u n g k a w a', 'b e d e g o n g', 'b u a l', 'a g i t a t o r', 'a u', 'a n t a r p u l a u', 'a l a k', 'b e r b e s a r', 'b e r s e m b u r a n', 'b r o m p i t', 'b e r j e j e r')
# ('b ə r a l i a n s i', 'b ə k a k a ʔ', 'a n i o n', 'b ə r n o d a', 'b u l u ʔ', 'a s p i r i n', 'a t ʃ a ʔ', 'b ə r g ə l u m a ŋ', 'b ə r s ə r o b o ʔ', 'b ə l a h a n', 'a r a i', 'b ə k ə r t a ʔ', 'a b a k u s', 'b ə r s a r a', 'b ə r t ə l a n d ʒ a ŋ', 'b ə s a r ɲ a', 'a r o m a', 'b ə r n i l a i', 'b a r z a n d ʒ i', 'b a s', 'b i l i o n', 'b e l a s u ŋ k a w a', 'b ə d ə g o ŋ', 'b u a l', 'a g i t a t o r', 'a u', 'a n t a r p u l a u', 'a l a ʔ', 'b ə r b ə s a r', 'b ə r s ə m b u r a n', 'b r o m p i t', 'b ə r d ʒ e d ʒ e r')
#
# 32 ('b e r d o s a', 'b e r g a r i s', 'b o k s e n', 'b e r e b u t', 'b l i r i k', 'b e r c a m p u r', 'b a t i l', 'b e r c a g a k', 'b e r j a l i n', 'a n a', 'a i r m a t a', 'a s b a k', 'b e r k e r i u t a n', 'b e l e l', 'b i t i n g', 'a l u r n y a', 'b a t u k', 'b e l o h', 'b r e m', 'a s p i r a n', 'b o b o t o k', 'b e r h a n t a r a n', 'b a n j u r', 'b a p e t', 'b e r k i r a', 'b e s i', 'b e r a p r e s i a s i', 'b a n d u n g', 'b u n d a r a n', 'a n t i t a n k', 'a k a d e m i k u s', 'b a r u n y a')
# ('b ə r d o s a', 'b ə r g a r i s', 'b o ʔ s ə n', 'b ə r ə b u t', 'b l i r i ʔ', 'b ə r t ʃ a m p u r', 'b a t i l', 'b ə r t ʃ a g a ʔ', 'b ə r d ʒ a l i n', 'a n a', 'a i r m a t a', 'a s b a ʔ', 'b ə r k ə r i u t a n', 'b e l e l', 'b i t i ŋ', 'a l u r ɲ a', 'b a t u ʔ', 'b e l o h', 'b r ə m', 'a s p i r a n', 'b o b o t o ʔ', 'b ə r h a n t a r a n', 'b a n d ʒ u r', 'b a p e t', 'b ə r k i r a', 'b ə s i', 'b ə r a p r e s i a s i', 'b a n d u ŋ', 'b u n d a r a n', 'a n t i t a n ʔ', 'a k a d e m i k u s', 'b a r u ɲ a')
#
# 32 ('a l u n a n', 'b e l a t i k', 'a b o l i s i', 'a t e i s m e', 'b e r e k r e a s i', 'a s t e r o i d', 'a n g o t', 'b e n t u r u n g', 'a t e i s t i s', 'b u n d u n g', 'b e n z o i n', 'a n j i n g', 'b e r e n g s e k', 'b e r b u i h', 'a t a s a n n y a', 'b i c u', 'b e r n o m o r', 'b u n g k i n g', 'b e r d e n d a n g', 'a g u n a n', 'b a i n', 'b e r d e m p e t a n', 'b e r b i n c a n g', 'b e n d o', 'b l o k', 'a n g k a', 'a k u a d e s', 'a s o n a n s i', 'b e r b e n t r o k', 'a w a h a m a', 'b e r d a s a r k a n', 'a r g u m e n')
# ('a l u n a n', 'b ə l a t i ʔ', 'a b o l i s i', 'a t e i s m ə', 'b ə r e ʔ r e a s i', 'a s t ə r o i d', 'a ŋ o t', 'b ə n t u r u ŋ', 'a t e i s t i s', 'b u n d u ŋ', 'b ə n z o i n', 'a n d ʒ i ŋ', 'b ə r e ŋ s e ʔ', 'b ə r b u i h', 'a t a s a n ɲ a', 'b i t ʃ u', 'b ə r n o m o r', 'b u ŋ k i ŋ', 'b ə r d ə n d a ŋ', 'a g u n a n', 'b a i n', 'b ə r d e m p e t a n', 'b ə r b i n t ʃ a ŋ', 'b ə n d o', 'b l o ʔ', 'a ŋ k a', 'a k u a d e s', 'a s o n a n s i', 'b ə r b ə n t r o ʔ', 'a w a h a m a', 'b ə r d a s a r k a n', 'a r g u m e n')
#
# 32 ('b e r s e p', 'b r o s', 'b e r e k o n o m i', 'b e r s e n d i r i a n', 'b e r u p a y a', 'b a y i n y a', 'a r t e r i', 'b e b e l', 'a h k a m', 'b e r d e n y u t', 'b e r g a u n', 'b e r t e n t u', 'b e r a k a l', 'b i j i a n', 'b e r k e a d a a n', 'b a d a r', 'a b r a s i', 'b a r i s a n', 'b e r b e l a n j a', 'b e r s e l u m u', 'b e r d e n t u n g', 'b e r p e n g a l a m a n', 'b e r t o p e n g', 'b e r g e t a h', 'a b s i s', 'b e r b u r u k', 'b e r t u k a n g', 'b e n g k u n g', 'b e r s i b u n u h', 'b a n c u t', 'b o n g k o t', 'b e r b o n c e n g a n')
# ('b ə r s e p', 'b r o s', 'b ə r e k o n o m i', 'b ə r s ə n d i r i a n', 'b ə r u p a j a', 'b a j i ɲ a', 'a r t ə r i', 'b ə b ə l', 'a h k a m', 'b ə r d ə ɲ u t', 'b ə r g a u n', 'b ə r t ə n t u', 'b ə r a k a l', 'b i d ʒ i a n', 'b ə r k ə a d a ʔ a n', 'b a d a r', 'a b r a s i', 'b a r i s a n', 'b ə r b ə l a n d ʒ a', 'b ə r s ə l u m u', 'b ə r d ə n t u ŋ', 'b ə r p ə ŋ a l a m a n', 'b ə r t o p e ŋ', 'b ə r g ə t a h', 'a b s i s', 'b ə r b u r u ʔ', 'b ə r t u k a ŋ', 'b ə ŋ k u ŋ', 'b ə r s i b u n u h', 'b a n t ʃ u t', 'b o ŋ k o t', 'b ə r b o n t ʃ e ŋ a n')
#
# 32 ('a t u s', 'b o n s a i', 'b a t a', 'b e r b a w a a n', 'b e r i k u t', 'a k r a b', 'b e r p e g a n g', 'a n t r o p o l o g', 'b a n t u a n', 'b e r i s t r i k a n', 'a d i w a r n a', 'b e r k e l o m p o k', 'b e r h a k', 'b e r s e m b u n y i', 'a k i k a h', 'b e l a c u', 'b a l a p', 'b u n g a', 'a n d i k a', 'a d v o k a s i', 'a r e a', 'a b u l', 'b e r d a b u s', 'b e l e b a s', 'a m p u t', 'b o r d i r', 'a k u r a t', 'b u n c i s', 'b e r c e l o t e h', 'b a h a r', 'b u b u s', 'b a c e k')
# ('a t u s', 'b o n s a i', 'b a t a', 'b ə r b a w a ʔ a n', 'b ə r i k u t', 'a ʔ r a b', 'b ə r p ə g a ŋ', 'a n t r o p o l o g', 'b a n t u a n', 'b ə r i s t r i k a n', 'a d i w a r n a', 'b ə r k ə l o m p o ʔ', 'b ə r h a ʔ', 'b ə r s ə m b u ɲ i', 'a k i k a h', 'b ə l a t ʃ u', 'b a l a p', 'b u ŋ a', 'a n d i k a', 'a d v o k a s i', 'a r e a', 'a b u l', 'b ə r d a b u s', 'b ə l ə b a s', 'a m p u t', 'b o r d i r', 'a k u r a t', 'b u n t ʃ i s', 'b ə r t ʃ e l o t ə h', 'b a h a r', 'b u b u s', 'b a t ʃ ə ʔ')
#
# 32 ('a m i l', 'a d i k k u', 'b e r t a k w a', 'b o n e t', 'b e r c a n g k u k', 'b e n a l u', 'b e k u', 'b e r j u m p a', 'b e r a r a k a n', 'b u j e t', 'b e r g u m u l', 'b a j u n y a', 'b a j u m u', 'a d r e s', 'b i r o k r a t i k', 'a e r o n a u t i k a', 'b e r k e l i a r a n', 'b o l p o i n', 'b a b i l', 'b e r a p u n g a n', 'b e r d e b u s', 'a l i e n a s i', 'b e r c i n t a k a n', 'b e r g o s o k', 'a m a t u r', 'b u j a n g', 'b e r t o l e r a n s i', 'b o g a m', 'b e r l u b a n g', 'a d a m', 'a s p i r a t', 'a n g g l a p')
# ('a m i l', 'a d i ʔ k u', 'b ə r t a ʔ w a', 'b o n e t', 'b ə r t ʃ a ŋ k u ʔ', 'b ə n a l u', 'b ə k u', 'b ə r d ʒ u m p a', 'b ə r a r a k a n', 'b u d ʒ e t', 'b ə r g u m u l', 'b a d ʒ u ɲ a', 'b a d ʒ u m u', 'a d r e s', 'b i r o ʔ r a t i ʔ', 'a e r o n a u t i k a', 'b ə r k ə l i a r a n', 'b o l p o i n', 'b a b i l', 'b ə r a p u ŋ a n', 'b ə r d ə b u s', 'a l i e n a s i', 'b ə r t ʃ i n t a k a n', 'b ə r g o s o ʔ', 'a m a t u r', 'b u d ʒ a ŋ', 'b ə r t o l ə r a n s i', 'b o g a m', 'b ə r l u b a ŋ', 'a d a m', 'a s p i r a t', 'a ŋ g l a p')
#
# 32 ('b a n t a i', 'b a s a u', 'b e r m i l i k', 'b e r p e n d a r', 'b i o k i m i a', 'b e r g u r a u', 'b e r a n j a k', 'a u t o g r a f', 'a n a r k i s t i s', 'a n g g u l', 'b e n g k i l', 'b e l a n d a', 'b a w a l', 'b e r s e r i k a t', 'b a d a r i', 'b e r a f i l i a s i', 'a s f i k s i a', 'b i n j a i', 'a n i m i s', 'b e r d a s a r', 'b e l e l a n g', 'b e r k e r u t', 'a s o s i a l', 'a b d o m e n', 'a r t i s a n', 'b e r t e m p i a s', 'b a n t a r a n', 'a v o n t u r', 'a s i', 'b a n t a h', 'b e r d e c i t', 'b e r b a y a n g')
# ('b a n t a i', 'b a s a u', 'b ə r m i l i ʔ', 'b ə r p e n d a r', 'b i o k i m i a', 'b ə r g u r a u', 'b ə r a n d ʒ a ʔ', 'a u t o g r a f', 'a n a r k i s t i s', 'a ŋ g u l', 'b ə ŋ k i l', 'b ə l a n d a', 'b a w a l', 'b ə r s ə r i k a t', 'b a d a r i', 'b ə r a f i l i a s i', 'a s f i ʔ s i a', 'b i n d ʒ a i', 'a n i m i s', 'b ə r d a s a r', 'b ə l e l a ŋ', 'b ə r k ə r u t', 'a s o s i a l', 'a b d o m e n', 'a r t i s a n', 'b ə r t ə m p i a s', 'b a n t a r a n', 'a v o n t u r', 'a s i', 'b a n t a h', 'b ə r d ə t ʃ i t', 'b ə r b a j a ŋ')
#
# 32 ('b e r s e n t o s a', 'b e r b i a k', 'a h l u l b a i t', 'b e r b u l i r', 'b e r j a r a k', 'b e r i k a n', 'a d i k o n g', 'b e r l u m u r', 'b u a i a n', 'b e n g k a k', 'b a g a l', 'b e r s e r a b u t', 'a l f a', 'b e l u d a r', 'b e r s a r a n g', 'a r t o n a', 'b r e n', 'b e l a l a i', 'b l e n d e r', 'b e r s i n', 'a b i d', 'a s a s i', 'b e r g a n t i a n', 'a r a s', 'b a u r', 'a j a r a n m u', 'b e r s i m b a h', 'a n y a n g', 'a m a h', 'b e r d i a m e t e r', 'b e r b u n g a', 'b i d a n g')
# ('b ə r s ə n t o s a', 'b ə r b i a ʔ', 'a h l u l b a i t', 'b ə r b u l i r', 'b ə r d ʒ a r a ʔ', 'b ə r i k a n', 'a d i k o ŋ', 'b ə r l u m u r', 'b u a i a n', 'b ə ŋ k a ʔ', 'b a g a l', 'b ə r s ə r a b u t', 'a l f a', 'b ə l u d a r', 'b ə r s a r a ŋ', 'a r t o n a', 'b r e n', 'b ə l a l a i', 'b l e n d ə r', 'b ə r s i n', 'a b i d', 'a s a s i', 'b ə r g a n t i a n', 'a r a s', 'b a u r', 'a d ʒ a r a n m u', 'b ə r s i m b a h', 'a ɲ a ŋ', 'a m a h', 'b ə r d i a m e t ə r', 'b ə r b u ŋ a', 'b i d a ŋ')
#
# 32 ('a r t e t i s', 'b e r h a s r a t', 'b e r a c u n', 'b e r k e n t u t', 'a k i', 'b e r m u n c u l a n', 'a n t a g o n i s t i s', 'b e r b u a t', 'a g r a r i a', 'a m p a t', 'b a n a', 'a d i p u r a', 'b e r l a n g s u n g', 'b e b e r a n', 'b i l a t e r a l', 'b i d u a n i t a', 'b e r a n g k a', 'b i o p s i', 'b e r e k o r', 'b e r c e r a i a n', 'b i n i n y a', 'b e r s e l a j u', 'b e n a m', 'b e r w e w e n a n g', 'b e b a s k a n', 'b i d a r i', 'b e r k o r b a n', 'a m b l e k', 'b e r k e h e n d a k', 'a n d a i a n', 'a m e r t a', 'b e r p i n g g i r')
# ('a r t e t i s', 'b ə r h a s r a t', 'b ə r a t ʃ u n', 'b ə r k ə n t u t', 'a k i', 'b ə r m u n t ʃ u l a n', 'a n t a g o n i s t i s', 'b ə r b u a t', 'a g r a r i a', 'a m p a t', 'b a n a', 'a d i p u r a', 'b ə r l a ŋ s u ŋ', 'b e b e r a n', 'b i l a t e r a l', 'b i d u a n i t a', 'b ə r a ŋ k a', 'b i o p s i', 'b ə r e k o r', 'b ə r t ʃ ə r a i a n', 'b i n i ɲ a', 'b ə r s ə l a d ʒ u', 'b ə n a m', 'b ə r w ə w ə n a ŋ', 'b e b a s k a n', 'b i d a r i', 'b ə r k o r b a n', 'a m b l ə ʔ', 'b ə r k ə h ə n d a ʔ', 'a n d a i a n', 'a m ə r t a', 'b ə r p i ŋ g i r')
#
# 32 ('b e r t e n u n g', 'b u g a r', 'b e k e r l a p a n', 'b a g a s i', 'b e r e n t e t', 'b o t o r', 'b i l a', 'b e r p e n d i r i a n', 'a n a f r o d i s i a k', 'b e r t u r u t', 'b e l i n c o n g', 'b e r p e l u k', 'b e r k e r i s i k', 'a d a l a h', 'b e l o', 'a y e m', 'a s u r a n s i', 'b a n y o l', 'b e g u k', 'b e r a k s i', 'b a j u k u', 'b e r s e n d e n g', 'b e r d o a', 'a p a t i', 'b e r b e n a r', 'b e r s i d a h u l u', 'b e d e b a h', 'b e r m o r a l', 'b e r d e d i k a s i', 'a n g k u p', 'b r a t a', 'b r a n k a s')
# ('b ə r t ə n u ŋ', 'b u g a r', 'b ə k ə r l a p a n', 'b a g a s i', 'b ə r e n t e t', 'b o t o r', 'b i l a', 'b ə r p ə n d i r i a n', 'a n a f r o d i s i a ʔ', 'b ə r t u r u t', 'b ə l i n t ʃ o ŋ', 'b ə r p ə l u ʔ', 'b ə r k ə r i s i ʔ', 'a d a l a h', 'b e l o', 'a j ə m', 'a s u r a n s i', 'b a ɲ o l', 'b ə g u ʔ', 'b ə r a ʔ s i', 'b a d ʒ u k u', 'b ə r s e n d e ŋ', 'b ə r d o a', 'a p a t i', 'b ə r b ə n a r', 'b ə r s i d a h u l u', 'b ə d ə b a h', 'b ə r m o r a l', 'b ə r d e d i k a s i', 'a ŋ k u p', 'b r a t a', 'b r a n k a s')
#
# 32 ('b a k a m', 'b e r k e l i l i n g', 'a n e m e r', 'b a l u t', 'b e r j u a l a n', 'a d s o r p s i', 'b e r u n s u r k a n', 'b e r t a l i', 'b e r p a n t a n g', 'b e n a', 'b e l o n', 'b e r e m b a n g', 'a m p e l', 'a g r e g a s i', 'a p a r a t u r', 'b e r t a p a', 'b e r c a n g a p', 'b e r s e r a n', 'b e r k e l u a r g a', 'b a n d e n g', 'b e r k e l i m', 'b e r s e b a b', 'b a r o k', 'b e r a n a k', 'a g a m a w i', 'a n a k n y a', 'b e r s e n i', 'a l k a m a r', 'b e r s e m a r a k', 'a s p r a k', 'b a r k a s', 'b e r b u t i r')
# ('b a k a m', 'b ə r k ə l i l i ŋ', 'a n e m ə r', 'b a l u t', 'b ə r d ʒ u a l a n', 'a d s o r p s i', 'b ə r u n s u r k a n', 'b ə r t a l i', 'b ə r p a n t a ŋ', 'b ə n a', 'b ə l o n', 'b ə r ə m b a ŋ', 'a m p ə l', 'a g r e g a s i', 'a p a r a t u r', 'b ə r t a p a', 'b ə r t ʃ a ŋ a p', 'b ə r s e r a n', 'b ə r k ə l u a r g a', 'b a n d ə ŋ', 'b ə r k ə l i m', 'b ə r s ə b a b', 'b a r o ʔ', 'b ə r a n a ʔ', 'a g a m a w i', 'a n a ʔ ɲ a', 'b ə r s ə n i', 'a l k a m a r', 'b ə r s ə m a r a ʔ', 'a s p r a ʔ', 'b a r k a s', 'b ə r b u t i r')
#
# 32 ('b e r a d e h', 'b e n t a', 'b a n c i', 'a k a r', 'a n g g r e k w a n', 'a n a t o m i', 'a m a t i r i s m e', 'b e n t a l a', 'b o k c a', 'a m a t a n', 'a d s o r b e n', 'b i l y e t', 'b e n t a n g a n', 'b r o k e r', 'b e r d e m p o k', 'a m a l a n n y a', 'a j a n g', 'b e r d e n g k u n g', 'a b r e k', 'a b n o r m a l', 'b u a h k a n', 'a n t a g o n i s m e', 'b e r p a n d u', 'a g e n', 'a g a k', 'b e r s e l e s a', 'b a u s u k u', 'a i s', 'b u l a k a n', 'a t e r e t', 'b e r l a w a n a n', 'b a t a n g n y a')
# ('b ə r a d e h', 'b ə n t a', 'b a n t ʃ i', 'a k a r', 'a ŋ g r e ʔ w a n', 'a n a t o m i', 'a m a t i r i s m ə', 'b ə n t a l a', 'b o ʔ t ʃ a', 'a m a t a n', 'a d s o r b e n', 'b i l j e t', 'b ə n t a ŋ a n', 'b r o k ə r', 'b ə r d ə m p o ʔ', 'a m a l a n ɲ a', 'a d ʒ a ŋ', 'b ə r d ə ŋ k u ŋ', 'a b r ə ʔ', 'a b n o r m a l', 'b u a h k a n', 'a n t a g o n i s m ə', 'b ə r p a n d u', 'a g e n', 'a g a ʔ', 'b ə r s ə l e s a', 'b a u s u k u', 'a i s', 'b u l a k a n', 'a t ə r e t', 'b ə r l a w a n a n', 'b a t a ŋ ɲ a')
#
# 32 ('b e r m a l a s', 'b e r a s a p', 'b a n d i t', 'b e r b a n d i n g', 'b e r a s a', 'b e r b a l i k', 'b e z a', 'b e r k e m u', 'a n t e p', 'a s k a r', 'a n d a l k a n', 'b e r d e r u k', 'a s m a r a d a n t a', 'a y a p', 'b e r d a h a n a m', 'a l k a u s a r', 'b a j a', 'b i n g k a h', 'b a b u n', 'b a y a m', 'b e r b a d a i', 'a l a', 'b e n y o h', 'a u k', 'a l a m a s', 'b e r c a k a r', 'b i r a i', 'b o r h a n', 'b i l i n g u a l', 'b e l e k a n', 'a b o n e m e n', 'b e r d a r m a w i s a t a')
# ('b ə r m a l a s', 'b ə r a s a p', 'b a n d i t', 'b ə r b a n d i ŋ', 'b ə r a s a', 'b ə r b a l i ʔ', 'b e z a', 'b ə r k ə m u', 'a n t ə p', 'a s k a r', 'a n d a l k a n', 'b ə r d ə r u ʔ', 'a s m a r a d a n t a', 'a j a p', 'b ə r d a h a n a m', 'a l k a u s a r', 'b a d ʒ a', 'b i ŋ k a h', 'b a b u n', 'b a j a m', 'b ə r b a d a i', 'a l a', 'b ə ɲ o h', 'a u ʔ', 'a l a m a s', 'b ə r t ʃ a k a r', 'b i r a i', 'b o r h a n', 'b i l i ŋ u a l', 'b e l e k a n', 'a b o n ə m e n', 'b ə r d a r m a w i s a t a')
#
# 32 ('a h a d', 'b a l a m', 'b u m', 'a n g k e t', 'b e r a n g g a p', 'b a n t a u', 'a r e a l', 'b i s e k t r i s', 'b e n t u s', 'a b s t a i n', 'a m u l e t', 'a m e l i o r a s i', 'b a p a k', 'b e r m a s y a r a k a t', 'a l f a b e t i s', 'b e r b e n t u r a n', 'b e n i', 'b e r i n g a t', 'b e r e n t a k', 'b e r k e l e d a r', 'a r s i p', 'b e r d e k a k', 'b e r b a r u t', 'a n d u n', 'b e r m a n i s', 'a l f', 'b e r t a n g g u n g - j a w a b', 'b e r e a k s i', 'b e l a h a k', 'a l a t', 'b e b e s a r a n', 'b e r m u s u h')
# ('a h a d', 'b a l a m', 'b u m', 'a ŋ k e t', 'b ə r a ŋ g a p', 'b a n t a u', 'a r e a l', 'b i s e ʔ t r i s', 'b ə n t u s', 'a b s t a i n', 'a m u l e t', 'a m e l i o r a s i', 'b a p a ʔ', 'b ə r m a s j a r a k a t', 'a l f a b e t i s', 'b ə r b ə n t u r a n', 'b e n i', 'b ə r i ŋ a t', 'b ə r ə n t a ʔ', 'b ə r k ə l e d a r', 'a r s i p', 'b ə r d ə k a ʔ', 'b ə r b a r u t', 'a n d u n', 'b ə r m a n i s', 'a l f', 'b ə r t a ŋ g u ŋ d ʒ a w a b', 'b ə r e a ʔ s i', 'b ə l a h a ʔ', 'a l a t', 'b ə b ə s a r a n', 'b ə r m u s u h')
#
# 32 ('b a d e', 'b e r k a k a k', 'b r o n k i t i s', 'a c a t', 'b e r m o t o r', 'a n g g a p', 'b u n g k e r', 'a b n u s', 'b a l a i', 'b e w o k', 'b e r k o k o k', 'b e r g a y a', 'b a r b a r i s m e', 'b a w a k a n', 'b a n g g a', 'b e d e g a p', 'b e r b u a h k a n', 'b e n g u k', 'b a d i', 'b e r a d e g a n', 'b e r g a n t u n g', 'a l a n g k a h', 'b e r k a w a n', 'b e r j a j a n', 'b e r a r i s', 'b e r l e l u a s a', 'b a y u r', 'b e r k e c u m i k', 'b a w a s i r', 'b e r b e d a', 'a n s a m b e l', 'b e r b a n y a k')
# ('b a d e', 'b ə r k a k a ʔ', 'b r o n k i t i s', 'a t ʃ a t', 'b ə r m o t o r', 'a ŋ g a p', 'b u ŋ k ə r', 'a b n u s', 'b a l a i', 'b e w o ʔ', 'b ə r k o k o ʔ', 'b ə r g a j a', 'b a r b a r i s m ə', 'b a w a k a n', 'b a ŋ g a', 'b ə d ə g a p', 'b ə r b u a h k a n', 'b ə ŋ u ʔ', 'b a d i', 'b ə r a d ə g a n', 'b ə r g a n t u ŋ', 'a l a ŋ k a h', 'b ə r k a w a n', 'b ə r d ʒ a d ʒ a n', 'b ə r a r i s', 'b ə r l ə l u a s a', 'b a j u r', 'b ə r k ə t ʃ u m i ʔ', 'b a w a s i r', 'b ə r b e d a', 'a n s a m b ə l', 'b ə r b a ɲ a ʔ')
#
# 32 ('a n g k u r', 'b e l a n d a r', 'a n j i r', 'b a c i k', 'b e r j a n g k a', 'b e r s e n g k a r u t', 'a m b u n g', 'b a n d u t', 'a s u m s i', 'b e r t a j u k', 'a l m a l u n', 'a r u n g', 'b e r e n a n g', 'b e r j i l i d', 'a n c a', 'b e r b e n i h', 'b a l a', 'a u r a t', 'a h o', 'a s', 'b e r c u p i n g', 'a f i r m a s i', 'b e n g a h', 'a l a b a n g k a', 'b i j a', 'a k u i f e r', 'a k u s t i k a', 'b i j i h', 'b e r t a b u r', 'b e r c u k u r', 'b e r k a s', 'b e r a b o n e m e n')
# ('a ŋ k u r', 'b ə l a n d a r', 'a n d ʒ i r', 'b a t ʃ i ʔ', 'b ə r d ʒ a ŋ k a', 'b ə r s ə ŋ k a r u t', 'a m b u ŋ', 'b a n d u t', 'a s u m s i', 'b ə r t a d ʒ u ʔ', 'a l m a l u n', 'a r u ŋ', 'b ə r ə n a ŋ', 'b ə r d ʒ i l i d', 'a n t ʃ a', 'b ə r b ə n i h', 'b a l a', 'a u r a t', 'a h o', 'a s', 'b ə r t ʃ u p i ŋ', 'a f i r m a s i', 'b ə ŋ a h', 'a l a b a ŋ k a', 'b i d ʒ a', 'a k u i f e r', 'a k u s t i k a', 'b i d ʒ i h', 'b ə r t a b u r', 'b ə r t ʃ u k u r', 'b ə r k a s', 'b ə r a b o n ə m e n')
#
# 32 ('b e r s o l e k', 'b l e k e k', 'b e l u b u r', 'b e r s t a t u s', 'b e n t u r a n', 'a r s i t e k t u r', 'b e r a n g k a t', 'b e r s e n a n g', 'b e r k i k', 'b e r s a l j u', 'b e r t a n i', 'b o n g o k', 'b e r a l u n', 'a l e r g i s', 'b e r l a n t a i', 'a t o k', 'b a n y o l a n', 'b e r p a t a h', 'b i n a a n', 'b a d m i n t o n', 'b e r t a r u n g', 'a y u n d a', 'b a p', 'b i j i', 'b i b i t', 'a w a w a r n a', 'b o i k o t', 'a b i a n', 'b e r h o r m a t', 'b e k s a n', 'a l e g o r i', 'b u a r i')
# ('b ə r s o l e ʔ', 'b l ə k e ʔ', 'b ə l u b u r', 'b ə r s t a t u s', 'b ə n t u r a n', 'a r s i t e ʔ t u r', 'b ə r a ŋ k a t', 'b ə r s ə n a ŋ', 'b ə r k i ʔ', 'b ə r s a l d ʒ u', 'b ə r t a n i', 'b o ŋ o ʔ', 'b ə r a l u n', 'a l e r g i s', 'b ə r l a n t a i', 'a t o ʔ', 'b a ɲ o l a n', 'b ə r p a t a h', 'b i n a ʔ a n', 'b a d m i n t o n', 'b ə r t a r u ŋ', 'a j u n d a', 'b a p', 'b i d ʒ i', 'b i b i t', 'a w a w a r n a', 'b o i k o t', 'a b i a n', 'b ə r h o r m a t', 'b ə ʔ s a n', 'a l e g o r i', 'b u a r i')
#
# 32 ('b e s a r k a n', 'b e r p e n g e t a h u a n', 'b o n t o t', 'b e r t e m a', 'a j a i b', 'a n t a r d a e r a h', 'a d e m p a u z e', 'b i c a n a', 'a n t i s i p a t i f', 'b e r e s', 'a n t i h i s t a m i n', 'a p o s t e r i o r i', 'b e r k e r i n g', 'a d i c i t a', 'a p a r a t', 'b u l a t a n', 'b e r c i r i k a n', 'b i a r a w a n', 'b a n d u l a n', 'b e r k e r u m u n', 'b e r d o m i n a s i', 'b e r e m b u s', 'b e r t a f a k u r', 'b e l a n d o n g a n', 'a r k u', 'a j a r', 'b o n y o k', 'b e r b a h a s a', 'b e r j a n j i', 'b e l a m b a n g', 'b e l u b u', 'b e r s a n g k u t')
# ('b ə s a r k a n', 'b ə r p ə ŋ ə t a h u a n', 'b o n t o t', 'b ə r t e m a', 'a d ʒ a i b', 'a n t a r d a e r a h', 'a d ə m p a u z ə', 'b i t ʃ a n a', 'a n t i s i p a t i f', 'b e r e s', 'a n t i h i s t a m i n', 'a p o s t ə r i o r i', 'b ə r k ə r i ŋ', 'a d i t ʃ i t a', 'a p a r a t', 'b u l a t a n', 'b ə r t ʃ i r i k a n', 'b i a r a w a n', 'b a n d u l a n', 'b ə r k ə r u m u n', 'b ə r d o m i n a s i', 'b ə r ə m b u s', 'b ə r t a f a k u r', 'b ə l a n d o ŋ a n', 'a r k u', 'a d ʒ a r', 'b o ɲ o ʔ', 'b ə r b a h a s a', 'b ə r d ʒ a n d ʒ i', 'b ə l a m b a ŋ', 'b ə l u b u', 'b ə r s a ŋ k u t')
#
# 32 ('b a t a l i o n', 'b e r s e w a k a', 'a m a r a n', 'a m p a i', 'a n g g u r a n', 'a p a k a h', 'b e r g e r o m b o l', 'b e r k u n j u n g', 'b e l i a n', 'a n u n a s i k a', 'a p a r t h e i d', 'b e r h u b u n g', 'b a k m i', 'b e r t e n g g a n g', 'b e r u n t u n', 'b a h a s', 'b i a w a s', 'b e l a n j a a n', 'b e n t e n g', 'a n a e r o b', 'b a r e n g', 'b e r d i n d i n g', 'b e r t i n g k a t', 'b a p l a n g', 'a k s e p t o r', 'b e r t a r u h', 'b e r h a r a p', 'b e l u n g s i n g', 'a r s i p e l a g o', 'a m p r o k', 'b e r c a l i t', 'b e r k e l u m u n')
# ('b a t a l i o n', 'b ə r s e w a k a', 'a m a r a n', 'a m p a i', 'a ŋ g u r a n', 'a p a k a h', 'b ə r g ə r o m b o l', 'b ə r k u n d ʒ u ŋ', 'b ə l i a n', 'a n u n a s i k a', 'a p a r t h e i d', 'b ə r h u b u ŋ', 'b a ʔ m i', 'b ə r t e ŋ g a ŋ', 'b ə r u n t u n', 'b a h a s', 'b i a w a s', 'b ə l a n d ʒ a ʔ a n', 'b e n t e ŋ', 'a n a e r o b', 'b a r ə ŋ', 'b ə r d i n d i ŋ', 'b ə r t i ŋ k a t', 'b a p l a ŋ', 'a ʔ s e p t o r', 'b ə r t a r u h', 'b ə r h a r a p', 'b ə l u ŋ s i ŋ', 'a r s i p e l a g o', 'a m p r o ʔ', 'b ə r t ʃ a l i t', 'b ə r k ə l u m u n')
#
# 32 ('a b s e n', 'b i o s k o p', 'b u d u k', 'b e r a n g g u k', 'b e r a r o m a', 'a k l i m a t i s a s i', 'b a r a u', 'a n t i m u n t a h', 'a n t i s e p s i s', 'a b r i k o s', 'b e l i k a t', 'b e r p e l u k a n', 'a k u n', 'b e r e n d e n g', 'a e r o m o v e l', 'b e r p e t a m', 'b e r c u r a', 'b e r k o m e n t a r', 'a f e k s i', 'b e r a - g o - g o', 'a d i k a', 'b u d i', 'b a m b a n g', 'b e r g i g i', 'b o r o k', 'b e r k e r i s', 'b l o k a d e', 'b e r c e l a', 'b e r u r u t a n', 'b e r s e t r i p', 'a n g k i t', 'a l u m n i')
# ('a b s e n', 'b i o s k o p', 'b u d u ʔ', 'b ə r a ŋ g u ʔ', 'b ə r a r o m a', 'a ʔ l i m a t i s a s i', 'b a r a u', 'a n t i m u n t a h', 'a n t i s e p s i s', 'a b r i k o s', 'b ə l i k a t', 'b ə r p ə l u k a n', 'a k u n', 'b ə r e n d e ŋ', 'a e r o m o v e l', 'b ə r p ə t a m', 'b ə r t ʃ u r a', 'b ə r k o m e n t a r', 'a f e ʔ s i', 'b ə r a g o g o', 'a d i k a', 'b u d i', 'b a m b a ŋ', 'b ə r g i g i', 'b o r o ʔ', 'b ə r k ə r i s', 'b l o k a d ə', 'b ə r t ʃ ə l a', 'b ə r u r u t a n', 'b ə r s ə t r i p', 'a ŋ k i t', 'a l u m n i')
#
# 32 ('b e b a l', 'b a s u n g a n', 'b e r b a u r', 'b e r p e s i a r', 'b e l a a n', 'b e r j i r a n', 'b e r n o b a t', 'a m p u k', 'a s u h', 'b e r k u b a n g', 'b e c e n g', 'a s a d', 'b a r i n g', 'b e r b a t u', 'a s m a r a l o k a', 'b e r a d a b', 'b e r e m a s', 'a m u k a n', 'b e r g e r a k', 'b e r e h a t', 'b e r o n j o n g', 'a p r i t', 'b a g a i', 'a y o', 'b e r l i b u r', 'a b a t o a r', 'b e r s e t e r u', 'a u t e n t i k', 'a l a m i', 'b e r d e m p e t', 'b e r g e r i g i', 'b a g a i m a n a p u n')
# ('b ə b a l', 'b a s u ŋ a n', 'b ə r b a u r', 'b ə r p ə s i a r', 'b ə l a ʔ a n', 'b ə r d ʒ i r a n', 'b ə r n o b a t', 'a m p u ʔ', 'a s u h', 'b ə r k u b a ŋ', 'b e t ʃ e ŋ', 'a s a d', 'b a r i ŋ', 'b ə r b a t u', 'a s m a r a l o k a', 'b ə r a d a b', 'b ə r ə m a s', 'a m u k a n', 'b ə r g ə r a ʔ', 'b ə r e h a t', 'b ə r o n d ʒ o ŋ', 'a p r i t', 'b a g a i', 'a j o', 'b ə r l i b u r', 'a b a t o a r', 'b ə r s ə t ə r u', 'a u t e n t i ʔ', 'a l a m i', 'b ə r d e m p e t', 'b ə r g ə r i g i', 'b a g a i m a n a p u n')
#
# 32 ('a s e r a n', 'b e r s i m p a t i', 'a i n u l b a n a t', 'a n u s', 'a w a n a m a', 'a p i a n', 'b e r e g u', 'b e r d e r a n g', 'b a n g k o k', 'a r a l', 'a k t i v i s', 'a l k a r i', 'b e k a', 'a s e k s u a l', 'a n t i - b e k u', 'b e r s e n d a r', 'b u a i', 'b e n g g a l a', 'b e r g e l u t', 'b e r b i n t i l', 'b e r t e k a t', 'a s a l', 'a u t a r k i s', 'b a k e l i t', 'b e r c e m p e r a', 'b e n u r', 'b e r k e c i m p u n g', 'b a t u a n', 'b e r d a f t a r', 'a t a v i s m e', 'a n c a m a n', 'b a h a l a')
# ('a s ə r a n', 'b ə r s i m p a t i', 'a i n u l b a n a t', 'a n u s', 'a w a n a m a', 'a p i a n', 'b ə r ə g u', 'b ə r d ə r a ŋ', 'b a ŋ k o ʔ', 'a r a l', 'a ʔ t i v i s', 'a l k a r i', 'b e k a', 'a s e ʔ s u a l', 'a n t i b ə k u', 'b ə r s ə n d a r', 'b u a i', 'b ə ŋ g a l a', 'b ə r g ə l u t', 'b ə r b i n t i l', 'b ə r t ə k a t', 'a s a l', 'a u t a r k i s', 'b a k ə l i t', 'b ə r t ʃ ə m p ə r a', 'b ə n u r', 'b ə r k ə t ʃ i m p u ŋ', 'b a t u a n', 'b ə r d a f t a r', 'a t a v i s m ə', 'a n t ʃ a m a n', 'b a h a l a')
#
# 32 ('a n t u n g', 'a m i k a l', 'b a n g', 'b e r u j u l', 'b u m i a h', 'b i d a n', 'b a k o', 'b o n g k o', 'a m a n t u', 'a r e n a', 'b e r u n s u r', 'b e r a l a h', 'b e r j a m', 'a d m i n i s t r a s i', 'a y o m', 'b e r k e r u n y u t', 'b e r b a k i', 'a p e s', 'a j a r i', 'b i k i r', 'b e r l a u', 'b e r t i u p', 'b u a n g a n', 'b e l i l a h', 'b e r k e m i h', 'a d i g u n a', 'a r n a l', 'b i n t u l', 'b e r k e m a l', 'b e r e n d a', 'b e r a n d a m', 'a u t o k r a s i')
# ('a n t u ŋ', 'a m i k a l', 'b a ŋ', 'b ə r u d ʒ u l', 'b u m i a h', 'b i d a n', 'b a k o', 'b o ŋ k o', 'a m a n t u', 'a r ə n a', 'b ə r u n s u r', 'b ə r a l a h', 'b ə r d ʒ a m', 'a d m i n i s t r a s i', 'a j o m', 'b ə r k ə r u ɲ u t', 'b ə r b a k i', 'a p ə s', 'a d ʒ a r i', 'b i k i r', 'b ə r l a u', 'b ə r t i u p', 'b u a ŋ a n', 'b ə l i l a h', 'b ə r k ə m i h', 'a d i g u n a', 'a r n a l', 'b i n t u l', 'b ə r k ə m a l', 'b ə r e n d a', 'b ə r a n d a m', 'a u t o ʔ r a s i')
#
# 32 ('b a u', 'b e r d e n t i n g', 'b e r t e m u', 'a s o s i a s i', 'a n t i', 'b i k i n i', 'a w a l', 'a b j a d', 'a k t u a r i a', 'b e t i', 'b a l a d a', 'b e r e k s p r e s i', 'b e r t a k h t a', 'b a y a', 'b a c o t', 'b e r t e r a s', 'b e r c a b a n g', 'b e r s i t', 'a k h i r n y a', 'a d i w i d i a', 'a n y a m', 'b i n t a n', 'b e r c a c a h', 'b e r s e m b a y a n', 'b a n z a i', 'a k r o b a t i k', 'b e r a g a n', 'b e r k i p a s', 'b e n d a h a r a', 'a n t a r t i k a', 'b e r h e m a t', 'a i r i')
# ('b a u', 'b ə r d ə n t i ŋ', 'b ə r t ə m u', 'a s o s i a s i', 'a n t i', 'b i k i n i', 'a w a l', 'a b d ʒ a d', 'a ʔ t u a r i a', 'b ə t i', 'b a l a d a', 'b ə r e ʔ s p r e s i', 'b ə r t a ʔ h t a', 'b a j a', 'b a t ʃ o t', 'b ə r t ə r a s', 'b ə r t ʃ a b a ŋ', 'b ə r s i t', 'a ʔ h i r ɲ a', 'a d i w i d i a', 'a ɲ a m', 'b i n t a n', 'b ə r t ʃ a t ʃ a h', 'b ə r s ə m b a j a n', 'b a n z a i', 'a ʔ r o b a t i ʔ', 'b ə r a g a n', 'b ə r k i p a s', 'b ə n d a h a r a', 'a n t a r t i k a', 'b ə r h e m a t', 'a i r i')
#
# 32 ('b e g u n d a l', 'b a r u l a h', 'b a l', 'b a g a u', 'a r a k i a n', 'a n d a n', 'b e r a w a l a n', 'b e n g a l', 'b e k e n', 'a l a f', 'a k t i v a', 'b e r n y a l a', 'b a d a n n y a', 'a d e h', 'b o r e h', 'b e l u m', 'a l m a m a t e r', 'b o n d o l', 'b e j a t', 'b e r b e l i n t a n g', 'b e r s e s a k', 'b e r a n g g a r', 'b u k e t', 'b e r s e p e d a', 'a n t i k l i n', 'a y u t a n', 'b e l i b a t', 'b e l e k', 'b e r s u k a c i t a', 'b e n d i', 'b e l a n d o n g', 'b e r b a j u')
# ('b ə g u n d a l', 'b a r u l a h', 'b a l', 'b a g a u', 'a r a k i a n', 'a n d a n', 'b ə r a w a l a n', 'b ə ŋ a l', 'b ə k e n', 'a l a f', 'a ʔ t i v a', 'b ə r ɲ a l a', 'b a d a n ɲ a', 'a d e h', 'b o r ə h', 'b ə l u m', 'a l m a m a t e r', 'b o n d o l', 'b ə d ʒ a t', 'b ə r b ə l i n t a ŋ', 'b ə r s ə s a ʔ', 'b ə r a ŋ g a r', 'b u k e t', 'b ə r s ə p e d a', 'a n t i ʔ l i n', 'a j u t a n', 'b ə l i b a t', 'b e l e ʔ', 'b ə r s u k a t ʃ i t a', 'b e n d i', 'b ə l a n d o ŋ', 'b ə r b a d ʒ u')
#
# 32 ('b o t a n i k u s', 'b e r a j a', 'b e r s e p i', 'b e r s e g e r a', 'b a r a n', 'b e r s u s a h', 'b e r k a t a', 'a m p e l', 'a n t a r a n', 'b o n c o n g', 'a t a r', 'a w a a i r', 'b e r i s t i g h f a r', 'b l a z e r', 'b e s t e l', 'b e r k e l u n', 'b e r s e g e h', 'a d a k a l a', 'b e r e v o l u s i', 'b a k d a', 'b a u k s i t', 'a y a n g', 'b e r d a b u n g', 'b a h a s a w a n', 'b e r l a k o n', 'b i a y a', 'a d i t o k o h', 'b u d i m a n', 'b e r s e c e p a t', 'a n d i l a u', 'a r t i k e l', 'a l i n g a n')
# ('b o t a n i k u s', 'b ə r a d ʒ a', 'b ə r s ə p i', 'b ə r s ə g ə r a', 'b a r a n', 'b ə r s u s a h', 'b ə r k a t a', 'a m p e l', 'a n t a r a n', 'b o n t ʃ o ŋ', 'a t a r', 'a w a ʔ a i r', 'b ə r i s t i g h f a r', 'b l a z ə r', 'b ə s t e l', 'b ə r k ə l u n', 'b ə r s e g e h', 'a d a k a l a', 'b ə r e v o l u s i', 'b a ʔ d a', 'b a u ʔ s i t', 'a j a ŋ', 'b ə r d a b u ŋ', 'b a h a s a w a n', 'b ə r l a k o n', 'b i a j a', 'a d i t o k o h', 'b u d i m a n', 'b ə r s ə t ʃ ə p a t', 'a n d i l a u', 'a r t i k ə l', 'a l i ŋ a n')
#
# 32 ('a i r n y a', 'a r t e r i o s k l e r o s i s', 'b e r d a p a t', 'b e l u n g k u r', 'b e r l a n j u t', 'b u b u t', 'b i l u r', 'b i a w a k', 'b u n b u n a n', 'b e r c e c a h', 'b e r t u g a s', 'b u g i l', 'b e n g e p', 'a s p i r a t i f', 'b a n g a n', 'b e r c e k i k', 'b u g e n v i l', 'b a n g i', 'b e l e n g k o k', 'b e r b u l u', 'b e r t e r a s k a n', 'b u j u k a n n y a', 'b e r l a b a', 'b e r s e k a t', 'b e r c e n d u a i', 'b e r s e p a n', 'b a c e m a n', 'b o p o n g', 'b e r b a r e n g a n', 'a m p u n', 'b e r p e r i s t i w a', 'a t l e t')
# ('a i r ɲ a', 'a r t e r i o s ʔ l e r o s i s', 'b ə r d a p a t', 'b ə l u ŋ k u r', 'b ə r l a n d ʒ u t', 'b u b u t', 'b i l u r', 'b i a w a ʔ', 'b u n b u n a n', 'b ə r t ʃ ə t ʃ a h', 'b ə r t u g a s', 'b u g i l', 'b ə ŋ ə p', 'a s p i r a t i f', 'b a ŋ a n', 'b ə r t ʃ ə k i ʔ', 'b u g ə n v i l', 'b a ŋ i', 'b ə l e ŋ k o ʔ', 'b ə r b u l u', 'b ə r t ə r a s k a n', 'b u d ʒ u k a n ɲ a', 'b ə r l a b a', 'b ə r s ə k a t', 'b ə r t ʃ ə n d u a i', 'b ə r s ə p a n', 'b a t ʃ ə m a n', 'b o p o ŋ', 'b ə r b a r ə ŋ a n', 'a m p u n', 'b ə r p ə r i s t i w a', 'a t l e t')
#
# 32 ('a k s e l e r a t o r', 'b o t e l i r', 'b e r s u m b e r k a n', 'b e r d a t a n g', 'b e r a s m a r a', 'b e r b a h a n a', 'b u n g a a n', 'a r a b i k a', 'b e k e r j a', 'a n u g e r a h', 'b e r b e n t e h', 'b e r d e r e t a n', 'b e r m e r e k', 'a r y a', 'b a n t u', 'b r a m b a n g', 'a b a i a n', 'b e r s a t u', 'b a n t i n g', 'a n a s i r', 'a n g g u r', 'b e r k i l a u', 'a d u h', 'a r g u m e n t a t i f', 'b e k e r j a s a m a', 'b e r h a l a', 'b i n c u t', 'b e r h i m p u n', 'a g a l', 'a l e m a n', 'a t a s e', 'a m b i l')
# ('a ʔ s e l ə r a t o r', 'b o t ə l i r', 'b ə r s u m b ə r k a n', 'b ə r d a t a ŋ', 'b ə r a s m a r a', 'b ə r b a h a n a', 'b u ŋ a ʔ a n', 'a r a b i k a', 'b ə k ə r d ʒ a', 'a n u g ə r a h', 'b ə r b e n t e h', 'b ə r d e r e t a n', 'b ə r m e r ə ʔ', 'a r j a', 'b a n t u', 'b r a m b a ŋ', 'a b a i a n', 'b ə r s a t u', 'b a n t i ŋ', 'a n a s i r', 'a ŋ g u r', 'b ə r k i l a u', 'a d u h', 'a r g u m e n t a t i f', 'b ə k ə r d ʒ a s a m a', 'b ə r h a l a', 'b i n t ʃ u t', 'b ə r h i m p u n', 'a g a l', 'a l ə m a n', 'a t a s e', 'a m b i l')
#
# 32 ('b e r e s', 'a n g g i t a n', 'b e r s e n d i r i', 'b a n g a r', 'a p a l a g i', 'b e r k e n d u r i', 'b o b o l', 'a s e p t i k', 'a n a r k i', 'a k h i r a n', 'b e r t e s m a k', 'a n t i s e p t i k', 'a r k a t i', 'b e l u a s', 'b e r s o r a k', 'b e r b u k i t', 'b a f t a', 'b i k a n g', 'b e r s e b e r a n g a n', 'b e n d e r u n g', 'a g u s', 'b e r l a k u', 'b e r k i l', 'b e r b i n t a n g', 'b e r l i d a h', 'a r k e o l o g', 'a l', 'b a s t a r', 'b e r d e g a m', 'b e t a', 'b e r k a i t', 'b e l e b a t')
# ('b ə r e s', 'a ŋ g i t a n', 'b ə r s ə n d i r i', 'b a ŋ a r', 'a p a l a g i', 'b ə r k ə n d u r i', 'b o b o l', 'a s e p t i ʔ', 'a n a r k i', 'a ʔ h i r a n', 'b ə r t ə s m a ʔ', 'a n t i s e p t i ʔ', 'a r k a t i', 'b ə l u a s', 'b ə r s o r a ʔ', 'b ə r b u k i t', 'b a f t a', 'b i k a ŋ', 'b ə r s ə b ə r a ŋ a n', 'b ə n d ə r u ŋ', 'a g u s', 'b ə r l a k u', 'b ə r k i l', 'b ə r b i n t a ŋ', 'b ə r l i d a h', 'a r k e o l o g', 'a l', 'b a s t a r', 'b ə r d ə g a m', 'b e t a', 'b ə r k a i t', 'b ə l ə b a t')
#
# 32 ('b e n u a', 'a r t i a n', 'b o l e r o', 'b e r t u n a n g', 'a k a i d', 'b o m b e r', 'a l o m o r f', 'a s i n', 'b e c u k', 'b e r s e n g g a y u t', 'b e l u r u', 'b a j i n g a n', 'b e r s i f a t', 'b e l i m b i n g', 'a s u', 'b e r s e l i n g', 'b e n d u a n', 'a k i b a t n y a', 'a d i l a n', 'b i n t a l', 'a f s u n', 'b e r p o t o n g a n', 'b e r d a k w a h', 'a l i r a n', 'b e r p e n d i d i k a n', 'b i s b o l', 'b a n y a k n y a', 'b e s o k', 'b o h o r o k', 'b e r a l a n g a n', 'b e l a', 'a u t o k r a t')
# ('b ə n u a', 'a r t i a n', 'b o l e r o', 'b ə r t u n a ŋ', 'a k a i d', 'b o m b ə r', 'a l o m o r f', 'a s i n', 'b e t ʃ u ʔ', 'b ə r s ə ŋ g a j u t', 'b ə l u r u', 'b a d ʒ i ŋ a n', 'b ə r s i f a t', 'b ə l i m b i ŋ', 'a s u', 'b ə r s ə l i ŋ', 'b ə n d u a n', 'a k i b a t ɲ a', 'a d i l a n', 'b i n t a l', 'a f s u n', 'b ə r p o t o ŋ a n', 'b ə r d a ʔ w a h', 'a l i r a n', 'b ə r p ə n d i d i k a n', 'b i s b o l', 'b a ɲ a ʔ ɲ a', 'b e s o ʔ', 'b o h o r o ʔ', 'b ə r a l a ŋ a n', 'b e l a', 'a u t o ʔ r a t')
#
# 32 ('b e n g k a n g', 'b i s a i', 'b e r a n g k a i', 'b e r s a s t r a', 'a r e m', 'b e r u k i r', 'b e r g e g a s', 'b a n g k e t', 'a m i s', 'b e r p e r a n a n', 'a c a h', 'b a n t e n g', 'b e r k e r u b u n g', 'b e l o l o k', 'b e r u k u r a n', 'a p i k a l', 'b e r c e c e r a n', 'a n g h u n', 'b e r a n t u k', 'b e r s u n g u t', 'b a b i', 'a n t a r s e l', 'b u b u h a n', 'a r u k', 'b e n d a n y a', 'b e r p e n g h a s i l a n', 'a p e n d i s i t i s', 'b e r b i r a s', 'b e r c a b i r a n', 'b i a r p u n', 'b e l a c a k', 'b e r p i h a k')
# ('b e ŋ k a ŋ', 'b i s a i', 'b ə r a ŋ k a i', 'b ə r s a s t r a', 'a r ə m', 'b ə r u k i r', 'b ə r g ə g a s', 'b a ŋ k e t', 'a m i s', 'b ə r p ə r a n a n', 'a t ʃ a h', 'b a n t ə ŋ', 'b ə r k ə r u b u ŋ', 'b ə l o l o ʔ', 'b ə r u k u r a n', 'a p i k a l', 'b ə r t ʃ e t ʃ e r a n', 'a ŋ h u n', 'b ə r a n t u ʔ', 'b ə r s u ŋ u t', 'b a b i', 'a n t a r s e l', 'b u b u h a n', 'a r u ʔ', 'b ə n d a ɲ a', 'b ə r p ə ŋ h a s i l a n', 'a p e n d i s i t i s', 'b ə r b i r a s', 'b ə r t ʃ a b i r a n', 'b i a r p u n', 'b ə l a t ʃ a ʔ', 'b ə r p i h a ʔ')
#
# 32 ('a d a s', 'b e r k e s i m p u l a n', 'a n t e r o', 'b u a k', 'b i n d e r', 'b a l o k', 'b e r s e b e l a h a n', 'a d a k a h', 'b e r t a n g g u h', 'b e r d a u n', 'b e r k h a s i a t', 'b e r t e p i', 'b e r d e p a n', 'b e r p e d o m a n', 'b e r k e r i c a u', 'a b a i', 'b e r i r a m a', 'a r a h n y a', 'b a l a t e n t a r a', 'b e k e r', 'b e r g e m u r u h', 'b i p o l a r', 'b e r t a b u n g', 'b e r u n d i n g', 'b a c o k', 'b e t a p a', 'b e r d u e l', 'a h m a d', 'b o g o t', 'b e r k e k u r a n g a n', 'a n t e l a s', 'b e r d e t a r')
# ('a d a s', 'b ə r k ə s i m p u l a n', 'a n t e r o', 'b u a ʔ', 'b i n d ə r', 'b a l o ʔ', 'b ə r s ə b ə l a h a n', 'a d a k a h', 'b ə r t a ŋ g u h', 'b ə r d a u n', 'b ə r ʔ h a s i a t', 'b ə r t ə p i', 'b ə r d ə p a n', 'b ə r p ə d o m a n', 'b ə r k ə r i t ʃ a u', 'a b a i', 'b ə r i r a m a', 'a r a h ɲ a', 'b a l a t ə n t a r a', 'b e k ə r', 'b ə r g ə m u r u h', 'b i p o l a r', 'b ə r t a b u ŋ', 'b ə r u n d i ŋ', 'b a t ʃ o ʔ', 'b ə t a p a', 'b ə r d u e l', 'a h m a d', 'b o g o t', 'b ə r k ə k u r a ŋ a n', 'a n t ə l a s', 'b ə r d ə t a r')
#
# 32 ('a r k e o l o g i', 'b e r k e l o k', 'b u l g u r', 'b e m b a m', 'b a n d a r a', 'b e r d e r a m', 'a l w a h', 'a d i d a y a', 'a f d e l i n g', 'b e n t u k', 'b a p a', 'b e r d e n g k i n g', 'a t o m', 'b e r s e m e n d a', 'b o g o l', 'a n t i e n z i m', 'b a b a n g', 'a c a r', 'b a n g b u n g', 'b e r t a n g g u n g', 'b e r b e l a h', 'a d m i n i s t r a t o r', 'b e r k e b u n', 'a b u r', 'b e r s e n g k e l i n g', 'a r l o j i', 'a m o r a l', 'b e r b e l a h a n', 'a d u', 'b e r k e j a n g', 'a l a n g', 'a n i h')
# ('a r k e o l o g i', 'b ə r k e l o ʔ', 'b u l g u r', 'b ə m b a m', 'b a n d a r a', 'b ə r d ə r a m', 'a l w a h', 'a d i d a j a', 'a f d e l i ŋ', 'b ə n t u ʔ', 'b a p a', 'b ə r d ə ŋ k i ŋ', 'a t o m', 'b ə r s ə m ə n d a', 'b o g o l', 'a n t i e n z i m', 'b a b a ŋ', 'a t ʃ a r', 'b a ŋ b u ŋ', 'b ə r t a ŋ g u ŋ', 'b ə r b ə l a h', 'a d m i n i s t r a t o r', 'b ə r k ə b u n', 'a b u r', 'b ə r s ə ŋ k ə l i ŋ', 'a r l o d ʒ i', 'a m o r a l', 'b ə r b ə l a h a n', 'a d u', 'b ə r k ə d ʒ a ŋ', 'a l a ŋ', 'a n i h')
#
# 32 ('b e r h a m p i r a n', 'a n g l o n g', 'a d i l', 'b e g u', 'b o n g k a l', 'b e r k e m e n d a n g', 'a l i n', 'b e r s e t u j u', 'a p u r a n', 'b e r a d a k a n', 'b i n c a c a k', 'b e n g u n g', 'b e r k a b u t', 'b e r g u r u', 'b e r k o m u n i k a s i', 'a s t r o n a u t', 'b r i s a n', 'a n i a y a', 'b e r s u d u t', 'a m b e k', 'b e r d e n g k u s', 'b e l a n', 'b i l a h', 'b e r k e m b a n', 'a n e s t e s i', 'b r o s u r', 'b e r b u d i', 'b e r p e n g h u n i', 'b e n g k a r a s', 'b e r k e m a m p u a n', 'b i s u', 'a y a r')
# ('b ə r h a m p i r a n', 'a ŋ l o ŋ', 'a d i l', 'b e g u', 'b o ŋ k a l', 'b ə r k ə m ə n d a ŋ', 'a l i n', 'b ə r s ə t u d ʒ u', 'a p u r a n', 'b ə r a d a k a n', 'b i n t ʃ a t ʃ a ʔ', 'b ə ŋ u ŋ', 'b ə r k a b u t', 'b ə r g u r u', 'b ə r k o m u n i k a s i', 'a s t r o n a u t', 'b r i s a n', 'a n i a j a', 'b ə r s u d u t', 'a m b ə ʔ', 'b ə r d ə ŋ k u s', 'b ə l a n', 'b i l a h', 'b ə r k ə m b a n', 'a n e s t e s i', 'b r o s u r', 'b ə r b u d i', 'b ə r p ə ŋ h u n i', 'b ə ŋ k a r a s', 'b ə r k ə m a m p u a n', 'b i s u', 'a j a r')
#
# 32 ('a n t i b i o t i k', 'b a h t e r a', 'b e r s e l e r a', 'b e r d a d u n g', 'b a g a k', 'a p i t', 'b l e k o k', 'a j a k a n', 'b e l a n g a h', 'b e r c a r u t', 'a r w a h', 'b e r b a d a n', 'b e r p u l u h', 'b e r b u l a n g', 'b e r d e n t a m', 'b e s l a h a n', 'b o k s u', 'b e r p a n g k a l a n', 'b o n g g o l', 'b e r k e m a h', 'a n g s o k a', 'b e n c a t', 'a k o r', 'b e d i l', 'b e r p e r i', 'a m a l g a m', 'b a l a n g', 'a f e k t i f', 'a s a b i a h', 'b a n g k a r', 'b e r l a r u t', 'b e l e k')
# ('a n t i b i o t i ʔ', 'b a h t ə r a', 'b ə r s ə l e r a', 'b ə r d a d u ŋ', 'b a g a ʔ', 'a p i t', 'b l ə k o ʔ', 'a d ʒ a k a n', 'b ə l a ŋ a h', 'b ə r t ʃ a r u t', 'a r w a h', 'b ə r b a d a n', 'b ə r p u l u h', 'b ə r b u l a ŋ', 'b ə r d ə n t a m', 'b ə s l a h a n', 'b o ʔ s u', 'b ə r p a ŋ k a l a n', 'b o ŋ g o l', 'b ə r k e m a h', 'a ŋ s o k a', 'b ə n t ʃ a t', 'a k o r', 'b ə d i l', 'b ə r p ə r i', 'a m a l g a m', 'b a l a ŋ', 'a f e ʔ t i f', 'a s a b i a h', 'b a ŋ k a r', 'b ə r l a r u t', 'b ə l e ʔ')
#
# 32 ('b e r p e l u a n g', 'a n t a r a b a n g s a', 'b e n i n g', 'b e r s e r a k', 'b e m b a r a p', 'b e r c a r a h', 'a b a i m a n a', 'a k h t a j', 'b e k a l a n', 'b i n a t a n g', 'a n d r o g e n', 'b e r t o l a k', 'b e r s a i n g', 'b e r a b a n g', 'b e t o n', 'b e r t i n d a k', 'b e r k e c a n d a n', 'a j e k', 'a l u p', 'b e r s e k o n g k o l', 'a n t r o p o m o r f i s m e', 'b e r t i t a h', 'b e r a n t u k a n', 'a u t o n o m i', 'b e g o n i a', 'b e r l a u k', 'b o l e h k a h', 'a u d i o l o g i', 'a t o m i s t i s', 'b o n c e n g a n', 'b a y a n g', 'a b r i k')
# ('b ə r p ə l u a ŋ', 'a n t a r a b a ŋ s a', 'b ə n i ŋ', 'b ə r s e r a ʔ', 'b ə m b a r a p', 'b ə r t ʃ a r a h', 'a b a i m a n a', 'a ʔ h t a d ʒ', 'b ə k a l a n', 'b i n a t a ŋ', 'a n d r o g e n', 'b ə r t o l a ʔ', 'b ə r s a i ŋ', 'b ə r a b a ŋ', 'b ə t o n', 'b ə r t i n d a ʔ', 'b ə r k ə t ʃ a n d a n', 'a d ʒ ə ʔ', 'a l u p', 'b ə r s ə k o ŋ k o l', 'a n t r o p o m o r f i s m ə', 'b ə r t i t a h', 'b ə r a n t u k a n', 'a u t o n o m i', 'b e g o n i a', 'b ə r l a u ʔ', 'b o l e h k a h', 'a u d i o l o g i', 'a t o m i s t i s', 'b o n t ʃ e ŋ a n', 'b a j a ŋ', 'a b r i ʔ')
#
# 32 ('b e a', 'b e r d a r a h', 'a n t a k e s u m a', 'a n a l i s', 'a b o r s i', 'b u n g k u k', 'a m e t i s', 'a k s e p', 'b e n a r a', 'a s f a l', 'a n t e n g', 'b r u t a l', 'b e r b a n g s a', 'b e r k i c a u', 'b e r g i z i', 'b a h a n', 'a s a k', 'b e r s o a l', 'b e r d a n d a n', 'b e r d i a n g', 'a r p u s', 'a k h b a r', 'b a k a r a n', 'b e r p o l i g a m i', 'a g u t', 'b u d a n c o', 'b i m b i n g a n', 'b o n d a', 'b a l u t a n', 'b e r s e l i m u t', 'a n g e l', 'a c a w i')
# ('b e a', 'b ə r d a r a h', 'a n t a k ə s u m a', 'a n a l i s', 'a b o r s i', 'b u ŋ k u ʔ', 'a m ə t i s', 'a ʔ s e p', 'b ə n a r a', 'a s f a l', 'a n t ə ŋ', 'b r u t a l', 'b ə r b a ŋ s a', 'b ə r k i t ʃ a u', 'b ə r g i z i', 'b a h a n', 'a s a ʔ', 'b ə r s o a l', 'b ə r d a n d a n', 'b ə r d i a ŋ', 'a r p u s', 'a ʔ h b a r', 'b a k a r a n', 'b ə r p o l i g a m i', 'a g u t', 'b u d a n t ʃ o', 'b i m b i ŋ a n', 'b o n d a', 'b a l u t a n', 'b ə r s ə l i m u t', 'a ŋ e l', 'a t ʃ a w i')
#
# 32 ('a l i m b u b u', 'b e r b o g a', 'a d a g i o', 'b e r k e l a k u a n', 'a m o n i u m', 'a b s e n t e i s m e', 'b e r k e p u l', 'b e r b a s i s', 'a p o l o g i a', 'b e n z e n a', 'b o n b o n', 'a g u k', 'a l a s a n', 'b e r k u m a n d a n g', 'b e l a n t i k a', 'b e n g k a n g', 'b e l a c a n', 'b u k u', 'b e r t a n d a n g', 'a l i m i a t', 'a n d a i', 'b u n g a r a n', 'b a t i h', 'b e n t u r', 'a d e g a n', 'b a g o r', 'b u n c a n g', 'b e r c o r a k', 'a n d a m a n', 'b u b u t a n', 'a n o m', 'b e r s a l u t')
# ('a l i m b u b u', 'b ə r b o g a', 'a d a g i o', 'b ə r k ə l a k u a n', 'a m o n i u m', 'a b s e n t e i s m ə', 'b ə r k ə p u l', 'b ə r b a s i s', 'a p o l o g i a', 'b e n z e n a', 'b o n b o n', 'a g u ʔ', 'a l a s a n', 'b ə r k u m a n d a ŋ', 'b ə l a n t i k a', 'b ə ŋ k a ŋ', 'b ə l a t ʃ a n', 'b u k u', 'b ə r t a n d a ŋ', 'a l i m i a t', 'a n d a i', 'b u ŋ a r a n', 'b a t i h', 'b ə n t u r', 'a d ə g a n', 'b a g o r', 'b u n t ʃ a ŋ', 'b ə r t ʃ o r a ʔ', 'a n d a m a n', 'b u b u t a n', 'a n o m', 'b ə r s a l u t')
#
# 32 ('a n a l', 'a r b i t r e r', 'b e r p a c a r', 'b e r d e n g i n g', 'b e r s e r b a n', 'b e r t u b u h', 'a s i n g', 'a r i f i n', 'a b s o r p t i f', 'a d a p', 'b e n c a n a', 'a d a l a t', 'b e r c e r i c a u', 'b e r a s a s k a n', 'a n g l u n g', 'b e r p a l i n g', 'b i l i s', 'b a t a s n y a', 'b e r k e y a k i n a n', 'b a n a l', 'b e r e m p a t', 'b e r t u t u r', 'b e r k u r a p', 'a u t o p s i', 'a y a h a n d a', 'b e r a k s a r a', 'b e n g k e r', 'a s y i k', 'a f i k s', 'a k u t', 'a k u r', 'b u k')
# ('a n a l', 'a r b i t r e r', 'b ə r p a t ʃ a r', 'b ə r d ə ŋ i ŋ', 'b ə r s ə r b a n', 'b ə r t u b u h', 'a s i ŋ', 'a r i f i n', 'a b s o r p t i f', 'a d a p', 'b ə n t ʃ a n a', 'a d a l a t', 'b ə r t ʃ ə r i t ʃ a u', 'b ə r a s a s k a n', 'a ŋ l u ŋ', 'b ə r p a l i ŋ', 'b i l i s', 'b a t a s ɲ a', 'b ə r k ə j a k i n a n', 'b a n a l', 'b ə r ə m p a t', 'b ə r t u t u r', 'b ə r k u r a p', 'a u t o p s i', 'a j a h a n d a', 'b ə r a ʔ s a r a', 'b e ŋ k e r', 'a s j i ʔ', 'a f i ʔ s', 'a k u t', 'a k u r', 'b u ʔ')
#
# 32 ('a l a m a t', 'b i d a k', 'b e r i m a n', 'a m b r u k', 'a m b a n g', 'b e r d e r u m', 'b e r d u k u n g', 'a r z a k', 'b e r b a i k a n', 'a d i p o s i t a s', 'b e r d i a m', 'a d i l u h u n g', 'b a u n', 'b e r a w a s', 'a t a s a n', 'a n a i', 'b i r a m a', 'b a d o n g', 'a l t a r', 'b e r d u i t', 'b e r d e n y i t', 'b e r p o k o k', 'b e r i n g i n', 'a k t u a r i s', 'a n g k u t a n', 'b a n i', 'b e r s e n d e l', 'b e r k o m p r o m i', 'b e r s e l i b u t', 'b e r c e n c a n g', 'a b a d i k a n', 'b e r a s o s i a s i')
# ('a l a m a t', 'b i d a ʔ', 'b ə r i m a n', 'a m b r u ʔ', 'a m b a ŋ', 'b ə r d ə r u m', 'b ə r d u k u ŋ', 'a r z a ʔ', 'b ə r b a i k a n', 'a d i p o s i t a s', 'b ə r d i a m', 'a d i l u h u ŋ', 'b a u n', 'b ə r a w a s', 'a t a s a n', 'a n a i', 'b i r a m a', 'b a d o ŋ', 'a l t a r', 'b ə r d u i t', 'b ə r d ə ɲ i t', 'b ə r p o k o ʔ', 'b ə r i ŋ i n', 'a ʔ t u a r i s', 'a ŋ k u t a n', 'b a n i', 'b ə r s e n d e l', 'b ə r k o m p r o m i', 'b ə r s ə l i b u t', 'b ə r t ʃ ə n t ʃ a ŋ', 'a b a d i k a n', 'b ə r a s o s i a s i')
#
# 32 ('b e r d e t i k', 'b a k t e r i o l o g', 'b a r s o', 'b e l a n t a r a', 'b o n g m e h', 'b e d o l a n', 'a b l a s i', 'b i k u', 'b i l', 'b a t i k', 'b e r b a l a p a n', 'b o n j o r', 'b e l u t', 'b e l i a u', 'b a l u h a n', 'b a u r a n', 'b e r d a e r a h', 'a c i', 'b e r t e l i m p u h', 'b a l a r', 'b e r d w i f u n g s i', 'a d u k a n', 'b i l i k', 'b e r a p i', 'b e n g k a l a i', 'b e r d u l i', 'b e h a n d e l', 'b e l i k', 'b e l i u t', 'a u d i t o r i u m', 'a b s o r b e n', 'b e r k i l a h')
# ('b ə r d ə t i ʔ', 'b a ʔ t e r i o l o g', 'b a r s o', 'b ə l a n t a r a', 'b o ŋ m e h', 'b ə d o l a n', 'a b l a s i', 'b i k u', 'b i l', 'b a t i ʔ', 'b ə r b a l a p a n', 'b o n d ʒ o r', 'b ə l u t', 'b ə l i a u', 'b a l u h a n', 'b a u r a n', 'b ə r d a e r a h', 'a t ʃ i', 'b ə r t ə l i m p u h', 'b a l a r', 'b ə r d w i f u ŋ s i', 'a d u k a n', 'b i l i ʔ', 'b ə r a p i', 'b ə ŋ k a l a i', 'b ə r d u l i', 'b ə h a n d ə l', 'b ə l i ʔ', 'b ə l i u t', 'a u d i t o r i u m', 'a b s o r b e n', 'b ə r k i l a h')
#
# 32 ('b e r p a s i r', 'b e l u l u k', 'a s a a n', 'a w a n g', 'b i n c a n g', 'b e r s i u l', 'b e n d u n g a n', 'b e r t e l a b a t', 'b a n d e a', 'b a n y a k a n', 'a r a b', 'a b a k a', 'b o k o p', 'b i h u n', 'b o l o s', 'b e r a n g s u r', 'b a s a', 'b a n g k u', 'a n g k e r', 'b e g i n i a n', 'b e t a r a', 'a g a m a n y a', 'b a l o n', 'a b r a k a d a b r a', 'b e n c a h', 'a m i r', 'b e r t e l e p o n', 'a m p l i t u d o', 'b o l o t', 'b e r a t u r a n', 'b e r h e n t i', 'b e r c a m b a h')
# ...
#
# 32 ('b e r s e p a h', 'b e r o n g g a', 'b i n j a t', 'b e n d i r', 'a d a p t i f', 'a k u', 'b e r a t a p k a n', 'b e n g g o l a n', 'b e r s e l u b u n g', 'a n o t a s i', 'a b r a k', 'b i o t e k', 'a n g s a n a', 'a m a n', 'a l a i', 'a n t a m i r', 'b a g a s', 'a m f i b i', 'a d i r a j a', 'a r e s t a s i', 'b e t a s', 'a d i n g', 'a n g k a t n y a', 'b a r o n g', 'b o k s e r', 'b e r g e j o l a k', 'b e r s u a m i k a n', 'b e r t e r u s a n', 'b i s e p s', 'b e r k a u l', 'b e r k e s e m p a t a n', 'b e r p i l i n')
# ('b ə r s ə p a h', 'b ə r o ŋ g a', 'b i n d ʒ a t', 'b ə n d i r', 'a d a p t i f', 'a k u', 'b ə r a t a p k a n', 'b e ŋ g o l a n', 'b ə r s ə l u b u ŋ', 'a n o t a s i', 'a b r a ʔ', 'b i o t e ʔ', 'a ŋ s a n a', 'a m a n', 'a l a i', 'a n t a m i r', 'b a g a s', 'a m f i b i', 'a d i r a d ʒ a', 'a r e s t a s i', 'b ə t a s', 'a d i ŋ', 'a ŋ k a t ɲ a', 'b a r o ŋ', 'b o ʔ s ə r', 'b ə r g ə d ʒ o l a ʔ', 'b ə r s u a m i k a n', 'b ə r t ə r u s a n', 'b i s e p s', 'b ə r k a u l', 'b ə r k ə s ə m p a t a n', 'b ə r p i l i n')
#
# 32 ('b e d a h', 'b a r a k a t', 'b e r d i e t', 'b a k i', 'b e r t e g u n', 'b e r h u j a h', 'a w a r a c u n', 'b e r p u s i n g', 'b e r s u k u', 'a m r a', 'b e r d e s a k a n', 'a g o - g o', 'b e r b u n t a n g', 'a y a k', 'b e r n a d a', 'b a n t a l', 'a b d a s', 'b e r d e n d a m', 'b i o g e n i k', 'b e r u n t u s', 'b e r o n a n i', 'a p o s i t i f', 'b a k a r a t', 'b e r c a d a n g', 'b e r c e k a h', 'b e r k e l e b i h a n', 'b e l a n d u n g', 'a k a l', 'b a h a m', 'b e r h a b i s', 'a d v i s', 'b e r e t')
# ('b ə d a h', 'b a r a k a t', 'b ə r d i e t', 'b a k i', 'b ə r t ə g u n', 'b ə r h u d ʒ a h', 'a w a r a t ʃ u n', 'b ə r p u s i ŋ', 'b ə r s u k u', 'a m r a', 'b ə r d ə s a k a n', 'a g o g o', 'b ə r b u n t a ŋ', 'a j a ʔ', 'b ə r n a d a', 'b a n t a l', 'a b d a s', 'b ə r d ə n d a m', 'b i o g e n i ʔ', 'b ə r u n t u s', 'b ə r o n a n i', 'a p o s i t i f', 'b a k a r a t', 'b ə r t ʃ a d a ŋ', 'b ə r t ʃ ə k a h', 'b ə r k ə l ə b i h a n', 'b ə l a n d u ŋ', 'a k a l', 'b a h a m', 'b ə r h a b i s', 'a d v i s', 'b e r e t')
#
# 32 ('b e r k e m e j a', 'b e r t a b r a k a n', 'b e r a g i', 'b u d e k', 'b e s u k', 'b e r k i s i', 'b e r d u r i', 'b a k h i l', 'b e r u p a', 'b a n g a n g', 'b i r', 'b i a d i', 'b a r', 'b a j u l', 'b e r s e d u', 'a m u n g', 'b e r t e m a k a n', 'a y u t', 'b e r b a i t', 'b e r i s i k a n', 'b e n t a k a n', 'b e r a n j a n g k a r y a', 'b a n g u n', 'b i o g r a f i', 'a g a h', 'b e r m a', 'b a r a n g n y a', 'b a l a l a i k a', 'a n t a r w i l a y a h', 'b u k a n l a h', 'b e r j a u h a n', 'a d i k u a s a')
# ('b ə r k ə m e d ʒ a', 'b ə r t a b r a k a n', 'b ə r a g i', 'b u d ə ʔ', 'b e s u ʔ', 'b ə r k i s i', 'b ə r d u r i', 'b a ʔ h i l', 'b ə r u p a', 'b a ŋ a ŋ', 'b i r', 'b i a d i', 'b a r', 'b a d ʒ u l', 'b ə r s ə d u', 'a m u ŋ', 'b ə r t e m a k a n', 'a j u t', 'b ə r b a i t', 'b ə r i s i k a n', 'b ə n t a k a n', 'b ə r a n d ʒ a ŋ k a r j a', 'b a ŋ u n', 'b i o g r a f i', 'a g a h', 'b ə r m a', 'b a r a ŋ ɲ a', 'b a l a l a i k a', 'a n t a r w i l a j a h', 'b u k a n l a h', 'b ə r d ʒ a u h a n', 'a d i k u a s a')
#
# 32 ('b e r d a w a i', 'b e r a s i n g', 'b i s n i s', 'b a l a n s', 'b e r u r a t', 'b a n t a h a n', 'b a k s i', 'b e r t e k a p', 'b e r h a t i', 'b e r p e n c a r a n', 'b e r b i n g k a i', 'a p a r t e m e n', 'b e r d a u l a t', 'b e r d a y a', 'b e r a s u r a n s i', 'b e l i n t a n g', 'b a n g k o t a n', 'a m a l i', 'b a r a n g k a l i', 'b e r d e s a r', 'b u l a t', 'b e r p a h a t', 'b e l a', 'b i', 'a i', 'b e r d a s i', 'a b e n', 'b e r b a j a', 'b e r n i a g a', 'b e r a m b u t', 'a r e s', 'b e l a t')
# ('b ə r d a w a i', 'b ə r a s i ŋ', 'b i s n i s', 'b a l a n s', 'b ə r u r a t', 'b a n t a h a n', 'b a ʔ s i', 'b ə r t ə k a p', 'b ə r h a t i', 'b ə r p ə n t ʃ a r a n', 'b ə r b i ŋ k a i', 'a p a r t ə m e n', 'b ə r d a u l a t', 'b ə r d a j a', 'b ə r a s u r a n s i', 'b ə l i n t a ŋ', 'b a ŋ k o t a n', 'a m a l i', 'b a r a ŋ k a l i', 'b ə r d ə s a r', 'b u l a t', 'b ə r p a h a t', 'b ə l a', 'b i', 'a i', 'b ə r d a s i', 'a b e n', 'b ə r b a d ʒ a', 'b ə r n i a g a', 'b ə r a m b u t', 'a r ə s', 'b ə l a t')
#
# 32 ('b e r f o t o', 'a s a l n y a', 'a g e n s i', 'b e r l a g u', 'b e j a n a', 'b e r d e h a m', 'a t a s', 'b e d u n g a n', 'b e r h a w a', 'b e l a t u k', 'b o m b a r d e m e n', 'b a s i t', 'a l h a s i l', 'b e r h a l a n g a n', 'b e r t u k a r', 'b e r b a t u k', 'b e r t e m b u n g', 'a u t o g e n', 'a k u a k u l t u r', 'b e r k e d u t', 'a n a k k u', 'b e k l e s', 'b i a s a', 'a l k o h o l i s m e', 'a p a r a t u s', 'b e r k e s o t', 'a k a d e m i s i', 'b e r a n d a', 'b a n a t', 'b o n', 'b e c u s', 'a r u n g a n')
# ('b ə r f o t o', 'a s a l ɲ a', 'a g e n s i', 'b ə r l a g u', 'b ə d ʒ a n a', 'b ə r d ə h a m', 'a t a s', 'b ə d u ŋ a n', 'b ə r h a w a', 'b ə l a t u ʔ', 'b o m b a r d ə m e n', 'b a s i t', 'a l h a s i l', 'b ə r h a l a ŋ a n', 'b ə r t u k a r', 'b ə r b a t u ʔ', 'b ə r t ə m b u ŋ', 'a u t o g e n', 'a k u a k u l t u r', 'b ə r k ə d u t', 'a n a ʔ k u', 'b e ʔ l e s', 'b i a s a', 'a l k o h o l i s m ə', 'a p a r a t u s', 'b ə r k e s o t', 'a k a d e m i s i', 'b ə r a n d a', 'b a n a t', 'b o n', 'b ə t ʃ u s', 'a r u ŋ a n')
#
# 32 ('b e r p a d u', 'a p l i k a t i f', 'b e r m u a r a', 'b e r s e r i', 'b e l i t u n g', 'a n a l o g i', 'b e r s e m a n g a t', 'b e r k u a l i t a s', 'b e r k e l a s', 'b e r k a c a', 'a f r o d i s i a k', 'b e r d e r a p', 'b e r z i a r a h', 'a m b i v a l e n s i', 'b a i t', 'b e r g o l e k', 'b u l d o s e r', 'b o n c e n g', 'a u t a r k i', 'b e r b u s a', 'a n u t a n', 'b e r b a s u t', 'b e r d a y a - c i p t a', 'a n s a', 'b e l a n g i r', 'a m b i g u i t a s', 'b u m p e t', 'a l a m i a h', 'b e r k e b e r a t a n', 'b e r p e n t a s', 'b i g a m i', 'b e r b e l i a n')
# ('b ə r p a d u', 'a p l i k a t i f', 'b ə r m u a r a', 'b ə r s ə r i', 'b ə l i t u ŋ', 'a n a l o g i', 'b ə r s ə m a ŋ a t', 'b ə r k u a l i t a s', 'b ə r k ə l a s', 'b ə r k a t ʃ a', 'a f r o d i s i a ʔ', 'b ə r d ə r a p', 'b ə r z i a r a h', 'a m b i v a l e n s i', 'b a i t', 'b ə r g o l e ʔ', 'b u l d o s ə r', 'b o n t ʃ e ŋ', 'a u t a r k i', 'b ə r b u s a', 'a n u t a n', 'b ə r b a s u t', 'b ə r d a j a t ʃ i p t a', 'a n s a', 'b ə l a ŋ i r', 'a m b i g u i t a s', 'b u m p ə t', 'a l a m i a h', 'b ə r k ə b ə r a t a n', 'b ə r p ə n t a s', 'b i g a m i', 'b ə r b ə l i a n')
#
# 32 ('b o r o n g a n', 'b e r m e k a r a n', 'b e r d i k a r i', 'a n g l a p', 'b e r a s i m i l a s i', 'a k s i', 'a s l i n y a', 'b e r d e b a t', 'b e r l u t u t', 'a r s e n a l', 'a n t a r p r i b a d i', 'b i a r', 'b e r c a d i k', 'b e r d o k a r', 'a v o n t u r i r', 'b e r b e n t u k', 'b e r k e r u d u n g', 'b e r d a y u n g', 'b a n i r', 'a y a l', 'b e r s e n d i', 'b a l a k', 'b e r a n t a r a', 'a n t a r i k s a w a t i', 'b e r u k i r a n', 'b u d u', 'a d a d', 'b e s e t', 'a g i t a s i', 'a r a h', 'b a k a k', 'a m p u t a s i')
# ('b o r o ŋ a n', 'b ə r m ə k a r a n', 'b ə r d i k a r i', 'a ŋ l a p', 'b ə r a s i m i l a s i', 'a ʔ s i', 'a s l i ɲ a', 'b ə r d e b a t', 'b ə r l u t u t', 'a r s ə n a l', 'a n t a r p r i b a d i', 'b i a r', 'b ə r t ʃ a d i ʔ', 'b ə r d o k a r', 'a v o n t u r i r', 'b ə r b ə n t u ʔ', 'b ə r k ə r u d u ŋ', 'b ə r d a j u ŋ', 'b a n i r', 'a j a l', 'b ə r s ə n d i', 'b a l a ʔ', 'b ə r a n t a r a', 'a n t a r i ʔ s a w a t i', 'b ə r u k i r a n', 'b u d u', 'a d a d', 'b ə s e t', 'a g i t a s i', 'a r a h', 'b a k a ʔ', 'a m p u t a s i')
#
# 32 ('b i r o k r a t i s', 'b o m b a s t i s', 'b a h a n g', 'b o m', 'a l u a n', "b a '", 'b a n d a r s a h', 'b a i k l a h', 'b e n g g o l', 'a n d e r a k', 'b o g e l', 'b e r d e n g k i', 'a s i a n', 'b u d a y a w a n', 'b e r s e l', 'b e r b o y o n g', 'b a b a r', 'a w a n', 'b i d u k', 'b e l o n t a n g', 'b u m b u n g', 'b e r u m b u n', 'b e r a n g k a l', 'b e r f u n g s i', 'b e r a n g g u l', 'a p l u s a n', 'b e r d e f i l e', 'b e r u t a n g', 'a r s i t e k', 'b e r t i n d i h', 'b a r i u m', 'a l k o h o l')
# ('b i r o ʔ r a t i s', 'b o m b a s t i s', 'b a h a ŋ', 'b o m', 'a l u a n', 'b a ʔ', 'b a n d a r s a h', 'b a i ʔ l a h', 'b e ŋ g o l', 'a n d ə r a ʔ', 'b o g e l', 'b ə r d ə ŋ k i', 'a s i a n', 'b u d a j a w a n', 'b ə r s e l', 'b ə r b o j o ŋ', 'b a b a r', 'a w a n', 'b i d u ʔ', 'b ə l o n t a ŋ', 'b u m b u ŋ', 'b ə r u m b u n', 'b ə r a ŋ k a l', 'b ə r f u ŋ s i', 'b ə r a ŋ g u l', 'a p l u s a n', 'b ə r d e f i l e', 'b ə r u t a ŋ', 'a r s i t e ʔ', 'b ə r t i n d i h', 'b a r i u m', 'a l k o h o l')
#
# 32 ('b e r t a l u', 'a s i h', 'b e r a n t i s i p a s i', 'b u b u n g', 'b e r d e d a k', 'a s f a r', 'a n s a r i', 'b e l a s', 'b e l e d a n g', 'a k r i l i k', 'b e r b a h a y a', 'b e r a w a n g', 'a p r i o r i', 'b e b r e k', 'b e r t e m p i a r', 'b e r b a s i k a l', 'b e r c e l a h', 'b e r f i k i r', 'b e r k e l o c a k', 'a t l e t n y a', 'b e m b a n', 'a k o m o d a t i f', 'a g r o i n d u s t r i', 'a u m a n', 'a k t i v i t a s', 'b e r d e n g u', 'b o r o', 'b e r l e k u k', 'b e d a l', 'b e r a l a s k a n', 'b e r t i m b u n', 'b e n t o s')
# ('b ə r t a l u', 'a s i h', 'b ə r a n t i s i p a s i', 'b u b u ŋ', 'b ə r d ə d a ʔ', 'a s f a r', 'a n s a r i', 'b ə l a s', 'b ə l e d a ŋ', 'a ʔ r i l i ʔ', 'b ə r b a h a j a', 'b ə r a w a ŋ', 'a p r i o r i', 'b e b r e ʔ', 'b ə r t ə m p i a r', 'b ə r b a s i k a l', 'b ə r t ʃ ə l a h', 'b ə r f i k i r', 'b ə r k ə l o t ʃ a ʔ', 'a t l e t ɲ a', 'b ə m b a n', 'a k o m o d a t i f', 'a g r o i n d u s t r i', 'a u m a n', 'a ʔ t i v i t a s', 'b ə r d ə ŋ u', 'b o r o', 'b ə r l ə k u ʔ', 'b ə d a l', 'b ə r a l a s k a n', 'b ə r t i m b u n', 'b ə n t o s')
#
# 32 ('a k s i s', 'b u', 'a f i a t', 'b e r d e t a s', 'b e r b e l a s - k a s i h a n', 'b a r b a r', 'b a n d o', 'b a d u y u t', 'b u n a', 'b i b i r n y a', 'b o r c i', 'b e k e r d o m', 'a y u h a i', 'a k l i a h', 'b e r b a h a g i a', 'b i n g i t', 'b e r n a f k a h', 'a k u a n', 'b a d', 'b e r b i s i k a n', 'b a w e l', 'b i r a m', 'b i m b i t', 'b e r c a n d a', 'b e r b e k a s', 'b e r p a c a r a n', 'b e r b e n a k', 'b a g u r', 'b e b e n a h', 'a g a m a w a n', 'b e r t e d u h k a n', 'a k u i s i s i')
# ('a ʔ s i s', 'b u', 'a f i a t', 'b ə r d ə t a s', 'b ə r b ə l a s k a s i h a n', 'b a r b a r', 'b a n d o', 'b a d u j u t', 'b u n a', 'b i b i r ɲ a', 'b o r t ʃ i', 'b ə k ə r d o m', 'a j u h a i', 'a ʔ l i a h', 'b ə r b a h a g i a', 'b i ŋ i t', 'b ə r n a f k a h', 'a k u a n', 'b a d', 'b ə r b i s i k a n', 'b a w e l', 'b i r a m', 'b i m b i t', 'b ə r t ʃ a n d a', 'b ə r b ə k a s', 'b ə r p a t ʃ a r a n', 'b ə r b ə n a ʔ', 'b a g u r', 'b ə b ə n a h', 'a g a m a w a n', 'b ə r t ə d u h k a n', 'a k u i s i s i')
#
# 32 ('b e r g u l i n g a n', 'a r t i f a k', 'b a n t a t', 'a n d a r', 'b e r a n d a n g', 'a b e r a s i', 'a s m a r a g a m a', 'b e n k a p', 'b e r k e t r a m p i l a n', 'b e r s i s a', 'b e r h a r i', 'b i g a m i s', 'b a i k', 'b e r k e c a m u k', 'a l t e r n a t i f', 'a k t o r', 'b e r t a m b a h', 'b a d a', 'a n j u r a n', 'b a k a l', 'b o y o n g a n', 'b u g i s', 'b e r f o k u s', 'a l t e r n a t o r', 'b e r k e c u k u p a n', 'b e r m i m p i', 'b e r p r i b a d i', 'b u l i r', 'a m a l', 'a n d o n g', 'a n c a n g a n', 'b h a y a n g k a r a')
# ('b ə r g u l i ŋ a n', 'a r t i f a ʔ', 'b a n t a t', 'a n d a r', 'b ə r a n d a ŋ', 'a b ə r a s i', 'a s m a r a g a m a', 'b e n k a p', 'b ə r k ə t r a m p i l a n', 'b ə r s i s a', 'b ə r h a r i', 'b i g a m i s', 'b a i ʔ', 'b ə r k ə t ʃ a m u ʔ', 'a l t e r n a t i f', 'a ʔ t o r', 'b ə r t a m b a h', 'b a d a', 'a n d ʒ u r a n', 'b a k a l', 'b o j o ŋ a n', 'b u g i s', 'b ə r f o k u s', 'a l t ə r n a t o r', 'b ə r k ə t ʃ u k u p a n', 'b ə r m i m p i', 'b ə r p r i b a d i', 'b u l i r', 'a m a l', 'a n d o ŋ', 'a n t ʃ a ŋ a n', 'b h a j a ŋ k a r a')
#
# 32 ('a n t i h', 'a w e t', 'b e r d o g o l', 'a n a k r o n i s t i s', 'b u k a n n y a', 'a n d o k', 'a u d i t', 'b e r s e m e n', 'a n g g u h', 'b a c a r', 'b e r k e a d i l a n', 'b a g i a n', 'a n g u r', 'a k s e l e r a s i', 'b e r b e l o k', 'b e r p e l u r u', 'a k t e n t a s', 'b a s u h', 'b i n c u l', 'b e r s e l i r a t', 'a b a n g', 'a b s e n s i', 'a f a l', 'b e r t e l i n g k a h', 'a t r i b u t', 'b i r a s', 'b a n d i n g', 'b o c o r a n', 'b e r d e r a j a t', 'b r i l i a n', 'b e r s i k a p', 'b e r i n d a')
# ('a n t i h', 'a w e t', 'b ə r d o g o l', 'a n a ʔ r o n i s t i s', 'b u k a n ɲ a', 'a n d o ʔ', 'a u d i t', 'b ə r s ə m e n', 'a ŋ g u h', 'b a t ʃ a r', 'b ə r k ə a d i l a n', 'b a g i a n', 'a ŋ u r', 'a ʔ s e l ə r a s i', 'b ə r b e l o ʔ', 'b ə r p ə l u r u', 'a ʔ t ə n t a s', 'b a s u h', 'b i n t ʃ u l', 'b ə r s ə l i r a t', 'a b a ŋ', 'a b s e n s i', 'a f a l', 'b ə r t ə l i ŋ k a h', 'a t r i b u t', 'b i r a s', 'b a n d i ŋ', 'b o t ʃ o r a n', 'b ə r d ə r a d ʒ a t', 'b r i l i a n', 'b ə r s i k a p', 'b ə r i n d a')
#
# 32 ('b e l a d a u', 'a l e r g i', 'b e r t e g u r', 'a n a s i o n a l', 'b e r m a s a m', 'b a k a', 'b u l d o g', 'a e r o s k o p', 'b e r s e p a h', 'a l e r g e n', 'b e r c a k', 'a k a d e m i', 'a k t a', 'a g a', 'b i a s', 'b e s k a p', 'b u b u k', 'b e g a', 'b e r e t', 'b e r j a t u h a n', 'a b r e a k s i', 'b e n g k u', 'b a n g k i r', 'b e g a d a n g', 'b e n g k a r', 'a k i l', 'a v e r s i', 'b e r t e r i m a', 'b e r t o b a t', 'b e b a t', 'a k s e p t a s i', 'b o t o l')
# ('b ə l a d a u', 'a l e r g i', 'b ə r t ə g u r', 'a n a s i o n a l', 'b ə r m a s a m', 'b a k a', 'b u l d o g', 'a e r o s k o p', 'b ə r s e p a h', 'a l e r g e n', 'b ə r t ʃ a ʔ', 'a k a d e m i', 'a ʔ t a', 'a g a', 'b i a s', 'b ə s k a p', 'b u b u ʔ', 'b e g a', 'b ə r e t', 'b ə r d ʒ a t u h a n', 'a b r e a ʔ s i', 'b ə ŋ k u', 'b a ŋ k i r', 'b ə g a d a ŋ', 'b ə ŋ k a r', 'a k i l', 'a v e r s i', 'b ə r t ə r i m a', 'b ə r t o b a t', 'b ə b a t', 'a ʔ s e p t a s i', 'b o t o l')
#
# 32 ('a u b a d e', 'b e r g e n g s i', 'a n g k i n', 'a t a u p u n', 'a s t a k a', 'a u t o g r a f i', 'a d u a n', 'b a t u', 'b e r i l m u', 'b o g i', 'b o l a k', 'b e r k o n g s i', 'b i n i', 'a r t i s', 'b e r b e n c a h', 'b e l e d i', 'a s i l', 'b u a t a n', 'a n d a l', 'b e l u l a n g', 'a s a h a n', 'a b a r', 'b e m b a r', 'b e l u k', 'b e r k e r i p u t', 'b i o l o g i', 'b e r o d a', 'b e r t u a h', 'b a n d r e k', 'a b u s', 'b e r p a n g k a t', 'b e r l a t a r')
# ('a u b a d ə', 'b ə r g e ŋ s i', 'a ŋ k i n', 'a t a u p u n', 'a s t a k a', 'a u t o g r a f i', 'a d u a n', 'b a t u', 'b ə r i l m u', 'b o g i', 'b o l a ʔ', 'b ə r k o ŋ s i', 'b i n i', 'a r t i s', 'b ə r b ə n t ʃ a h', 'b ə l ə d i', 'a s i l', 'b u a t a n', 'a n d a l', 'b ə l u l a ŋ', 'a s a h a n', 'a b a r', 'b e m b a r', 'b ə l u ʔ', 'b ə r k ə r i p u t', 'b i o l o g i', 'b ə r o d a', 'b ə r t u a h', 'b a n d r e ʔ', 'a b u s', 'b ə r p a ŋ k a t', 'b ə r l a t a r')
#
# 12 ('b e r s a n g g u l', 'b e r b a n j a r', 'b e l a s a n', 'a t a u', 'a m r i l', 'b e s t a r i', 'a m a l g a m a s i', 'b u n d a s', 'b u n c i t', 'a s u n g', 'b o n g s o r', 'b i n g u n g')
# ('b ə r s a ŋ g u l', 'b ə r b a n d ʒ a r', 'b ə l a s a n', 'a t a u', 'a m r i l', 'b ə s t a r i', 'a m a l g a m a s i', 'b u n d a s', 'b u n t ʃ i t', 'a s u ŋ', 'b o ŋ s o r', 'b i ŋ u ŋ')

# %% [markdown]
# ## Turning training data into Tensors/Variables

# %%
def indexes_from_pair(dataset, pair) :
  """
  pair: [graphemes, phonemes]
  """

  #TODO: Add experimentation on different types of grapheme (i.e. letters, morphemes, subword, syllables, etc.)
  graphemes_indexes = [dataset.grapheme2index[grapheme] for grapheme in pair[0].split(' ')] # Letter as grapheme

  phonemes_indexes = [dataset.phoneme2index[phoneme] for phoneme in pair[1].split(' ')] # Single-charater phoneme
  return graphemes_indexes, phonemes_indexes

def variables_from_pair(dataset, pair) :
  graphemes_indexes, phonemes_indexes = indexes_from_pair(dataset, pair)
  graphemes_indexes.append(EOS_TOKEN)
  phonemes_indexes.append(EOS_TOKEN)
  graphemes_var = Variable(torch.LongTensor(graphemes_indexes).view(-1, 1))
  phonemes_var = Variable(torch.LongTensor(phonemes_indexes).view(-1, 1))

  if USE_CUDA :
    graphemes_var = graphemes_var.cuda()
    phonemes_var = phonemes_var.cuda()
  return graphemes_var, phonemes_var

print(train_g2p_dataset, train_dataloader.dataset[0])
print(variables_from_pair(train_g2p_dataset, train_dataloader.dataset[2]))
print("grp", train_g2p_dataset.index2grapheme)
print("phn", train_g2p_dataset.index2phoneme)
print(len(train_dataloader))
# Out:
# <__main__.G2PDataset object at 0x7f9e583bf8b0> ('a b a', 'a b a')
# (tensor([[2],
#         [3],
#         [4],
#         [2],
#         [5],
#         [1]], device='cuda:0'), tensor([[2],
#         [3],
#         [4],
#         [2],
#         [5],
#         [1]], device='cuda:0'))
# grp {0: '<SOS>', 1: '<EOS>', 2: 'a', 3: 'b', 4: "'", 5: 'd', 6: 'i', 7: 'h', 8: 'k', 9: 'n', 10: 'm', 11: 'u', 12: 's', 13: 'g', 14: 'y', 15: 'r', 16: 't', 17: 'o', 18: 'e', 19: 'l', 20: 'c', 21: 'j', 22: 'v', 23: 'p', 24: 'f', 25: 'w', 26: 'z', 27: '-', 28: 'q'}
# phn {0: '<SOS>', 1: '<EOS>', 2: 'a', 3: 'b', 4: 'ʔ', 5: 'd', 6: 'i', 7: 'h', 8: 'k', 9: 'n', 10: 'm', 11: 'u', 12: 's', 13: 'ŋ', 14: 'ɲ', 15: 'r', 16: 't', 17: 'o', 18: 'e', 19: 'l', 20: 'ʃ', 21: 'ə', 22: 'ʒ', 23: 'v', 24: 'p', 25: 'f', 26: 'j', 27: 'w', 28: 'g', 29: 'z'}
# 160

# %% [markdown]
# ## Model definitions

# %% [markdown]
# ### Encoder

# %%
class Encoder(nn.Module) :
  def __init__(self, input_size, hidden_size, n_layers=1) -> None :
    super(Encoder, self).__init__()

    self.input_size = input_size
    self.hidden_size = hidden_size
    self.n_layers = n_layers

    self.embedding = nn.Embedding(input_size, hidden_size)
    self.gru = nn.GRU(hidden_size, hidden_size, n_layers)

  def forward(self, word_inputs, hidden) :
    seq_len = len(word_inputs)
    embedded = self.embedding(word_inputs).view(seq_len, 1, -1)
    output, hidden = self.gru(embedded, hidden)
    return output, hidden
  
  def init_hidden(self) :
    hidden = Variable(torch.zeros(self.n_layers, 1, self.hidden_size))
    if USE_CUDA :
      hidden = hidden.cuda()
    return hidden

# %% [markdown]
# ### Attention

# %%
class Attn(nn.Module) :
  def __init__(self, method, hidden_size) -> None :
    super(Attn, self).__init__()

    self.method = method
    self.hidden_size = hidden_size

    if self.method == "general" :
      self.attn = nn.Linear(self.hidden_size, hidden_size)
    elif self.method == "concat" :
      self.attn = nn.Linear(self.hidden_size*2, hidden_size)
      self.other = nn.Parameter(torch.FloatTensor(hidden_size))
  
  def forward(self, hidden, encoder_outputs) :
    seq_len = len(encoder_outputs)

    # Create variable to store attention energies
    attn_energies = Variable(torch.zeros(seq_len)) # B x 1 x S
    if USE_CUDA :
      attn_energies = attn_energies.cuda()
    
    # Calculate energies for each encoder output
    for i in range(seq_len) :
      attn_energies[i] = self.score(hidden.squeeze(0), encoder_outputs[i].squeeze(0))
    
    # Normalize energiees to weights in range 0 to 1, resize to 1 x 1 x seq_len
    return F.softmax(attn_energies).unsqueeze(0).unsqueeze(0)

  def score(self, hidden, encoder_output) :
    # print("hidden shape", hidden.shape, hidden)
    # print("encoder_output shape", encoder_output.shape, encoder_output)
    if self.method == "dot" :
      energy = hidden.dot(encoder_output)
    elif self.method == "general" :
      energy = self.attn(encoder_output)
      energy = hidden.dot(energy)
    elif self.method == "concat" :
      hidden = hidden.unsqueeze(0)
      encoder_output = encoder_output.unsqueeze(0)
      energy = self.attn(torch.cat((hidden, encoder_output), 1))
      energy = self.other.dot(energy.squeeze(0))
    return energy

# %% [markdown]
# ### AttnDecoderRNN

# %%
class AttnDecoderRNN(nn.Module) :
  def __init__(self, attn_model, hidden_size, output_size, n_layers=1, dropout_proba=.1) -> None :
    super(AttnDecoderRNN, self).__init__()
    
    self.attn_model = attn_model
    self.hidden_size = hidden_size
    self.output_size = output_size
    self.n_layers = n_layers
    self.dropout_proba = dropout_proba

    # Define layers
    self.embedding = nn.Embedding(output_size, hidden_size)
    self.gru = nn.GRU(hidden_size*2, hidden_size, n_layers, dropout=dropout_proba)
    self.out = nn.Linear(hidden_size*2, output_size)

    # Choose attention model
    if attn_model != "none" :
      self.attn = Attn(attn_model, hidden_size)
  
  def forward(self, word_input, last_context, last_hidden, encoder_outputs) :
    # Get the embedding of the current input word (last output word)
    word_embedded = self.embedding(word_input).view(1, 1, -1) # S=1 x B x N
    
    # Combine embedded input word and last context, run through RNN
    rnn_input = torch.cat((word_embedded, last_context.unsqueeze(0)), dim=2)
    rnn_output, hidden = self.gru(rnn_input, last_hidden)

    # Calculate attention from current RNN state and all encoder outputs; apply to encoder outputs
    attn_weights = self.attn(rnn_output.squeeze(0), encoder_outputs)
    context = attn_weights.bmm(encoder_outputs.transpose(0, 1)) # B x 1 x N

    # Final output layer (next word prediction) usint the RNN hidden state and context vector
    rnn_output = rnn_output.squeeze(0)  # S=1 x B x N => B x N
    context = context.squeeze(1)        # B x S=1 x N => B x N
    output = F.log_softmax(self.out(torch.cat((rnn_output, context), dim=1)))

    # Return final output, hidden state, and attention weights (for visualization)
    return output, context, hidden, attn_weights

# %% [markdown]
# ## Testing the models

# %%
encoder_test = Encoder(10, 10, 2)
decoder_test = AttnDecoderRNN("general", 10, 10, 2)
print(encoder_test)
print(decoder_test)

encoder_hidden = encoder_test.init_hidden()
word_input = Variable(torch.LongTensor([1, 2, 3]))
if USE_CUDA :
  encoder_test.cuda()
  word_input = word_input.cuda()
encoder_outputs, encoder_hidden = encoder_test(word_input, encoder_hidden)

word_inputs = Variable(torch.LongTensor([1, 2, 3]))
decoder_attns = torch.zeros(1, 3, 3)
decoder_hidden = encoder_hidden
decoder_context = Variable(torch.zeros(1, decoder_test.hidden_size))

if USE_CUDA :
  decoder_test.cuda()
  word_inputs = word_inputs.cuda()
  decoder_context = decoder_context.cuda()

for i in range(3) :
  decoder_output, decoder_context, decoder_hidden, decoder_attn = decoder_test(word_inputs[i], decoder_context, decoder_hidden, encoder_outputs)
  print(decoder_output.size(), decoder_hidden.size(), decoder_attn.size())
  decoder_attns[0, i] = decoder_attn.squeeze(0).cpu().data
# Out:
# Encoder(
#   (embedding): Embedding(10, 10)
#   (gru): GRU(10, 10, num_layers=2)
# )
# AttnDecoderRNN(
#   (embedding): Embedding(10, 10)
#   (gru): GRU(20, 10, num_layers=2, dropout=0.1)
#   (out): Linear(in_features=20, out_features=10, bias=True)
#   (attn): Attn(
#     (attn): Linear(in_features=10, out_features=10, bias=True)
#   )
# )
# torch.Size([1, 10]) torch.Size([2, 1, 10]) torch.Size([1, 1, 3])
# torch.Size([1, 10]) torch.Size([2, 1, 10]) torch.Size([1, 1, 3])
# torch.Size([1, 10]) torch.Size([2, 1, 10]) torch.Size([1, 1, 3])
# /tmp/ipykernel_346/3262303860.py:27: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(attn_energies).unsqueeze(0).unsqueeze(0)
# /tmp/ipykernel_346/1620053795.py:35: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   output = F.log_softmax(self.out(torch.cat((rnn_output, context), dim=1)))

# %% [markdown]
# ## Helper functions

# %%
import time
import math
import matplotlib.pyplot as plt
plt.switch_backend("agg")
import matplotlib.ticker as ticker
# %matplotlib inline
import numpy as np

def as_minutes(seconds) :
  minutes = math.floor(seconds/60)
  seconds -= minutes*60
  return f"{minutes}m {seconds}s"

def time_since(since, percent) :
  now = time.time()
  seconds = now - since
  eta_seconds = seconds/(percent)
  remaining_seconds = eta_seconds - seconds
  return f"{as_minutes(seconds)} (- {as_minutes(remaining_seconds)})"

# %% [markdown]
# ## Training script

# %%
teacher_forcing_ratio = .5

def train(input_variable, target_variable, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion) :
  # Zero gradients of both optimizers
  encoder_optimizer.zero_grad()
  decoder_optimizer.zero_grad()
  loss = 0 # Added onto for each word

  # Get size of input and target sentences
  input_length = input_variable.size()[0]
  target_length = target_variable.size()[0]

  # Run words through the encoder
  encoder_hidden = encoder.init_hidden()
  encoder_outputs, encoder_hidden = encoder(input_variable, encoder_hidden)

  # Prepare input and output variables
  decoder_input = Variable(torch.LongTensor([[SOS_TOKEN]]))
  decoder_context = Variable(torch.zeros(1, decoder.hidden_size))
  decoder_hidden = encoder_hidden # Use last hidden state from encoder to start decoder
  if USE_CUDA :
    decoder_input = decoder_input.cuda()
    decoder_context = decoder_context.cuda()
  
  # Choose whether to use teacher forcing or not
  use_teacher_forcing = random.random() < teacher_forcing_ratio
  if use_teacher_forcing :
    # Teacher forcing: Use the ground-truth target as the next input
    for di in range(target_length) :
      decoder_output, decoder_context, decoder_hidden, decoder_attention = decoder(decoder_input, decoder_context, decoder_hidden, encoder_outputs)
      loss += criterion(decoder_output, target_variable[di])
      decoder_input = target_variable[di] # Next target is the next input
  else :
    # Without teacher forcing: use network's own prediction as the next input
    for di in range(target_length) :
      decoder_output, decoder_context, decoder_hidden, decoder_attention = decoder(decoder_input, decoder_context, decoder_hidden, encoder_outputs)
      loss += criterion(decoder_output, target_variable[di])

      # Get most likely word index (highest value) from output
      topv, topi = decoder_output.data.topk(1)
      ni = topi[0][0]

      decoder_input = Variable(torch.LongTensor([[ni]])) # Chosen word is next input
      if USE_CUDA :
        decoder_input = decoder_input.cuda()
      
      # Stop at the end of sentence (not necessary when using known targets)
      if ni == EOS_TOKEN :
        break
  
  # Backpropagation
  loss.backward()
  encoder_optimizer.step()
  decoder_optimizer.step()

  return loss.item()/target_length

# %% [markdown]
# ## Initialize the model

# %%
attn_model = "general"
hidden_size = 500
n_layers = 2
dropout_proba = .1

# Initialize models
encoder = Encoder(train_g2p_dataset.n_graphemes, hidden_size, n_layers)
decoder = AttnDecoderRNN(attn_model, hidden_size, train_g2p_dataset.n_phonemes, n_layers, dropout_proba=dropout_proba)

# Move models to GPU
if USE_CUDA :
  encoder.cuda()
  decoder.cuda()

# Initialize optimizers and criterion
learning_rate = .001
encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate)
criterion = nn.NLLLoss()

# %% [markdown]
# ## Training the model

# %%
# Training configurations
n_epochs = 10
plot_every = 1
print_every = 1

# Keep track of time elapsed and running averages
plot_losses = []
print_loss_total = 0 # Reset every print_every
plot_loss_total = 0 # Reset every plot_every

start = time.time()
for epoch in range(1, n_epochs+1) :
  print(f"Training for epoch {epoch} has started. Found {len(train_dataloader)} batch(es).")
  # Get all the training data batch
  for batch, (grps, phns) in enumerate(train_dataloader) :
    n_samples = len(grps)
    print(f"\tStart processing batch {batch+1} out of {len(train_dataloader)} batch(es). Found {n_samples} sample(s).")
    batch_loss = 0
    # Iterate through all samples in each batch
    for i in range(n_samples) :
      input_variable, target_variable = variables_from_pair(train_g2p_dataset, (grps[i], phns[i]))
      # Run the train function
      loss = train(input_variable, target_variable, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion)
      batch_loss += loss
    batch_loss /= n_samples
    print_loss_total += batch_loss
    plot_loss_total += batch_loss
    print(f"\tBatch {batch+1} out of {len(train_dataloader)} finished. batch loss: {batch_loss}")
  print_loss_total /= len(train_dataloader)
  plot_loss_total /= len(train_dataloader)

  if epoch%print_every == 0 :
    print_loss_avg = print_loss_total/print_every
    print_loss_total = 0
    print(f"Epoch {epoch} finished in {time_since(start, epoch/n_epochs)} ({epoch} {epoch*100/n_epochs}%) {round(print_loss_avg, 4)}")

  if epoch%plot_every == 0 :
    plot_loss_avg = plot_loss_total/plot_every
    plot_losses.append(plot_loss_avg)
    plot_loss_total = 0
# Out:
# Training for epoch 2 has started. Found 160 batch(es).
# 	Start processing batch 1 out of 160 batch(es). Found 32 sample(s).
# /tmp/ipykernel_346/3262303860.py:27: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(attn_energies).unsqueeze(0).unsqueeze(0)
# /tmp/ipykernel_346/1620053795.py:35: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   output = F.log_softmax(self.out(torch.cat((rnn_output, context), dim=1)))
# 	Batch 1 out of 160 finished. batch loss: 2.4723350263411694
# 	Start processing batch 2 out of 160 batch(es). Found 32 sample(s).
# 	Batch 2 out of 160 finished. batch loss: 2.2944891576003417
# 	Start processing batch 3 out of 160 batch(es). Found 32 sample(s).
# 	Batch 3 out of 160 finished. batch loss: 1.9405427638680746
# 	Start processing batch 4 out of 160 batch(es). Found 32 sample(s).
# 	Batch 4 out of 160 finished. batch loss: 1.9731040976780316
# 	Start processing batch 5 out of 160 batch(es). Found 32 sample(s).
# 	Batch 5 out of 160 finished. batch loss: 1.8381945989703459
# 	Start processing batch 6 out of 160 batch(es). Found 32 sample(s).
# 	Batch 6 out of 160 finished. batch loss: 1.8166968332181586
# 	Start processing batch 7 out of 160 batch(es). Found 32 sample(s).
# 	Batch 7 out of 160 finished. batch loss: 1.6349641768522507
# 	Start processing batch 8 out of 160 batch(es). Found 32 sample(s).
# 	Batch 8 out of 160 finished. batch loss: 1.7568679828707443
# 	Start processing batch 9 out of 160 batch(es). Found 32 sample(s).
# 	Batch 9 out of 160 finished. batch loss: 1.9498597367264834
# 	Start processing batch 10 out of 160 batch(es). Found 32 sample(s).

# %% [markdown]
# ## Visualize training loss

# %%
def show_plot(points) :
  plt.figure()
  fig, ax = plt.subplots()
  # This locator puts ticks at regular intervals
  loc = ticker.MultipleLocator(base=.2)
  ax.yaxis.set_major_locator(loc)
  plt.title("Training loss")
  plt.
  plt.plot(points)

show_plot(plot_losses)

# %% [markdown]
# ## Evaluate the model

# %%
def evaluate(sentence, max_length=MAX_LENGTH) :
  input_variable = variable_from_sentence(input_lang, sentence)
  input_length = input_variable.size()[0]
  print("input_length", input_length)

  # Run through encoder
  encoder_hidden = encoder.init_hidden()
  encoder_outputs, encoder_hidden = encoder(input_variable, encoder_hidden)
  print("encoder_outputs", encoder_outputs.shape)
  print("encoder_hidden", encoder_hidden.shape)

  # Create starting vectors for decoder
  decoder_input = Variable(torch.LongTensor([[SOS_TOKEN]])) # SOS
  decoder_context = Variable(torch.zeros(1, decoder.hidden_size))
  if USE_CUDA :
    decoder_input = decoder_input.cuda()
    decoder_context = decoder_context.cuda()
  
  decoder_hidden = encoder_hidden
  decoded_words = []
  decoder_attentions = torch.zeros(max_length, max_length)
  
  # Run through decoder
  for di in range(max_length) :
    decoder_output, decoder_context, decoder_hidden, decoder_attention = decoder(decoder_input, decoder_context, decoder_hidden, encoder_outputs)
    decoder_attentions[di, :decoder_attention.size(2)] += decoder_attention.squeeze(0).squeeze(0).cpu().data

    # Choose top word from output
    topv, topi = decoder_output.data.topk(1)
    ni = topi[0][0]
    if ni.item() == EOS_TOKEN :
      decoded_words.append("<EOS>")
      break
    else :
      decoded_words.append(output_lang.index2word[ni.item()])
    
    # Next input is chosen word
    decoder_input = Variable(torch.LongTensor([[ni.item()]]))
    if USE_CUDA :
      decoder_input = decoder_input.cuda()
  print(decoder_attentions[:di+1, :len(encoder_outputs)])
  return decoded_words, decoder_attentions[:di+1, :len(encoder_outputs)]

def evaluate_randomly() :
  pair = random.choice(pairs)

  output_words, decoder_attns = evaluate(pair[0])
  output_sentence = ' '.join(output_words)

  print('>', pair[0])
  print('=', pair[1])
  print('<', output_sentence)
  print('')
  return pair, output_words, decoder_attns

pair, output_words, decoder_attns = evaluate_randomly()
plt.matshow(decoder_attns.numpy())
