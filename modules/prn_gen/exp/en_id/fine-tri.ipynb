# %% [markdown]
# ## Import libraries

# %%
print(globals()["_dh"][0])
# Out:
# /mnt/d/Hakims/college/S2/tesis/id-g2p-medical-domain/modules/prn-gen/exp/en_id

# %%
import os
import random
import shutil

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn.utils.rnn import pad_sequence
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

# %%
# %pip install jiwer
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -vidia-cudnn-cu12 (/home/ahmadnaufalhakim/.local/lib/python3.8/site-packages)
# Requirement already satisfied: jiwer in /home/ahmadnaufalhakim/.local/lib/python3.8/site-packages (3.1.0)
# Requirement already satisfied: click>=8.1.8 in /home/ahmadnaufalhakim/.local/lib/python3.8/site-packages (from jiwer) (8.1.8)
# Requirement already satisfied: rapidfuzz>=3.9.7 in /home/ahmadnaufalhakim/.local/lib/python3.8/site-packages (from jiwer) (3.9.7)
# WARNING: Ignoring invalid distribution -vidia-cudnn-cu12 (/home/ahmadnaufalhakim/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -vidia-cudnn-cu12 (/home/ahmadnaufalhakim/.local/lib/python3.8/site-packages)
# Note: you may need to restart the kernel to use updated packages.

# %%
from jiwer import wer

# %% [markdown]
# ## Variables

# %%
GRP_TYPE = "trigram" # @param ["unigram", "bigram", "trigram"]
ATTN_MODEL = "dot"
EMB_DIM = "512" # @param [16, 32, 64, 128, 256, 512]
HIDDEN_SIZE = "64" # @param [64, 128, 256, 512, 1024]
N_LAYERS = "1" # @param [1, 2]
DROPOUT_PROBA = .1

# %% [markdown]
# ## Constants

# %%
# PyTorch
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
USE_CUDA = (DEVICE.type == "cuda")
print(f"Using device: {DEVICE}")
BATCH_SIZE = 64

# Data preprocessing
SOS_TOKEN = 0
EOS_TOKEN = 1
PAD_TOKEN = 2
UNK_TOKEN = 3

# Directories
CURR_DIR = globals()["_dh"][0]
DATA_SOURCE_DIR = os.path.join(CURR_DIR, "../../data/en_ma")
DATA_DIR = os.path.join(CURR_DIR, "data")
if not os.path.exists(DATA_DIR) :
  os.mkdir(DATA_DIR)
shutil.copy(os.path.join(DATA_SOURCE_DIR, "train_converted.csv"), os.path.join(DATA_DIR, "train.csv"))
shutil.copy(os.path.join(DATA_SOURCE_DIR, "val_converted.csv"), os.path.join(DATA_DIR, "val.csv"))
shutil.copy(os.path.join(DATA_SOURCE_DIR, "test_converted.csv"), os.path.join(DATA_DIR, "test.csv"))
MODELS_DIR = os.path.join(CURR_DIR, "models")
if not os.path.exists(MODELS_DIR) :
  os.mkdir(MODELS_DIR)
MODELS_DIR = os.path.join(MODELS_DIR, GRP_TYPE)
if not os.path.exists(MODELS_DIR) :
  os.mkdir(MODELS_DIR)

# Dataset preparation
PHONEME_REGEX_PATTERNS = {
  'C': [
    "((tʃ)|(dʒ)|(ŋ)|(ɲ)|(sj))",
    "((ʔ)|(b)|(d)|(f)|(g)|(h)|(k)|(l)|(m)|(n)|(p)|(r)|(s)|(t)|(v)|(w)|(j)|(z))"
  ],
  'V': [
    "((ai)|(au)|(oi)|(ei))",
    "(a|i|u|e|ə|o)"
  ]
}
COMBINED_PHONEME_REGEX_PATTERNS = '|'.join(
  pattern for patterns in PHONEME_REGEX_PATTERNS.values() for pattern in patterns
)
COMBINED_PHONEME_REGEX_PATTERNS = f"(?:{COMBINED_PHONEME_REGEX_PATTERNS})"
# Out:
# Using device: cuda

# %% [markdown]
# ## Preparing dataset

# %% [markdown]
# ### `G2PDataset` torch dataset class definition

# %%
class G2PDataset(Dataset) :
  def __init__(self, graphemes_list, phonemes_list, lang_list) -> None :
    assert len(graphemes_list) == len(phonemes_list) == len(lang_list)
    # Handle graphemes
    self.graphemes_list = graphemes_list
    self.grapheme2index = {}
    self.index2grapheme = {0: "<SOS>", 1: "<EOS>", 2:"<PAD>", 3:"<UNK>"}
    self.n_graphemes = 4
    for graphemes in graphemes_list :
      for grapheme in graphemes :
        self.add_grapheme(grapheme)
    i = 4
    for grapheme in sorted(self.grapheme2index) :
      self.grapheme2index[grapheme] = i
      self.index2grapheme[i] = grapheme
      i += 1
    # Handle phonemes
    self.phonemes_list = phonemes_list
    self.phoneme2index = {}
    self.index2phoneme = {0: "<SOS>", 1: "<EOS>", 2:"<PAD>"}
    self.n_phonemes = 3
    for phonemes in phonemes_list :
      for phoneme in phonemes :
        self.add_phoneme(phoneme)
    i = 3
    for phoneme in sorted(self.phoneme2index) :
      self.phoneme2index[phoneme] = i
      self.index2phoneme[i] = phoneme
      i += 1
    # Handle lang
    self.lang_list = lang_list

  def add_grapheme(self, grapheme) :
    if grapheme not in self.grapheme2index :
      self.grapheme2index[grapheme] = self.n_graphemes
      self.index2grapheme[self.n_graphemes] = grapheme
      self.n_graphemes += 1

  def add_phoneme(self, phoneme) :
    if phoneme not in self.phoneme2index :
      self.phoneme2index[phoneme] = self.n_phonemes
      self.index2phoneme[self.n_phonemes] = phoneme
      self.n_phonemes += 1

  def __len__(self) :
    return len(self.graphemes_list)

  def __getitem__(self, index) -> str :
    graphemes = [self.grapheme2index.get(grapheme, UNK_TOKEN) for grapheme in self.graphemes_list[index]] + [EOS_TOKEN]
    phonemes = [self.phoneme2index[phoneme] for phoneme in self.phonemes_list[index]] + [EOS_TOKEN]
    lang = self.lang_list[index]
    return graphemes, phonemes, lang

# %% [markdown]
# ### Helper functions to prepare `train/val/test` set

# %%
def extract_graphemes(grapheme_syllable_sequence:str, grp_type:str) :
  word = ''.join(grapheme_syllable_sequence.split('.'))
  # Unigram
  if grp_type == "unigram" :
    return [*word]
  # Bigram
  elif grp_type == "bigram" :
    if len(word) < 2 :
      return [word]
    return [word[i:i+2] for i in range(len(word)-1)]
  # Trigram
  elif grp_type == "trigram" :
    if len(word) < 3 :
      return [word]
    return [word[i:i+3] for i in range(len(word)-2)]

def extract_arpabet_phonemes(arpabet_phoneme_sequence:str) :
  return arpabet_phoneme_sequence.split()

# %%
def prepare_dataset(split_name:str, grp_type:str) :
  assert split_name in ["train", "val", "test"]
  assert grp_type in ["unigram", "bigram", "trigram"]
  print(f"Reading {split_name} entries ..")
  # Read the file and split into lines
  with open(os.path.join(DATA_DIR, f"{split_name}.csv"), encoding="utf-8") as f_csv :
    next(f_csv, None)
    # Split every row into pairs
    pairs = [[s.strip('\n') for s in row.split(',')] for row in f_csv]
    # Accumulate all lines into two graphemes and phonemes lists
    graphemes_list = [extract_graphemes(pair[0], grp_type) for pair in pairs] # Split grapheme as desired
    phonemes_list = [extract_arpabet_phonemes(pair[1]) for pair in pairs]
    lang_list = [pair[2] for pair in pairs]
    # Create the G2PDataset object
    g2p_dataset = G2PDataset(graphemes_list, phonemes_list, lang_list)
  return g2p_dataset, pairs

# %%
train_g2p_dataset, train_pairs = prepare_dataset("train", grp_type=GRP_TYPE)
val_g2p_dataset, val_pairs = prepare_dataset("val", grp_type=GRP_TYPE)
test_g2p_dataset, test_pairs = prepare_dataset("test", grp_type=GRP_TYPE)
pairs = train_pairs + val_pairs + test_pairs

# Equalize grapheme and phoneme mappings for val and test set
## Valid set
val_g2p_dataset.grapheme2index = train_g2p_dataset.grapheme2index
val_g2p_dataset.index2grapheme = train_g2p_dataset.index2grapheme
val_g2p_dataset.n_graphemes = train_g2p_dataset.n_graphemes
val_g2p_dataset.phoneme2index = train_g2p_dataset.phoneme2index
val_g2p_dataset.index2phoneme = train_g2p_dataset.index2phoneme
val_g2p_dataset.n_phonemes = train_g2p_dataset.n_phonemes
## Test set
test_g2p_dataset.grapheme2index = train_g2p_dataset.grapheme2index
test_g2p_dataset.index2grapheme = train_g2p_dataset.index2grapheme
test_g2p_dataset.n_graphemes = train_g2p_dataset.n_graphemes
test_g2p_dataset.phoneme2index = train_g2p_dataset.phoneme2index
test_g2p_dataset.index2phoneme = train_g2p_dataset.index2phoneme
test_g2p_dataset.n_phonemes = train_g2p_dataset.n_phonemes

# Find the maximum output sequence length among graphemes and phonemes across all datasets
MAX_LENGTH = -999
for graphemes in train_g2p_dataset.graphemes_list :
  if MAX_LENGTH < len(graphemes) :
    MAX_LENGTH = len(graphemes)
for phonemes in train_g2p_dataset.phonemes_list :
  if MAX_LENGTH < len(phonemes) :
    MAX_LENGTH = len(phonemes)
for graphemes in val_g2p_dataset.graphemes_list :
  if MAX_LENGTH < len(graphemes) :
    MAX_LENGTH = len(graphemes)
for phonemes in val_g2p_dataset.phonemes_list :
  if MAX_LENGTH < len(phonemes) :
    MAX_LENGTH = len(phonemes)
for graphemes in test_g2p_dataset.graphemes_list :
  if MAX_LENGTH < len(graphemes) :
    MAX_LENGTH = len(graphemes)
for phonemes in test_g2p_dataset.phonemes_list :
  if MAX_LENGTH < len(phonemes) :
    MAX_LENGTH = len(phonemes)

# Initialize weight loss for en and id
N = len(train_pairs)
K = 2
EN_WEIGHT = N/(K * sum(1 for pair in train_pairs if pair[2]=="en"))
ID_WEIGHT = N/(K * sum(1 for pair in train_pairs if pair[2]=="ma"))
print(f"EN_WEIGHT: {EN_WEIGHT}")
print(f"ID_WEIGHT: {ID_WEIGHT}")
# Out:
# Reading train entries ..
# Reading val entries ..
# Reading test entries ..
# EN_WEIGHT: 0.6138648959009436
# ID_WEIGHT: 2.6955844953082524

# %%
torch.save(train_g2p_dataset.index2grapheme, os.path.join(MODELS_DIR, "id2grp.pth"))
torch.save(train_g2p_dataset.index2phoneme, os.path.join(MODELS_DIR, "id2phn.pth"))

# Custom Collate function (for padding)
def collate_fn(batch) :
  # batch: [(input_seq, target_seq, lang), ...]
  graphemes, phonemes, langs = zip(*batch)
  # Pad sequences
  graphemes_padded = pad_sequence([torch.tensor(x) for x in graphemes], padding_value=PAD_TOKEN)
  phonemes_padded = pad_sequence([torch.tensor(y) for y in phonemes], padding_value=PAD_TOKEN)
  return graphemes_padded, phonemes_padded, langs

train_dataloader = DataLoader(train_g2p_dataset, batch_size=BATCH_SIZE, collate_fn=collate_fn, shuffle=True)
valid_dataloader = DataLoader(val_g2p_dataset, batch_size=BATCH_SIZE, collate_fn=collate_fn, shuffle=False)
test_dataloader = DataLoader(test_g2p_dataset, batch_size=BATCH_SIZE, collate_fn=collate_fn, shuffle=False)

# %% [markdown]
# ## Turning grapheme and phoneme data to Tensors/Variables

# %%
def indexes_from_word(dataset, word, grp_type) :
  assert grp_type in ["unigram", "bigram", "trigram"]
  if grp_type == "unigram" :
    graphemes = [*word]
  elif grp_type == "bigram" :
    graphemes = [word[i:i+2] for i in range(len(word)-1)] if len(word)>=2 else [word]
  elif grp_type == "trigram" :
    graphemes = [word[i:i+3] for i in range(len(word)-2)] if len(word)>=3 else [word]
  return [dataset.grapheme2index.get(grapheme, UNK_TOKEN) for grapheme in graphemes] + [EOS_TOKEN]

def variable_from_word(dataset, word, grp_type) :
  indexes = indexes_from_word(dataset, word, grp_type)
  var = torch.LongTensor(indexes).view(-1, 1)
  if USE_CUDA :
    var = var.cuda()
  return var

### BOTH NOT USED until further observation
def indexes_from_pair(dataset, pair) :
  """
  pair: [graphemes, phonemes]
  """
  graphemes_indexes = [dataset.grapheme2index.get(grapheme, UNK_TOKEN) for grapheme in pair[0].split()] + [EOS_TOKEN]
  phonemes_indexes = [dataset.phoneme2index[phoneme] for phoneme in pair[1].split()] + [EOS_TOKEN]
  return graphemes_indexes, phonemes_indexes

def variables_from_pair(dataset, pair) :
  graphemes_indexes, phonemes_indexes = indexes_from_pair(dataset, pair)
  graphemes_var = torch.LongTensor(graphemes_indexes).view(-1, 1)
  phonemes_var = torch.LongTensor(phonemes_indexes).view(-1, 1)
  if USE_CUDA :
    graphemes_var = graphemes_var.cuda()
    phonemes_var = phonemes_var.cuda()
  return graphemes_var, phonemes_var

# %%
print(indexes_from_word(train_g2p_dataset, "menguncinya", grp_type=GRP_TYPE))
# print(variable_from_word(train_g2p_dataset, "menguncinya", grp_type=GRP_TYPE))
# Out:
# [4609, 2019, 4984, 2788, 7632, 4884, 1195, 3444, 5218, 1]

# %%
print(train_g2p_dataset, train_dataloader.dataset[0])
print(train_g2p_dataset[0])
print(train_dataloader.dataset[0])
print("train grp", len(train_g2p_dataset.index2grapheme), train_g2p_dataset.index2grapheme)
print("valid grp", len(val_g2p_dataset.index2grapheme), val_g2p_dataset.index2grapheme)
print("test grp", len(test_g2p_dataset.index2grapheme), test_g2p_dataset.index2grapheme)
print("train phn", len(train_g2p_dataset.index2phoneme), train_g2p_dataset.index2phoneme)
print("valid phn", len(val_g2p_dataset.index2phoneme), val_g2p_dataset.index2phoneme)
print("test phn", len(test_g2p_dataset.index2phoneme), test_g2p_dataset.index2phoneme)
print(len(train_g2p_dataset.grapheme2index), train_g2p_dataset.grapheme2index)
print(len(val_g2p_dataset.grapheme2index), val_g2p_dataset.grapheme2index)
print(len(test_g2p_dataset.grapheme2index), test_g2p_dataset.grapheme2index)
print(len(train_g2p_dataset.phoneme2index), train_g2p_dataset.phoneme2index)
print(len(val_g2p_dataset.phoneme2index), val_g2p_dataset.phoneme2index)
print(len(test_g2p_dataset.phoneme2index), test_g2p_dataset.phoneme2index)
# Out:
# <__main__.G2PDataset object at 0x7fc948b80880> ([19, 1093, 691, 7732, 1], [18, 6, 35, 1], 'en')
# ([19, 1093, 691, 7732, 1], [18, 6, 35, 1], 'en')
# ([19, 1093, 691, 7732, 1], [18, 6, 35, 1], 'en')
# train grp 8960 {0: '<SOS>', 1: '<EOS>', 2: '<PAD>', 3: '<UNK>', 4: "'af", 5: "'ag", 6: "'ah", 7: "'al", 8: "'am", 9: "'an", 10: "'aq", 11: "'ar", 12: "'at", 13: "'au", 14: "'av", 15: "'ay", 16: "'ba", 17: "'be", 18: "'br", 19: "'ca", 20: "'cl", 21: "'co", 22: "'da", 23: "'de", 24: "'dj", 25: "'do", 26: "'du", 27: "'dw", 28: "'eg", 29: "'el", 30: "'em", 31: "'en", 32: "'er", 33: "'es", 34: "'et", 35: "'ex", 36: "'gl", 37: "'go", 38: "'gr", 39: "'ha", 40: "'hu", 41: "'is", 42: "'iv", 43: "'ji", 44: "'ke", 45: "'le", 46: "'ll", 47: "'m", 48: "'ma", 49: "'me", 50: "'n", 51: "'na", 52: "'ne", 53: "'oe", 54: "'on", 55: "'or", 56: "'qu", 57: "'re", 58: "'ri", 59: "'ro", 60: "'sh", 61: "'sm", 62: "'so", 63: "'ti", 64: "'to", 65: "'ts", 66: "'un", 67: "'ve", 68: '--i', 69: '--n', 70: '-a-', 71: '-ab', 72: '-ac', 73: '-ad', 74: '-ak', 75: '-al', 76: '-an', 77: '-ap', 78: '-ar', 79: '-as', 80: '-au', 81: '-aw', 82: '-ba', 83: '-be', 84: '-bi', 85: '-bl', 86: '-bo', 87: '-br', 88: '-by', 89: '-ca', 90: '-ce', 91: '-ch', 92: '-ci', 93: '-cl', 94: '-co', 95: '-cu', 96: '-da', 97: '-de', 98: '-di', 99: '-do', 100: '-dr', 101: '-du', 102: '-ea', 103: '-ed', 104: '-ef', 105: '-ei', 106: '-el', 107: '-em', 108: '-en', 109: '-er', 110: '-fa', 111: '-fe', 112: '-fi', 113: '-fo', 114: '-fr', 115: '-fu', 116: '-ga', 117: '-ge', 118: '-gi', 119: '-go', 120: '-gr', 121: '-gu', 122: '-ha', 123: '-he', 124: '-hi', 125: '-ho', 126: '-hu', 127: '-in', 128: '-is', 129: '-it', 130: '-ja', 131: '-je', 132: '-ka', 133: '-ki', 134: '-kn', 135: '-ku', 136: '-la', 137: '-le', 138: '-li', 139: '-lo', 140: '-lu', 141: '-ma', 142: '-me', 143: '-mi', 144: '-mo', 145: '-ne', 146: '-ni', 147: '-nu', 148: '-ny', 149: '-of', 150: '-ol', 151: '-on', 152: '-op', 153: '-or', 154: '-ou', 155: '-ow', 156: '-pa', 157: '-pe', 158: '-pl', 159: '-po', 160: '-pr', 161: '-qu', 162: '-ra', 163: '-re', 164: '-ri', 165: '-ro', 166: '-ru', 167: '-sa', 168: '-sc', 169: '-se', 170: '-sh', 171: '-si', 172: '-sp', 173: '-st', 174: '-su', 175: '-ta', 176: '-te', 177: '-th', 178: '-ti', 179: '-to', 180: '-tu', 181: '-tw', 182: '-ub', 183: '-un', 184: '-up', 185: '-ur', 186: '-vi', 187: '-wa', 188: '-wh', 189: '-wi', 190: '-wo', 191: '-wr', 192: '-ye', 193: '-yo', 194: "a'a", 195: "a'b", 196: "a'd", 197: "a'e", 198: "a'h", 199: "a'i", 200: "a'l", 201: "a'n", 202: "a'r", 203: "a's", 204: "a'u", 205: "a'v", 206: 'a-a', 207: 'a-c', 208: 'a-g', 209: 'a-j', 210: 'a-k', 211: 'a-m', 212: 'a-n', 213: 'a-p', 214: 'a-r', 215: 'a-u', 216: 'aab', 217: 'aac', 218: 'aad', 219: 'aaf', 220: 'aag', 221: 'aah', 222: 'aai', 223: 'aak', 224: 'aal', 225: 'aam', 226: 'aan', 227: 'aap', 228: 'aaq', 229: 'aar', 230: 'aas', 231: 'aat', 232: 'aav', 233: 'aay', 234: 'ab', 235: "ab'", 236: 'aba', 237: 'abb', 238: 'abc', 239: 'abd', 240: 'abe', 241: 'abh', 242: 'abi', 243: 'abj', 244: 'abk', 245: 'abl', 246: 'abm', 247: 'abn', 248: 'abo', 249: 'abp', 250: 'abr', 251: 'abs', 252: 'abt', 253: 'abu', 254: 'abw', 255: 'aby', 256: "ac'", 257: 'aca', 258: 'acb', 259: 'acc', 260: 'acd', 261: 'ace', 262: 'acf', 263: 'acg', 264: 'ach', 265: 'aci', 266: 'ack', 267: 'acl', 268: 'acm', 269: 'acn', 270: 'aco', 271: 'acp', 272: 'acq', 273: 'acr', 274: 'acs', 275: 'act', 276: 'acu', 277: 'acv', 278: 'acw', 279: 'acy', 280: 'acz', 281: 'ad', 282: "ad'", 283: 'ad-', 284: 'ada', 285: 'adb', 286: 'adc', 287: 'add', 288: 'ade', 289: 'adf', 290: 'adg', 291: 'adh', 292: 'adi', 293: 'adj', 294: 'adk', 295: 'adl', 296: 'adm', 297: 'adn', 298: 'ado', 299: 'adp', 300: 'adq', 301: 'adr', 302: 'ads', 303: 'adt', 304: 'adu', 305: 'adv', 306: 'adw', 307: 'ady', 308: 'adz', 309: 'ae', 310: "ae'", 311: 'aea', 312: 'aeb', 313: 'aec', 314: 'aed', 315: 'aee', 316: 'aef', 317: 'aeg', 318: 'aeh', 319: 'aek', 320: 'ael', 321: 'aem', 322: 'aen', 323: 'aeo', 324: 'aer', 325: 'aes', 326: 'aet', 327: 'aeu', 328: 'aev', 329: 'aez', 330: 'afa', 331: 'afc', 332: 'afd', 333: 'afe', 334: 'aff', 335: 'afg', 336: 'afh', 337: 'afi', 338: 'afk', 339: 'afl', 340: 'afm', ...
# valid grp 8960 {0: '<SOS>', 1: '<EOS>', 2: '<PAD>', 3: '<UNK>', 4: "'af", 5: "'ag", 6: "'ah", 7: "'al", 8: "'am", 9: "'an", 10: "'aq", 11: "'ar", 12: "'at", 13: "'au", 14: "'av", 15: "'ay", 16: "'ba", 17: "'be", 18: "'br", 19: "'ca", 20: "'cl", 21: "'co", 22: "'da", 23: "'de", 24: "'dj", 25: "'do", 26: "'du", 27: "'dw", 28: "'eg", 29: "'el", 30: "'em", 31: "'en", 32: "'er", 33: "'es", 34: "'et", 35: "'ex", 36: "'gl", 37: "'go", 38: "'gr", 39: "'ha", 40: "'hu", 41: "'is", 42: "'iv", 43: "'ji", 44: "'ke", 45: "'le", 46: "'ll", 47: "'m", 48: "'ma", 49: "'me", 50: "'n", 51: "'na", 52: "'ne", 53: "'oe", 54: "'on", 55: "'or", 56: "'qu", 57: "'re", 58: "'ri", 59: "'ro", 60: "'sh", 61: "'sm", 62: "'so", 63: "'ti", 64: "'to", 65: "'ts", 66: "'un", 67: "'ve", 68: '--i', 69: '--n', 70: '-a-', 71: '-ab', 72: '-ac', 73: '-ad', 74: '-ak', 75: '-al', 76: '-an', 77: '-ap', 78: '-ar', 79: '-as', 80: '-au', 81: '-aw', 82: '-ba', 83: '-be', 84: '-bi', 85: '-bl', 86: '-bo', 87: '-br', 88: '-by', 89: '-ca', 90: '-ce', 91: '-ch', 92: '-ci', 93: '-cl', 94: '-co', 95: '-cu', 96: '-da', 97: '-de', 98: '-di', 99: '-do', 100: '-dr', 101: '-du', 102: '-ea', 103: '-ed', 104: '-ef', 105: '-ei', 106: '-el', 107: '-em', 108: '-en', 109: '-er', 110: '-fa', 111: '-fe', 112: '-fi', 113: '-fo', 114: '-fr', 115: '-fu', 116: '-ga', 117: '-ge', 118: '-gi', 119: '-go', 120: '-gr', 121: '-gu', 122: '-ha', 123: '-he', 124: '-hi', 125: '-ho', 126: '-hu', 127: '-in', 128: '-is', 129: '-it', 130: '-ja', 131: '-je', 132: '-ka', 133: '-ki', 134: '-kn', 135: '-ku', 136: '-la', 137: '-le', 138: '-li', 139: '-lo', 140: '-lu', 141: '-ma', 142: '-me', 143: '-mi', 144: '-mo', 145: '-ne', 146: '-ni', 147: '-nu', 148: '-ny', 149: '-of', 150: '-ol', 151: '-on', 152: '-op', 153: '-or', 154: '-ou', 155: '-ow', 156: '-pa', 157: '-pe', 158: '-pl', 159: '-po', 160: '-pr', 161: '-qu', 162: '-ra', 163: '-re', 164: '-ri', 165: '-ro', 166: '-ru', 167: '-sa', 168: '-sc', 169: '-se', 170: '-sh', 171: '-si', 172: '-sp', 173: '-st', 174: '-su', 175: '-ta', 176: '-te', 177: '-th', 178: '-ti', 179: '-to', 180: '-tu', 181: '-tw', 182: '-ub', 183: '-un', 184: '-up', 185: '-ur', 186: '-vi', 187: '-wa', 188: '-wh', 189: '-wi', 190: '-wo', 191: '-wr', 192: '-ye', 193: '-yo', 194: "a'a", 195: "a'b", 196: "a'd", 197: "a'e", 198: "a'h", 199: "a'i", 200: "a'l", 201: "a'n", 202: "a'r", 203: "a's", 204: "a'u", 205: "a'v", 206: 'a-a', 207: 'a-c', 208: 'a-g', 209: 'a-j', 210: 'a-k', 211: 'a-m', 212: 'a-n', 213: 'a-p', 214: 'a-r', 215: 'a-u', 216: 'aab', 217: 'aac', 218: 'aad', 219: 'aaf', 220: 'aag', 221: 'aah', 222: 'aai', 223: 'aak', 224: 'aal', 225: 'aam', 226: 'aan', 227: 'aap', 228: 'aaq', 229: 'aar', 230: 'aas', 231: 'aat', 232: 'aav', 233: 'aay', 234: 'ab', 235: "ab'", 236: 'aba', 237: 'abb', 238: 'abc', 239: 'abd', 240: 'abe', 241: 'abh', 242: 'abi', 243: 'abj', 244: 'abk', 245: 'abl', 246: 'abm', 247: 'abn', 248: 'abo', 249: 'abp', 250: 'abr', 251: 'abs', 252: 'abt', 253: 'abu', 254: 'abw', 255: 'aby', 256: "ac'", 257: 'aca', 258: 'acb', 259: 'acc', 260: 'acd', 261: 'ace', 262: 'acf', 263: 'acg', 264: 'ach', 265: 'aci', 266: 'ack', 267: 'acl', 268: 'acm', 269: 'acn', 270: 'aco', 271: 'acp', 272: 'acq', 273: 'acr', 274: 'acs', 275: 'act', 276: 'acu', 277: 'acv', 278: 'acw', 279: 'acy', 280: 'acz', 281: 'ad', 282: "ad'", 283: 'ad-', 284: 'ada', 285: 'adb', 286: 'adc', 287: 'add', 288: 'ade', 289: 'adf', 290: 'adg', 291: 'adh', 292: 'adi', 293: 'adj', 294: 'adk', 295: 'adl', 296: 'adm', 297: 'adn', 298: 'ado', 299: 'adp', 300: 'adq', 301: 'adr', 302: 'ads', 303: 'adt', 304: 'adu', 305: 'adv', 306: 'adw', 307: 'ady', 308: 'adz', 309: 'ae', 310: "ae'", 311: 'aea', 312: 'aeb', 313: 'aec', 314: 'aed', 315: 'aee', 316: 'aef', 317: 'aeg', 318: 'aeh', 319: 'aek', 320: 'ael', 321: 'aem', 322: 'aen', 323: 'aeo', 324: 'aer', 325: 'aes', 326: 'aet', 327: 'aeu', 328: 'aev', 329: 'aez', 330: 'afa', 331: 'afc', 332: 'afd', 333: 'afe', 334: 'aff', 335: 'afg', 336: 'afh', 337: 'afi', 338: 'afk', 339: 'afl', 340: 'afm', ...
# test grp 8960 {0: '<SOS>', 1: '<EOS>', 2: '<PAD>', 3: '<UNK>', 4: "'af", 5: "'ag", 6: "'ah", 7: "'al", 8: "'am", 9: "'an", 10: "'aq", 11: "'ar", 12: "'at", 13: "'au", 14: "'av", 15: "'ay", 16: "'ba", 17: "'be", 18: "'br", 19: "'ca", 20: "'cl", 21: "'co", 22: "'da", 23: "'de", 24: "'dj", 25: "'do", 26: "'du", 27: "'dw", 28: "'eg", 29: "'el", 30: "'em", 31: "'en", 32: "'er", 33: "'es", 34: "'et", 35: "'ex", 36: "'gl", 37: "'go", 38: "'gr", 39: "'ha", 40: "'hu", 41: "'is", 42: "'iv", 43: "'ji", 44: "'ke", 45: "'le", 46: "'ll", 47: "'m", 48: "'ma", 49: "'me", 50: "'n", 51: "'na", 52: "'ne", 53: "'oe", 54: "'on", 55: "'or", 56: "'qu", 57: "'re", 58: "'ri", 59: "'ro", 60: "'sh", 61: "'sm", 62: "'so", 63: "'ti", 64: "'to", 65: "'ts", 66: "'un", 67: "'ve", 68: '--i', 69: '--n', 70: '-a-', 71: '-ab', 72: '-ac', 73: '-ad', 74: '-ak', 75: '-al', 76: '-an', 77: '-ap', 78: '-ar', 79: '-as', 80: '-au', 81: '-aw', 82: '-ba', 83: '-be', 84: '-bi', 85: '-bl', 86: '-bo', 87: '-br', 88: '-by', 89: '-ca', 90: '-ce', 91: '-ch', 92: '-ci', 93: '-cl', 94: '-co', 95: '-cu', 96: '-da', 97: '-de', 98: '-di', 99: '-do', 100: '-dr', 101: '-du', 102: '-ea', 103: '-ed', 104: '-ef', 105: '-ei', 106: '-el', 107: '-em', 108: '-en', 109: '-er', 110: '-fa', 111: '-fe', 112: '-fi', 113: '-fo', 114: '-fr', 115: '-fu', 116: '-ga', 117: '-ge', 118: '-gi', 119: '-go', 120: '-gr', 121: '-gu', 122: '-ha', 123: '-he', 124: '-hi', 125: '-ho', 126: '-hu', 127: '-in', 128: '-is', 129: '-it', 130: '-ja', 131: '-je', 132: '-ka', 133: '-ki', 134: '-kn', 135: '-ku', 136: '-la', 137: '-le', 138: '-li', 139: '-lo', 140: '-lu', 141: '-ma', 142: '-me', 143: '-mi', 144: '-mo', 145: '-ne', 146: '-ni', 147: '-nu', 148: '-ny', 149: '-of', 150: '-ol', 151: '-on', 152: '-op', 153: '-or', 154: '-ou', 155: '-ow', 156: '-pa', 157: '-pe', 158: '-pl', 159: '-po', 160: '-pr', 161: '-qu', 162: '-ra', 163: '-re', 164: '-ri', 165: '-ro', 166: '-ru', 167: '-sa', 168: '-sc', 169: '-se', 170: '-sh', 171: '-si', 172: '-sp', 173: '-st', 174: '-su', 175: '-ta', 176: '-te', 177: '-th', 178: '-ti', 179: '-to', 180: '-tu', 181: '-tw', 182: '-ub', 183: '-un', 184: '-up', 185: '-ur', 186: '-vi', 187: '-wa', 188: '-wh', 189: '-wi', 190: '-wo', 191: '-wr', 192: '-ye', 193: '-yo', 194: "a'a", 195: "a'b", 196: "a'd", 197: "a'e", 198: "a'h", 199: "a'i", 200: "a'l", 201: "a'n", 202: "a'r", 203: "a's", 204: "a'u", 205: "a'v", 206: 'a-a', 207: 'a-c', 208: 'a-g', 209: 'a-j', 210: 'a-k', 211: 'a-m', 212: 'a-n', 213: 'a-p', 214: 'a-r', 215: 'a-u', 216: 'aab', 217: 'aac', 218: 'aad', 219: 'aaf', 220: 'aag', 221: 'aah', 222: 'aai', 223: 'aak', 224: 'aal', 225: 'aam', 226: 'aan', 227: 'aap', 228: 'aaq', 229: 'aar', 230: 'aas', 231: 'aat', 232: 'aav', 233: 'aay', 234: 'ab', 235: "ab'", 236: 'aba', 237: 'abb', 238: 'abc', 239: 'abd', 240: 'abe', 241: 'abh', 242: 'abi', 243: 'abj', 244: 'abk', 245: 'abl', 246: 'abm', 247: 'abn', 248: 'abo', 249: 'abp', 250: 'abr', 251: 'abs', 252: 'abt', 253: 'abu', 254: 'abw', 255: 'aby', 256: "ac'", 257: 'aca', 258: 'acb', 259: 'acc', 260: 'acd', 261: 'ace', 262: 'acf', 263: 'acg', 264: 'ach', 265: 'aci', 266: 'ack', 267: 'acl', 268: 'acm', 269: 'acn', 270: 'aco', 271: 'acp', 272: 'acq', 273: 'acr', 274: 'acs', 275: 'act', 276: 'acu', 277: 'acv', 278: 'acw', 279: 'acy', 280: 'acz', 281: 'ad', 282: "ad'", 283: 'ad-', 284: 'ada', 285: 'adb', 286: 'adc', 287: 'add', 288: 'ade', 289: 'adf', 290: 'adg', 291: 'adh', 292: 'adi', 293: 'adj', 294: 'adk', 295: 'adl', 296: 'adm', 297: 'adn', 298: 'ado', 299: 'adp', 300: 'adq', 301: 'adr', 302: 'ads', 303: 'adt', 304: 'adu', 305: 'adv', 306: 'adw', 307: 'ady', 308: 'adz', 309: 'ae', 310: "ae'", 311: 'aea', 312: 'aeb', 313: 'aec', 314: 'aed', 315: 'aee', 316: 'aef', 317: 'aeg', 318: 'aeh', 319: 'aek', 320: 'ael', 321: 'aem', 322: 'aen', 323: 'aeo', 324: 'aer', 325: 'aes', 326: 'aet', 327: 'aeu', 328: 'aev', 329: 'aez', 330: 'afa', 331: 'afc', 332: 'afd', 333: 'afe', 334: 'aff', 335: 'afg', 336: 'afh', 337: 'afi', 338: 'afk', 339: 'afl', 340: 'afm',  ...
# train phn 36 {0: '<SOS>', 1: '<EOS>', 2: '<PAD>', 3: 'AA', 4: 'AO', 5: 'AW', 6: 'AX', 7: 'AY', 8: 'B', 9: 'CH', 10: 'D', 11: 'EH', 12: 'EY', 13: 'F', 14: 'G', 15: 'HH', 16: 'IY', 17: 'JH', 18: 'K', 19: 'L', 20: 'M', 21: 'N', 22: 'NG', 23: 'NY', 24: 'OY', 25: 'P', 26: 'Q', 27: 'R', 28: 'S', 29: 'SH', 30: 'T', 31: 'UW', 32: 'V', 33: 'W', 34: 'Y', 35: 'Z'}
# valid phn 36 {0: '<SOS>', 1: '<EOS>', 2: '<PAD>', 3: 'AA', 4: 'AO', 5: 'AW', 6: 'AX', 7: 'AY', 8: 'B', 9: 'CH', 10: 'D', 11: 'EH', 12: 'EY', 13: 'F', 14: 'G', 15: 'HH', 16: 'IY', 17: 'JH', 18: 'K', 19: 'L', 20: 'M', 21: 'N', 22: 'NG', 23: 'NY', 24: 'OY', 25: 'P', 26: 'Q', 27: 'R', 28: 'S', 29: 'SH', 30: 'T', 31: 'UW', 32: 'V', 33: 'W', 34: 'Y', 35: 'Z'}
# test phn 36 {0: '<SOS>', 1: '<EOS>', 2: '<PAD>', 3: 'AA', 4: 'AO', 5: 'AW', 6: 'AX', 7: 'AY', 8: 'B', 9: 'CH', 10: 'D', 11: 'EH', 12: 'EY', 13: 'F', 14: 'G', 15: 'HH', 16: 'IY', 17: 'JH', 18: 'K', 19: 'L', 20: 'M', 21: 'N', 22: 'NG', 23: 'NY', 24: 'OY', 25: 'P', 26: 'Q', 27: 'R', 28: 'S', 29: 'SH', 30: 'T', 31: 'UW', 32: 'V', 33: 'W', 34: 'Y', 35: 'Z'}
# 8956 {"'ca": 19, 'cau': 1093, 'aus': 691, 'use': 7732, "'co": 21, 'cou': 1270, 'our': 5731, 'urs': 7720, 'rse': 6493, "'em": 30, "'m": 47, "'n": 50, "'qu": 56, 'quo': 6136, 'uot': 7668, 'ote': 5696, "'ti": 63, 'tis': 7138, '--n': 69, '-ny': 148, 'nya': 5218, '-an': 76, 'and': 520, 'nda': 4897, '-be': 83, 'bel': 869, 'ela': 1959, 'las': 4131, '-co': 94, 'com': 1263, 'omp': 5548, 'mpe': 4727, 'pen': 5905, 'eng': 2019, '-de': 97, 'del': 1466, 'lap': 4128, 'apa': 559, 'pan': 5859, '-ka': 132, 'kan': 3842, '-ku': 135, '-le': 137, 'len': 4199, 'ngg': 4970, 'gga': 2609, 'gan': 2549, 'ang': 523, '-ma': 141, 'mah': 4528, 'aha': 376, 'has': 2854, 'asi': 627, 'sis': 6765, 'isw': 3547, 'swa': 6938, '-se': 169, 'sep': 6700, 'epi': 2071, 'pit': 5961, '-ta': 175, 'tak': 7015, '-wa': 187, 'wan': 8028, 'wat': 8032, 'ati': 655, "a'd": 196, "'du": 26, "a'h": 198, "'ha": 39, 'had': 2839, 'aab': 216, 'abe': 240, 'ber': 875, 'erg': 2093, 'aac': 217, 'ach': 264, 'che': 1163, 'hen': 2898, 'aak': 223, 'ake': 442, 'ker': 3889, 'aal': 224, 'als': 482, 'lse': 4393, 'set': 6704, 'eth': 2148, 'aam': 225, 'amo': 504, 'mod': 4699, 'odt': 5363, 'aan': 226, 'anc': 519, 'nco': 4888, 'cor': 1267, 'aar': 229, 'ard': 593, 'rde': 6220, 'dem': 1467, 'ema': 1987, 'rdv': 6236, 'dva': 1672, 'var': 7856, 'ark': 600, 'aro': 604, 'ron': 6444, "on'": 5558, "n's": 4828, 'ons': 5578, 'nso': 5138, 'son': 6830, 'art': 609, 'rti': 6522, 'aas': 230, 'ase': 623, 'ab': 234, 'aba': 236, 'bab': 809, 'bac': 810, 'cha': 1159, 'ack': 266, 'aco': 270, 'acu': 276, 'cus': 1332, 'bad': 811, 'ada': 284, 'dak': 1407, 'aka': 438, 'adi': 292, 'dia': 1513, 'iah': 3172, 'dik': 1523, 'ika': 3352, 'bah': 815, 'bai': 816, 'aia': 398, 'ian': 3178, 'aik': 408, 'aim': 410, 'ima': 3398, 'man': 4534, 'ana': 517, 'air': 414, 'bal': 819, 'alk': 475, 'lki': 4280, 'kin': 3932, 'alo': 479, 'lon': 4357, 'one': 5564, 'los': 4362, 'ban': 821, 'ndo': 4911, 'don': 1583, 'oni': 5568, 'nin': 5010, 'ing': 3426, 'onm': 5572, 'nme': 5061, 'men': 4609, 'ent': 2032, 'nts': 5167, 'nga': 4964, 'ngn': 4977, 'gny': 2702, 'ant': 536, 'nto': 5164, 'bar': 824, 'ara': 590, 'ran': 6173, 'arc': 592, 'rca': 6198, 'are': 594, 'bas': 825, 'asc': 621, 'sca': 6665, 'cal': 1084, 'ash': 626, 'she': 6730, 'hed': 2888, 'bat': 826, 'ate': 651, 'ted': 7059, 'tem': 7068, 'eme': 1991, 'tes': 7074, 'tin': 7133, 'ato': 661, 'toa': 7179, 'oar': 5298, 'bau': 827, 'abb': 237, 'bba': 834, 'tie': 7124, 'iel': 3261, 'ell': 1970, 'llo': 4306, 'bbe': 835, 'ben': 871, 'enh': 2020, 'nha': 4991, 'hau': 2856, 'bet': 877, 'ett': 2159, 'bev': 879, 'evi': 2193, 'vil': 7912, 'ill': 3383, 'lle': 4297, 'bey': 882, "ey'": 2251, "y's": 8428, 'bbi': 836, 'bie': 901, 'bit': 916, 'itt': 3570, 'bbo': 838, 'bot': 970, 'ott': 5709, "tt'": 7241, "t's": 6984, 'bou': 971, 'oud': 5719, 'bbr': 839, 'bre': 983, 'rev': 6264, 'via': 7904, 'iat': 3183, 'tio': 7134, 'ion': 3461, 'bbs': 840, 'bby': 842, 'abc': 238, 'bco': 846, 'cot': 1269, 'tek': 7066, 'abd': 239, 'bda': 849, 'dal': 1408, 'all': 476, 'lla': 4293, 'lah': 4120, 'das': 1415, 'bde': 850, 'bdi': 851, 'dic': 1515, 'ica': 3209, 'cat': 1092, 'kas': 3846, 'bdn': 852, 'dno': 1566, 'nor': 5100, 'bdo': 853, 'dol': 1581, 'oll': 5519, 'dom': 1582, 'ome': 5538, 'omi': 5542, 'min': 4653, 'ina': 3420, 'nal': 4857, 'bdu': 855, 'duc': 1649, 'uct': 7417, 'cte': 1304, 'tee': 7060, 'ees': 1840, 'cti': 1307, 'cto': 1311, 'tor': 7195, 'ors': 5654, 'cts': 1313, 'dul': 1658, 'ula': 7577, 'laz': 4138, 'azi': 790, 'ziz': 8854, 'ull': 7587, 'lar': 4130, 'ele': 1963, 'les': 4204, 'eln': 1972, 'elo': 1973, 'low': 4366, 'els': 1977, 'lso': 4402, 'end': 2016, 'ndr': 4914, 'dro': 1609, 'rot': 6450, 'oth': 5699, 'era': 2087, 'ras': 6178, 'erc': 2089, 'rcr': 6209, 'cro': 1287, 'rom': 6443, 'omb': 5535, 'mbi': 4553, 'erd': 2090, 'dee': 1459, 'een': 1837, 'erl': 2098, 'rle': 6371, 'erm': 2099, 'rmi': 6393, 'err': 2104, 'rra': 6475, 'rat': 6179, 'ona': 5560, 'ert': 2106, 'tte': 7245, 'tti': 7249, 'eya': 2252, 'yan': 8458, 'nce': 4882, 'eyt': 2268, 'yta ...
# 8956 {"'ca": 19, 'cau': 1093, 'aus': 691, 'use': 7732, "'co": 21, 'cou': 1270, 'our': 5731, 'urs': 7720, 'rse': 6493, "'em": 30, "'m": 47, "'n": 50, "'qu": 56, 'quo': 6136, 'uot': 7668, 'ote': 5696, "'ti": 63, 'tis': 7138, '--n': 69, '-ny': 148, 'nya': 5218, '-an': 76, 'and': 520, 'nda': 4897, '-be': 83, 'bel': 869, 'ela': 1959, 'las': 4131, '-co': 94, 'com': 1263, 'omp': 5548, 'mpe': 4727, 'pen': 5905, 'eng': 2019, '-de': 97, 'del': 1466, 'lap': 4128, 'apa': 559, 'pan': 5859, '-ka': 132, 'kan': 3842, '-ku': 135, '-le': 137, 'len': 4199, 'ngg': 4970, 'gga': 2609, 'gan': 2549, 'ang': 523, '-ma': 141, 'mah': 4528, 'aha': 376, 'has': 2854, 'asi': 627, 'sis': 6765, 'isw': 3547, 'swa': 6938, '-se': 169, 'sep': 6700, 'epi': 2071, 'pit': 5961, '-ta': 175, 'tak': 7015, '-wa': 187, 'wan': 8028, 'wat': 8032, 'ati': 655, "a'd": 196, "'du": 26, "a'h": 198, "'ha": 39, 'had': 2839, 'aab': 216, 'abe': 240, 'ber': 875, 'erg': 2093, 'aac': 217, 'ach': 264, 'che': 1163, 'hen': 2898, 'aak': 223, 'ake': 442, 'ker': 3889, 'aal': 224, 'als': 482, 'lse': 4393, 'set': 6704, 'eth': 2148, 'aam': 225, 'amo': 504, 'mod': 4699, 'odt': 5363, 'aan': 226, 'anc': 519, 'nco': 4888, 'cor': 1267, 'aar': 229, 'ard': 593, 'rde': 6220, 'dem': 1467, 'ema': 1987, 'rdv': 6236, 'dva': 1672, 'var': 7856, 'ark': 600, 'aro': 604, 'ron': 6444, "on'": 5558, "n's": 4828, 'ons': 5578, 'nso': 5138, 'son': 6830, 'art': 609, 'rti': 6522, 'aas': 230, 'ase': 623, 'ab': 234, 'aba': 236, 'bab': 809, 'bac': 810, 'cha': 1159, 'ack': 266, 'aco': 270, 'acu': 276, 'cus': 1332, 'bad': 811, 'ada': 284, 'dak': 1407, 'aka': 438, 'adi': 292, 'dia': 1513, 'iah': 3172, 'dik': 1523, 'ika': 3352, 'bah': 815, 'bai': 816, 'aia': 398, 'ian': 3178, 'aik': 408, 'aim': 410, 'ima': 3398, 'man': 4534, 'ana': 517, 'air': 414, 'bal': 819, 'alk': 475, 'lki': 4280, 'kin': 3932, 'alo': 479, 'lon': 4357, 'one': 5564, 'los': 4362, 'ban': 821, 'ndo': 4911, 'don': 1583, 'oni': 5568, 'nin': 5010, 'ing': 3426, 'onm': 5572, 'nme': 5061, 'men': 4609, 'ent': 2032, 'nts': 5167, 'nga': 4964, 'ngn': 4977, 'gny': 2702, 'ant': 536, 'nto': 5164, 'bar': 824, 'ara': 590, 'ran': 6173, 'arc': 592, 'rca': 6198, 'are': 594, 'bas': 825, 'asc': 621, 'sca': 6665, 'cal': 1084, 'ash': 626, 'she': 6730, 'hed': 2888, 'bat': 826, 'ate': 651, 'ted': 7059, 'tem': 7068, 'eme': 1991, 'tes': 7074, 'tin': 7133, 'ato': 661, 'toa': 7179, 'oar': 5298, 'bau': 827, 'abb': 237, 'bba': 834, 'tie': 7124, 'iel': 3261, 'ell': 1970, 'llo': 4306, 'bbe': 835, 'ben': 871, 'enh': 2020, 'nha': 4991, 'hau': 2856, 'bet': 877, 'ett': 2159, 'bev': 879, 'evi': 2193, 'vil': 7912, 'ill': 3383, 'lle': 4297, 'bey': 882, "ey'": 2251, "y's": 8428, 'bbi': 836, 'bie': 901, 'bit': 916, 'itt': 3570, 'bbo': 838, 'bot': 970, 'ott': 5709, "tt'": 7241, "t's": 6984, 'bou': 971, 'oud': 5719, 'bbr': 839, 'bre': 983, 'rev': 6264, 'via': 7904, 'iat': 3183, 'tio': 7134, 'ion': 3461, 'bbs': 840, 'bby': 842, 'abc': 238, 'bco': 846, 'cot': 1269, 'tek': 7066, 'abd': 239, 'bda': 849, 'dal': 1408, 'all': 476, 'lla': 4293, 'lah': 4120, 'das': 1415, 'bde': 850, 'bdi': 851, 'dic': 1515, 'ica': 3209, 'cat': 1092, 'kas': 3846, 'bdn': 852, 'dno': 1566, 'nor': 5100, 'bdo': 853, 'dol': 1581, 'oll': 5519, 'dom': 1582, 'ome': 5538, 'omi': 5542, 'min': 4653, 'ina': 3420, 'nal': 4857, 'bdu': 855, 'duc': 1649, 'uct': 7417, 'cte': 1304, 'tee': 7060, 'ees': 1840, 'cti': 1307, 'cto': 1311, 'tor': 7195, 'ors': 5654, 'cts': 1313, 'dul': 1658, 'ula': 7577, 'laz': 4138, 'azi': 790, 'ziz': 8854, 'ull': 7587, 'lar': 4130, 'ele': 1963, 'les': 4204, 'eln': 1972, 'elo': 1973, 'low': 4366, 'els': 1977, 'lso': 4402, 'end': 2016, 'ndr': 4914, 'dro': 1609, 'rot': 6450, 'oth': 5699, 'era': 2087, 'ras': 6178, 'erc': 2089, 'rcr': 6209, 'cro': 1287, 'rom': 6443, 'omb': 5535, 'mbi': 4553, 'erd': 2090, 'dee': 1459, 'een': 1837, 'erl': 2098, 'rle': 6371, 'erm': 2099, 'rmi': 6393, 'err': 2104, 'rra': 6475, 'rat': 6179, 'ona': 5560, 'ert': 2106, 'tte': 7245, 'tti': 7249, 'eya': 2252, 'yan': 8458, 'nce': 4882, 'eyt': 2268, 'yta ...
# 8956 {"'ca": 19, 'cau': 1093, 'aus': 691, 'use': 7732, "'co": 21, 'cou': 1270, 'our': 5731, 'urs': 7720, 'rse': 6493, "'em": 30, "'m": 47, "'n": 50, "'qu": 56, 'quo': 6136, 'uot': 7668, 'ote': 5696, "'ti": 63, 'tis': 7138, '--n': 69, '-ny': 148, 'nya': 5218, '-an': 76, 'and': 520, 'nda': 4897, '-be': 83, 'bel': 869, 'ela': 1959, 'las': 4131, '-co': 94, 'com': 1263, 'omp': 5548, 'mpe': 4727, 'pen': 5905, 'eng': 2019, '-de': 97, 'del': 1466, 'lap': 4128, 'apa': 559, 'pan': 5859, '-ka': 132, 'kan': 3842, '-ku': 135, '-le': 137, 'len': 4199, 'ngg': 4970, 'gga': 2609, 'gan': 2549, 'ang': 523, '-ma': 141, 'mah': 4528, 'aha': 376, 'has': 2854, 'asi': 627, 'sis': 6765, 'isw': 3547, 'swa': 6938, '-se': 169, 'sep': 6700, 'epi': 2071, 'pit': 5961, '-ta': 175, 'tak': 7015, '-wa': 187, 'wan': 8028, 'wat': 8032, 'ati': 655, "a'd": 196, "'du": 26, "a'h": 198, "'ha": 39, 'had': 2839, 'aab': 216, 'abe': 240, 'ber': 875, 'erg': 2093, 'aac': 217, 'ach': 264, 'che': 1163, 'hen': 2898, 'aak': 223, 'ake': 442, 'ker': 3889, 'aal': 224, 'als': 482, 'lse': 4393, 'set': 6704, 'eth': 2148, 'aam': 225, 'amo': 504, 'mod': 4699, 'odt': 5363, 'aan': 226, 'anc': 519, 'nco': 4888, 'cor': 1267, 'aar': 229, 'ard': 593, 'rde': 6220, 'dem': 1467, 'ema': 1987, 'rdv': 6236, 'dva': 1672, 'var': 7856, 'ark': 600, 'aro': 604, 'ron': 6444, "on'": 5558, "n's": 4828, 'ons': 5578, 'nso': 5138, 'son': 6830, 'art': 609, 'rti': 6522, 'aas': 230, 'ase': 623, 'ab': 234, 'aba': 236, 'bab': 809, 'bac': 810, 'cha': 1159, 'ack': 266, 'aco': 270, 'acu': 276, 'cus': 1332, 'bad': 811, 'ada': 284, 'dak': 1407, 'aka': 438, 'adi': 292, 'dia': 1513, 'iah': 3172, 'dik': 1523, 'ika': 3352, 'bah': 815, 'bai': 816, 'aia': 398, 'ian': 3178, 'aik': 408, 'aim': 410, 'ima': 3398, 'man': 4534, 'ana': 517, 'air': 414, 'bal': 819, 'alk': 475, 'lki': 4280, 'kin': 3932, 'alo': 479, 'lon': 4357, 'one': 5564, 'los': 4362, 'ban': 821, 'ndo': 4911, 'don': 1583, 'oni': 5568, 'nin': 5010, 'ing': 3426, 'onm': 5572, 'nme': 5061, 'men': 4609, 'ent': 2032, 'nts': 5167, 'nga': 4964, 'ngn': 4977, 'gny': 2702, 'ant': 536, 'nto': 5164, 'bar': 824, 'ara': 590, 'ran': 6173, 'arc': 592, 'rca': 6198, 'are': 594, 'bas': 825, 'asc': 621, 'sca': 6665, 'cal': 1084, 'ash': 626, 'she': 6730, 'hed': 2888, 'bat': 826, 'ate': 651, 'ted': 7059, 'tem': 7068, 'eme': 1991, 'tes': 7074, 'tin': 7133, 'ato': 661, 'toa': 7179, 'oar': 5298, 'bau': 827, 'abb': 237, 'bba': 834, 'tie': 7124, 'iel': 3261, 'ell': 1970, 'llo': 4306, 'bbe': 835, 'ben': 871, 'enh': 2020, 'nha': 4991, 'hau': 2856, 'bet': 877, 'ett': 2159, 'bev': 879, 'evi': 2193, 'vil': 7912, 'ill': 3383, 'lle': 4297, 'bey': 882, "ey'": 2251, "y's": 8428, 'bbi': 836, 'bie': 901, 'bit': 916, 'itt': 3570, 'bbo': 838, 'bot': 970, 'ott': 5709, "tt'": 7241, "t's": 6984, 'bou': 971, 'oud': 5719, 'bbr': 839, 'bre': 983, 'rev': 6264, 'via': 7904, 'iat': 3183, 'tio': 7134, 'ion': 3461, 'bbs': 840, 'bby': 842, 'abc': 238, 'bco': 846, 'cot': 1269, 'tek': 7066, 'abd': 239, 'bda': 849, 'dal': 1408, 'all': 476, 'lla': 4293, 'lah': 4120, 'das': 1415, 'bde': 850, 'bdi': 851, 'dic': 1515, 'ica': 3209, 'cat': 1092, 'kas': 3846, 'bdn': 852, 'dno': 1566, 'nor': 5100, 'bdo': 853, 'dol': 1581, 'oll': 5519, 'dom': 1582, 'ome': 5538, 'omi': 5542, 'min': 4653, 'ina': 3420, 'nal': 4857, 'bdu': 855, 'duc': 1649, 'uct': 7417, 'cte': 1304, 'tee': 7060, 'ees': 1840, 'cti': 1307, 'cto': 1311, 'tor': 7195, 'ors': 5654, 'cts': 1313, 'dul': 1658, 'ula': 7577, 'laz': 4138, 'azi': 790, 'ziz': 8854, 'ull': 7587, 'lar': 4130, 'ele': 1963, 'les': 4204, 'eln': 1972, 'elo': 1973, 'low': 4366, 'els': 1977, 'lso': 4402, 'end': 2016, 'ndr': 4914, 'dro': 1609, 'rot': 6450, 'oth': 5699, 'era': 2087, 'ras': 6178, 'erc': 2089, 'rcr': 6209, 'cro': 1287, 'rom': 6443, 'omb': 5535, 'mbi': 4553, 'erd': 2090, 'dee': 1459, 'een': 1837, 'erl': 2098, 'rle': 6371, 'erm': 2099, 'rmi': 6393, 'err': 2104, 'rra': 6475, 'rat': 6179, 'ona': 5560, 'ert': 2106, 'tte': 7245, 'tti': 7249, 'eya': 2252, 'yan': 8458, 'nce': 4882, 'eyt': 2268, 'yta ...
# 33 {'K': 18, 'AX': 6, 'Z': 35, 'AO': 4, 'R': 27, 'S': 28, 'M': 20, 'N': 21, 'W': 33, 'T': 30, 'IY': 16, 'NY': 23, 'AA': 3, 'D': 10, 'B': 8, 'L': 19, 'CH': 9, 'P': 25, 'EH': 11, 'NG': 22, 'UW': 31, 'G': 14, 'HH': 15, 'Q': 26, 'V': 32, 'AY': 7, 'SH': 29, 'EY': 12, 'AW': 5, 'JH': 17, 'Y': 34, 'OY': 24, 'F': 13}
# 33 {'K': 18, 'AX': 6, 'Z': 35, 'AO': 4, 'R': 27, 'S': 28, 'M': 20, 'N': 21, 'W': 33, 'T': 30, 'IY': 16, 'NY': 23, 'AA': 3, 'D': 10, 'B': 8, 'L': 19, 'CH': 9, 'P': 25, 'EH': 11, 'NG': 22, 'UW': 31, 'G': 14, 'HH': 15, 'Q': 26, 'V': 32, 'AY': 7, 'SH': 29, 'EY': 12, 'AW': 5, 'JH': 17, 'Y': 34, 'OY': 24, 'F': 13}
# 33 {'K': 18, 'AX': 6, 'Z': 35, 'AO': 4, 'R': 27, 'S': 28, 'M': 20, 'N': 21, 'W': 33, 'T': 30, 'IY': 16, 'NY': 23, 'AA': 3, 'D': 10, 'B': 8, 'L': 19, 'CH': 9, 'P': 25, 'EH': 11, 'NG': 22, 'UW': 31, 'G': 14, 'HH': 15, 'Q': 26, 'V': 32, 'AY': 7, 'SH': 29, 'EY': 12, 'AW': 5, 'JH': 17, 'Y': 34, 'OY': 24, 'F': 13}

# %% [markdown]
# ## Model definitions

# %% [markdown]
# ### Encoder

# %%
class Encoder(nn.Module) :
  def __init__(self, input_size, emb_dim, hidden_size, n_layers=1) -> None :
    super(Encoder, self).__init__()
    self.input_size = input_size
    self.hidden_size = hidden_size
    self.n_layers = n_layers

    self.embedding = nn.Embedding(input_size, emb_dim)
    self.gru = nn.GRU(emb_dim, hidden_size, n_layers, batch_first=False)
    if USE_CUDA :
      self.embedding = self.embedding.cuda()
      self.gru = self.gru.cuda()

  def forward(self, token_inputs, hidden) :
    embedded = self.embedding(token_inputs) # [seq_len, batch_size, emb_dim]
    output, hidden = self.gru(embedded, hidden)
    return output, hidden # output: [seq_len, batch_size, hidden_size]

  def init_hidden(self, batch_size=1) :
    hidden = torch.zeros(self.n_layers, batch_size, self.hidden_size)
    # hidden shape: [n_layers, batch_size, hidden_size]
    if USE_CUDA :
      hidden = hidden.cuda()
    return hidden

# %% [markdown]
# ### Attention

# %%
class Attn(nn.Module) :
  def __init__(self, method, hidden_size) -> None :
    super(Attn, self).__init__()
    self.method = method
    self.hidden_size = hidden_size

    if self.method == "general" :
      self.attn = nn.Linear(self.hidden_size, hidden_size)
      if USE_CUDA :
        self.attn = self.attn.cuda()
    elif self.method == "concat" :
      self.attn = nn.Linear(self.hidden_size*2, hidden_size)
      self.v = nn.Parameter(torch.FloatTensor(hidden_size))
      if USE_CUDA :
        self.attn = self.attn.cuda()
        self.v = self.v.cuda()

  def forward(self, hidden, encoder_outputs) :
    # hidden shape: [1, batch_size, hidden_size]
    # encoder_outputs shape: [seq_len, batch_size, hidden_size]

    if self.method == "dot" :
      # Vectorized dot product for all positions in the sequence
      attn_energies = torch.sum(hidden * encoder_outputs, dim=2) # [seq_len, batch_size]
    elif self.method == "general" :
      energy = self.attn(encoder_outputs) # [seq_len, batch_size, hidden_size]
      attn_energies = torch.sum(hidden * energy, dim=2)
    elif self.method == "concat" :
      hidden_expanded = hidden.expand(encoder_outputs.size(0), -1, -1) # [seq_len, batch_size, hidden_size]
      energy = self.attn(torch.cat((hidden_expanded, encoder_outputs), 2)) # [seq_len, batch_size, hidden_size]
      attn_energies = torch.sum(self.v * energy, dim=2)

    # Normalize energies to weights
    attn_weights = F.softmax(attn_energies, dim=0) # [seq_len, batch_size]
    return attn_weights.transpose(0, 1).unsqueeze(1) # [batch_size, 1, seq_len]

# %% [markdown]
# ### Decoder

# %%
class Decoder(nn.Module) :
  def __init__(self, attn_model, emb_dim, hidden_size, output_size, n_layers=1, dropout_proba=.1) -> None :
    super(Decoder, self).__init__()
    self.attn_model = attn_model
    self.hidden_size = hidden_size
    self.output_size = output_size
    self.n_layers = n_layers
    self.dropout_proba = dropout_proba

    # Define layers
    self.embedding = nn.Embedding(output_size, emb_dim)
    self.gru = nn.GRU(emb_dim + hidden_size, hidden_size, n_layers, dropout=dropout_proba, batch_first=False)
    self.out = nn.Linear(hidden_size*2, output_size)

    # Choose attention model
    if attn_model != "none" :
      self.attn = Attn(attn_model, hidden_size)

    if USE_CUDA :
      self.embedding = self.embedding.cuda()
      self.gru = self.gru.cuda()
      self.out = self.out.cuda()
      self.attn = self.attn.cuda()

  def forward(self, token_input, last_context, last_hidden, encoder_outputs) :
    # token_input shape: [1, batch_size]
    # last_context shape: [batch_size, hidden_size]
    # last_hidden shape: [n_layers, batch_size, hidden_size]
    # encoder_outputs shape: [seq_len, batch_size, hidden]
    # Get the embedding of the current input token (last output token)

    embedded = self.embedding(token_input) # [1, batch_size, emb_dim]
    # Combine embedded input token and last context, run through RNN
    rnn_input = torch.cat((embedded, last_context.unsqueeze(0)), dim=2) # [1, batch_size, emb_dim + hidden_size]
    # GRU forward
    rnn_output, hidden = self.gru(rnn_input, last_hidden) # rnn_output: [1, batch_size, hidden_size]

    # Calculate attention from current RNN state and all encoder outputs; apply to encoder outputs
    attn_weights = self.attn(rnn_output, encoder_outputs) # [batch_size, 1, seq_len]
    context = torch.bmm(attn_weights, encoder_outputs.transpose(0, 1)) # [batch_size, 1, hidden_size]
    context = context.transpose(0, 1) # [1, batch_size, hidden_size]

    # Final output layer (next token prediction) using the RNN hidden state and context vector
    rnn_output = rnn_output.squeeze(0)  # [batch_size, hidden_size]
    context = context.squeeze(0)        # [batch_size, hidden_size]
    output = torch.cat((rnn_output, context), dim=1) # [batch_size, hidden_size * 2]
    output = F.log_softmax(self.out(output), dim=1) # [batch_size, output_size]

    # Return final output, hidden state, and attention weights (for visualization)
    return output, context, hidden, attn_weights

# %% [markdown]
# ## Technical check

# %%
# testing params
batch_size = 3
input_size = 100
emb_dim = 25
hidden_size = 15
n_layers = 1

# Init models
encoder_test = Encoder(input_size, emb_dim, hidden_size, n_layers)
decoder_test = Decoder("dot", emb_dim, hidden_size, output_size=input_size, n_layers=n_layers)
# Test encoder
encoder_hidden = encoder_test.init_hidden(batch_size=batch_size)
print("Encoder hidden shape:", encoder_hidden.shape)
# Test input (seq_len=4, batch_size=3)
input_batch = torch.LongTensor([[1,4,7], [2,5,8], [3,6,9], [4,7,10]])
if USE_CUDA :
  input_batch = input_batch.cuda()
print("Input batch shape:", input_batch.shape)

encoder_outputs, encoder_hidden = encoder_test(input_batch, encoder_hidden)
print("Encoder outputs shape:", encoder_outputs.shape)
print("Encoder hidden shape:", encoder_hidden.shape)

# Test decoder
decoder_input = torch.LongTensor([[SOS_TOKEN] * batch_size]) # (1, batch_size)
decoder_context = torch.zeros(batch_size, hidden_size) # (batch_size, hidden_size)
decoder_hidden = encoder_hidden
if USE_CUDA :
  decoder_input = decoder_input.cuda()
  decoder_context = decoder_context.cuda()
for di in range(2) :
  decoder_output, decoder_context, decoder_hidden, attn = decoder_test(
      decoder_input,
      decoder_context,
      decoder_hidden,
      encoder_outputs
  )
  print(f"Step {di}:")
  print("Decoder output shape:", decoder_output.shape) # [batch_size, output_size]
  print("Decoder context shape:", decoder_context.shape)
  print("Decoder hidden shape:", decoder_hidden.shape) # [n_layers, batch_size, hidden_size]
  print("Attention shape:", attn.shape) # [batch_size, 1, seq_len]
  decoder_input = torch.argmax(decoder_output, dim=1).unsqueeze(0) # Greedy decoding
# Out:
# /home/ahmadnaufalhakim/.local/lib/python3.8/site-packages/torch/nn/modules/rnn.py:83: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# Encoder hidden shape: torch.Size([1, 3, 15])
# Input batch shape: torch.Size([4, 3])
# Encoder outputs shape: torch.Size([4, 3, 15])
# Encoder hidden shape: torch.Size([1, 3, 15])
# Step 0:
# Decoder output shape: torch.Size([3, 100])
# Decoder context shape: torch.Size([3, 15])
# Decoder hidden shape: torch.Size([1, 3, 15])
# Attention shape: torch.Size([3, 1, 4])
# Step 1:
# Decoder output shape: torch.Size([3, 100])
# Decoder context shape: torch.Size([3, 15])
# Decoder hidden shape: torch.Size([1, 3, 15])
# Attention shape: torch.Size([3, 1, 4])

# %% [markdown]
# ## Helper functions (for training log)

# %%
import time
import math
import matplotlib.pyplot as plt
plt.switch_backend("agg")
import matplotlib.ticker as ticker
# %matplotlib inline
import numpy as np

def as_minutes(seconds) :
  minutes = math.floor(seconds/60)
  seconds -= minutes*60
  return f"{minutes}m {round(seconds, 2)}s"

def time_since(since, percent) :
  now = time.time()
  seconds = now - since
  eta_seconds = seconds/(percent)
  remaining_seconds = eta_seconds - seconds
  return f"{as_minutes(seconds)} (- {as_minutes(remaining_seconds)})"

# %% [markdown]
# ## Train and validation script

# %%
teacher_forcing_ratio = .5

def train_batch(input_batch, target_batch, langs, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion) :
  encoder_optimizer.zero_grad()
  decoder_optimizer.zero_grad()
  if USE_CUDA :
    input_batch = input_batch.cuda()
    target_batch = target_batch.cuda()

  batch_size = input_batch.size(1)
  # Forward through encoder
  encoder_hidden = encoder.init_hidden(batch_size)
  encoder_outputs, encoder_hidden = encoder(input_batch, encoder_hidden)
  # Prepare decoder inputs
  decoder_input = torch.LongTensor([[SOS_TOKEN] * batch_size])
  decoder_context = torch.zeros(batch_size, decoder.hidden_size)
  decoder_hidden = encoder_hidden # Use last hidden state from encoder to start decoder
  if USE_CUDA :
    decoder_input = decoder_input.cuda()
    decoder_context = decoder_context.cuda()

  loss = 0
  for di in range(target_batch.size(0)) :
    decoder_output, decoder_context, decoder_hidden, decoder_attention = decoder(
      decoder_input, decoder_context, decoder_hidden, encoder_outputs
    )
    # # Debug: check for nan
    # if torch.isnan(criterion(decoder_output, target_batch[di])).any() :
    #   print("nan detected in decoder_output at step", di)
    #   print(f"step {di}/{target_batch.size(0)-1}")
    #   print(f"{di-1}:\t{target_batch[di-1]}")
    #   for i in range(di, target_batch.size(0)) :
    #     print(f"{i}:\t{target_batch[i]}")
    #   print(target_batch)
    #   print(decoder_output.shape, target_batch[di].shape, criterion(decoder_output, target_batch[di]))
    # Calculate loss for this step (sum over batch)
    loss += criterion(decoder_output, target_batch[di])
    # Teacher forcing
    decoder_input = target_batch[di].unsqueeze(0) if random.random() < teacher_forcing_ratio else decoder_output.argmax(1).unsqueeze(0)
    if USE_CUDA :
      decoder_input = decoder_input.cuda()

  # Normalize loss
  loss /= target_batch.size(0)

  # Apply language weights
  weights = torch.tensor([EN_WEIGHT if lang=="en" else ID_WEIGHT for lang in langs])
  if USE_CUDA :
    weights = weights.cuda()
  weighted_loss = (loss * weights).mean()

  # Backpropagate weighted loss
  weighted_loss.backward()
  encoder_optimizer.step()
  decoder_optimizer.step()

  return loss.item(), weighted_loss.item()

def infer_batch(input_batch, target_batch, encoder, decoder, criterion) :
  if USE_CUDA :
    input_batch = input_batch.cuda()
    target_batch = target_batch.cuda()

  batch_size = input_batch.size(1)
  # Forward through encoder
  encoder_hidden = encoder.init_hidden(batch_size)
  encoder_outputs, encoder_hidden = encoder(input_batch, encoder_hidden)
  # Prepare decoder inputs
  decoder_input = torch.LongTensor([[SOS_TOKEN] * batch_size])
  decoder_context = torch.zeros(batch_size, decoder.hidden_size)
  decoder_hidden = encoder_hidden # Use last hidden state from encoder to start decoder
  if USE_CUDA :
    decoder_input = decoder_input.cuda()
    decoder_context = decoder_context.cuda()

  loss = 0
  for di in range(target_batch.size(0)) :
    decoder_output, decoder_context, decoder_hidden, decoder_attention = decoder(
      decoder_input, decoder_context, decoder_hidden, encoder_outputs
    )
    # Calculate loss for this step (sum over batch)
    loss += criterion(decoder_output, target_batch[di])
    # Greedy decoding without teacher forcing
    topi = decoder_output.argmax(1)
    decoder_input = topi.unsqueeze(0).detach() # detach from history

  # Normalize loss
  loss /= target_batch.size(0)

  return loss.item()

# %% [markdown]
# ## Initialize model

# %%
attn_model = ATTN_MODEL
emb_dim = EMB_DIM
hidden_size = HIDDEN_SIZE
n_layers = N_LAYERS
dropout_proba = DROPOUT_PROBA

# Initialize models
encoder = Encoder(train_g2p_dataset.n_graphemes, int(emb_dim), int(hidden_size), int(n_layers))
decoder = Decoder(attn_model, int(emb_dim), int(hidden_size), train_g2p_dataset.n_phonemes, int(n_layers), dropout_proba=dropout_proba)
n_encoder_parameters = sum(p.numel() for p in encoder.parameters() if p.requires_grad)
n_decoder_parameters = sum(p.numel() for p in decoder.parameters() if p.requires_grad)

print(f"attn_model: {attn_model}")
print(f"emb_dim: {emb_dim}")
print(f"hidden_size: {hidden_size}")
print(f"n_layers: {n_layers}")
print(f"Encoder has a total number of {n_encoder_parameters} parameters")
print(f"Decoder has a total number of {n_decoder_parameters} parameters")
print(f"Total number of all parameters is {n_encoder_parameters+n_decoder_parameters}")

# Move models to GPU
if USE_CUDA :
  encoder.cuda()
  decoder.cuda()

# Learning rate and weight decay parameters
learning_rate = .001
weight_decay = 1e-5
# Initialize optimizers and criterion
encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate, weight_decay=weight_decay)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate, weight_decay=weight_decay)
criterion = nn.NLLLoss(ignore_index=PAD_TOKEN)

# Early stopping parameters
patience = 999
epochs_without_improvement = 0
# Learning rate scheduling
encoder_scheduler = optim.lr_scheduler.ReduceLROnPlateau(encoder_optimizer, factor=.5)
decoder_scheduler = optim.lr_scheduler.ReduceLROnPlateau(decoder_optimizer, factor=.5)
# Out:
# /home/ahmadnaufalhakim/.local/lib/python3.8/site-packages/torch/nn/modules/rnn.py:83: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# attn_model: dot
# emb_dim: 512
# hidden_size: 64
# n_layers: 1
# Encoder has a total number of 4698496 parameters
# Decoder has a total number of 146340 parameters
# Total number of all parameters is 4844836

# %% [markdown]
# ## Run the training script

# %%
# Training configurations
n_epochs = 100
# Keep track of time elapsed and running averages
train_losses = []
val_losses = []
# Keep track of the best validation set loss
best_val_loss = float("inf")

start = time.time()
for epoch in range(1, n_epochs+1) :
  # Set both encoder and decoder to training mode
  encoder.train()
  decoder.train()
  print(f"Training for epoch {epoch} has started (lr={encoder_optimizer.param_groups[0]['lr']}). Found {len(train_dataloader)} batch(es).")
  # Training
  total_train_loss = 0
  total_train_tokens = 0
  for batch, (grps, phns, langs) in enumerate(train_dataloader) :
    # Count tokens (excluding padding)
    total_train_tokens += (phns!=PAD_TOKEN).sum().item()
    # Train and get WEIGHTED loss
    unweighted_train_loss, weighted_train_loss = train_batch(grps, phns, langs, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion)
    # Track UNWEIGHTED train loss for logging
    total_train_loss += unweighted_train_loss * (phns!=PAD_TOKEN).sum().item()

  # Set both encoder and decoder to evaluation mode
  encoder.eval()
  decoder.eval()
  # Validation
  with torch.no_grad() :
    total_val_loss = 0
    total_val_tokens = 0
    for grps, phns, langs in valid_dataloader :
      # Count tokens (excluding padding)
      total_val_tokens += (phns!=PAD_TOKEN).sum().item()
      # Infer and get loss
      val_loss = infer_batch(grps, phns, encoder, decoder, criterion)
      # Track val loss for logging
      total_val_loss += val_loss * (phns!=PAD_TOKEN).sum().item()

  # Calculate epoch metrics
  avg_train_loss = total_train_loss/total_train_tokens
  avg_val_loss = total_val_loss/total_val_tokens
  print(f"Epoch {epoch} finished in {time_since(start, epoch/n_epochs)} ({epoch} {epoch*100/n_epochs}%). train avg loss: {round(avg_train_loss, 4)}, val avg loss: {round(avg_val_loss, 4)}")

  # Update schedulers based on validation loss
  encoder_scheduler.step(avg_val_loss)
  decoder_scheduler.step(avg_val_loss)

  # Save the losses for visualization
  train_losses.append(avg_train_loss)
  val_losses.append(avg_val_loss)

  # Save the model if the validation loss is better than the previous iterations' validation loss
  if avg_val_loss < best_val_loss :
    epochs_without_improvement = 0
    if epoch > 1 :
      previous_best_encoder = [f for f in os.listdir(MODELS_DIR) if f.startswith(f"FIN-encoder-wdecay_1e_5-attn_{attn_model}-emb_{emb_dim}-hddn_{hidden_size}-layers_{n_layers}")][0]
      previous_best_decoder = [f for f in os.listdir(MODELS_DIR) if f.startswith(f"FIN-decoder-wdecay_1e_5-attn_{attn_model}-emb_{emb_dim}-hddn_{hidden_size}-layers_{n_layers}")][0]
      os.remove(os.path.join(MODELS_DIR, previous_best_encoder))
      os.remove(os.path.join(MODELS_DIR, previous_best_decoder))
    torch.save(encoder.state_dict(), os.path.join(MODELS_DIR, f"FIN-encoder-wdecay_1e_5-attn_{attn_model}-emb_{emb_dim}-hddn_{hidden_size}-layers_{n_layers}-epoch_{epoch}.pth"))
    torch.save(decoder.state_dict(), os.path.join(MODELS_DIR, f"FIN-decoder-wdecay_1e_5-attn_{attn_model}-emb_{emb_dim}-hddn_{hidden_size}-layers_{n_layers}-epoch_{epoch}.pth"))
    best_val_loss = avg_val_loss
  else :
    epochs_without_improvement += 1
    if epochs_without_improvement >= patience :
      print(f"Early stopping after {epoch} epochs")
      break
# Out:
# Training for epoch 1 has started (lr=0.001). Found 1922 batch(es).
# Epoch 1 finished in 0m 51.19s (- 84m 27.61s) (1 1.0%). train avg loss: 1.7717, val avg loss: 1.67
# Training for epoch 2 has started (lr=0.001). Found 1922 batch(es).
# Epoch 2 finished in 1m 43.38s (- 84m 25.63s) (2 2.0%). train avg loss: 0.9723, val avg loss: 1.2801
# Training for epoch 3 has started (lr=0.001). Found 1922 batch(es).
# Epoch 3 finished in 2m 34.18s (- 83m 5.26s) (3 3.0%). train avg loss: 0.7159, val avg loss: 1.1497
# Training for epoch 4 has started (lr=0.001). Found 1922 batch(es).
# Epoch 4 finished in 3m 27.27s (- 82m 54.43s) (4 4.0%). train avg loss: 0.5889, val avg loss: 1.0353
# Training for epoch 5 has started (lr=0.001). Found 1922 batch(es).
# Epoch 5 finished in 4m 23.89s (- 83m 33.9s) (5 5.0%). train avg loss: 0.5378, val avg loss: 0.9784
# Training for epoch 6 has started (lr=0.001). Found 1922 batch(es).
# Epoch 6 finished in 5m 15.29s (- 82m 19.54s) (6 6.0%). train avg loss: 0.4816, val avg loss: 1.0003
# Training for epoch 7 has started (lr=0.001). Found 1922 batch(es).
# Epoch 7 finished in 6m 8.19s (- 81m 31.67s) (7 7.0%). train avg loss: 0.472, val avg loss: 1.0008
# Training for epoch 8 has started (lr=0.001). Found 1922 batch(es).
# Epoch 8 finished in 6m 58.11s (- 80m 8.21s) (8 8.0%). train avg loss: 0.4248, val avg loss: 0.9333
# Training for epoch 9 has started (lr=0.001). Found 1922 batch(es).
# Epoch 9 finished in 7m 49.87s (- 79m 10.91s) (9 9.0%). train avg loss: 0.4128, val avg loss: 0.8613
# Training for epoch 10 has started (lr=0.001). Found 1922 batch(es).
# Epoch 10 finished in 8m 41.58s (- 78m 14.2s) (10 10.0%). train avg loss: 0.3931, val avg loss: 0.8084
# Training for epoch 11 has started (lr=0.001). Found 1922 batch(es).
# Epoch 11 finished in 9m 28.39s (- 76m 38.79s) (11 11.0%). train avg loss: 0.3677, val avg loss: 0.7879
# Training for epoch 12 has started (lr=0.001). Found 1922 batch(es).
# Epoch 12 finished in 10m 11.51s (- 74m 44.4s) (12 12.0%). train avg loss: 0.3591, val avg loss: 0.8089
# Training for epoch 13 has started (lr=0.001). Found 1922 batch(es).
# Epoch 13 finished in 10m 57.13s (- 73m 17.69s) (13 13.0%). train avg loss: 0.336, val avg loss: 0.7778
# Training for epoch 14 has started (lr=0.001). Found 1922 batch(es).
# Epoch 14 finished in 11m 41.83s (- 71m 51.25s) (14 14.0%). train avg loss: 0.3462, val avg loss: 0.7919
# Training for epoch 15 has started (lr=0.001). Found 1922 batch(es).
# Epoch 15 finished in 12m 26.44s (- 70m 29.81s) (15 15.0%). train avg loss: 0.3238, val avg loss: 0.7719
# Training for epoch 16 has started (lr=0.001). Found 1922 batch(es).
# Epoch 16 finished in 13m 13.03s (- 69m 23.39s) (16 16.0%). train avg loss: 0.3122, val avg loss: 0.7408
# Training for epoch 17 has started (lr=0.001). Found 1922 batch(es).
# Epoch 17 finished in 14m 0.63s (- 68m 24.27s) (17 17.0%). train avg loss: 0.3028, val avg loss: 0.8324
# Training for epoch 18 has started (lr=0.001). Found 1922 batch(es).
# Epoch 18 finished in 14m 51.93s (- 67m 43.24s) (18 18.0%). train avg loss: 0.2858, val avg loss: 0.7569
# Training for epoch 19 has started (lr=0.001). Found 1922 batch(es).
# Epoch 19 finished in 15m 45.99s (- 67m 12.91s) (19 19.0%). train avg loss: 0.273, val avg loss: 0.7115
# Training for epoch 20 has started (lr=0.001). Found 1922 batch(es).
# Epoch 20 finished in 16m 36.58s (- 66m 26.33s) (20 20.0%). train avg loss: 0.2837, val avg loss: 0.7313
# Training for epoch 21 has started (lr=0.001). Found 1922 batch(es).
# Epoch 21 finished in 17m 26.59s (- 65m 37.16s) (21 21.0%). train avg loss: 0.2873, val avg loss: 0.7037
# Training for epoch 22 has started (lr=0.001). Found 1922 batch(es).
# Epoch 22 finished in 18m 14.92s (- 64m 42.0s) (22 22.0%). train avg loss: 0.2593, val avg loss: 0.7288
# Training for epoch 23 has started (lr=0.001). Found 1922 batch(es).
# Epoch 23 finished in 19m 1.05s (- 63m 40.05s) (23 23.0%). train avg loss: 0.2644, val avg loss: 0.7278
# Training for epoch 24 has started (lr=0.001). Found 1922 batch(es).
# Epoch 24 finished in 19m 47.51s (- 62m 40.46s) (24 24.0%). train avg loss: 0.2679, val avg loss: 0.7554
# Training for epoch 25 has started (lr=0.001). Found 1922 batch(es).
# Epoch 25 finished in 20m 39.08s (- 61m 57.23s) (25 25.0%). train avg loss: 0.2443, val avg loss: 0.6951
# Training for epoch 26 has started (lr=0.001). Found 1922 batch(es).
# Epoch 26 finished in 21m 30.87s (- 61m 14.01s) (26 26.0%). train avg loss: 0.2445, val avg loss: 0.6775
# Training for epoch 27 has started (lr=0.001). Found 1922 batch(es).
# Epoch 27 finished in 22m 26.43s (- 60m 40.36s) (27 27.0%). train avg loss: 0.2439, val avg loss: 0.6378
# Training for epoch 28 has started (lr=0.001). Found 1922 batch(es).
# Epoch 28 finished in 23m 22.24s (- 60m 5.76s) (28 28.0%). train avg loss: 0.2449, val avg loss: 0.7146
# Training for epoch 29 has started (lr=0.001). Found 1922 batch(es).
# Epoch 29 finished in 24m 19.64s (- 59m 33.6s) (29 29.0%). train avg loss: 0.2297, val avg loss: 0.6836
# Training for epoch 30 has started (lr=0.001). Found 1922 batch(es).
# Epoch 30 finished in 25m 15.06s (- 58m 55.14s) (30 30.0%). train avg loss: 0.2291, val avg loss: 0.6747
# Training for epoch 31 has started (lr=0.001). Found 1922 batch(es).
# Epoch 31 finished in 26m 15.94s (- 58m 27.73s) (31 31.0%). train avg loss: 0.2335, val avg loss: 0.6597
# Training for epoch 32 has started (lr=0.001). Found 1922 batch(es).
# Epoch 32 finished in 27m 5.42s (- 57m 34.03s) (32 32.0%). train avg loss: 0.2166, val avg loss: 0.6386
# Training for epoch 33 has started (lr=0.001). Found 1922 batch(es).
# Epoch 33 finished in 27m 52.39s (- 56m 35.46s) (33 33.0%). train avg loss: 0.2254, val avg loss: 0.6489
# Training for epoch 34 has started (lr=0.001). Found 1922 batch(es).
# Epoch 34 finished in 28m 47.44s (- 55m 53.26s) (34 34.0%). train avg loss: 0.2272, val avg loss: 0.617
# Training for epoch 35 has started (lr=0.001). Found 1922 batch(es).
# Epoch 35 finished in 29m 40.33s (- 55m 6.32s) (35 35.0%). train avg loss: 0.2116, val avg loss: 0.6278
# Training for epoch 36 has started (lr=0.001). Found 1922 batch(es).
# Epoch 36 finished in 30m 29.53s (- 54m 12.5s) (36 36.0%). train avg loss: 0.2308, val avg loss: 0.6578
# Training for epoch 37 has started (lr=0.001). Found 1922 batch(es).
# Epoch 37 finished in 31m 17.52s (- 53m 16.87s) (37 37.0%). train avg loss: 0.1978, val avg loss: 0.6183
# Training for epoch 38 has started (lr=0.001). Found 1922 batch(es).
# Epoch 38 finished in 32m 5.22s (- 52m 21.15s) (38 38.0%). train avg loss: 0.1991, val avg loss: 0.78
# Training for epoch 39 has started (lr=0.001). Found 1922 batch(es).
# Epoch 39 finished in 32m 50.66s (- 51m 22.31s) (39 39.0%). train avg loss: 0.2169, val avg loss: 0.6316
# Training for epoch 40 has started (lr=0.001). Found 1922 batch(es).
# Epoch 40 finished in 33m 36.78s (- 50m 25.16s) (40 40.0%). train avg loss: 0.202, val avg loss: 0.8158
# Training for epoch 41 has started (lr=0.001). Found 1922 batch(es).
# Epoch 41 finished in 34m 22.6s (- 49m 28.13s) (41 41.0%). train avg loss: 0.2145, val avg loss: 0.6705
# Training for epoch 42 has started (lr=0.001). Found 1922 batch(es).
# Epoch 42 finished in 35m 8.21s (- 48m 31.34s) (42 42.0%). train avg loss: 0.1969, val avg loss: 0.5924
# Training for epoch 43 has started (lr=0.001). Found 1922 batch(es).
# Epoch 43 finished in 35m 54.15s (- 47m 35.5s) (43 43.0%). train avg loss: 0.1972, val avg loss: 0.6143
# Training for epoch 44 has started (lr=0.001). Found 1922 batch(es).
# Epoch 44 finished in 36m 45.02s (- 46m 46.39s) (44 44.0%). train avg loss: 0.197, val avg loss: 0.5963
# Training for epoch 45 has started (lr=0.001). Found 1922 batch(es).
# Epoch 45 finished in 37m 46.31s (- 46m 9.94s) (45 45.0%). train avg loss: 0.1921, val avg loss: 0.6094
# Training for epoch 46 has started (lr=0.001). Found 1922 batch(es).
# Epoch 46 finished in 38m 40.93s (- 45m 24.57s) (46 46.0%). train avg loss: 0.1991, val avg loss: 0.6217
# Training for epoch 47 has started (lr=0.001). Found 1922 batch(es).
# Epoch 47 finished in 39m 35.66s (- 44m 38.93s) (47 47.0%). train avg loss: 0.2232, val avg loss: 0.6127
# Training for epoch 48 has started (lr=0.001). Found 1922 batch(es).
# Epoch 48 finished in 40m 29.22s (- 43m 51.65s) (48 48.0%). train avg loss: 0.2001, val avg loss: 0.627
# Training for epoch 49 has started (lr=0.001). Found 1922 batch(es).
# Epoch 49 finished in 41m 25.64s (- 43m 7.1s) (49 49.0%). train avg loss: 0.1854, val avg loss: 0.664
# Training for epoch 50 has started (lr=0.001). Found 1922 batch(es).
# Epoch 50 finished in 42m 26.03s (- 42m 26.03s) (50 50.0%). train avg loss: 0.1969, val avg loss: 0.5808
# Training for epoch 51 has started (lr=0.001). Found 1922 batch(es).
# Epoch 51 finished in 43m 22.26s (- 41m 40.21s) (51 51.0%). train avg loss: 0.1861, val avg loss: 0.5924
# Training for epoch 52 has started (lr=0.001). Found 1922 batch(es).
# Epoch 52 finished in 44m 16.45s (- 40m 52.1s) (52 52.0%). train avg loss: 0.1827, val avg loss: 0.5827
# Training for epoch 53 has started (lr=0.001). Found 1922 batch(es).
# Epoch 53 finished in 45m 4.71s (- 39m 58.52s) (53 53.0%). train avg loss: 0.1798, val avg loss: 0.585
# Training for epoch 54 has started (lr=0.001). Found 1922 batch(es).
# Epoch 54 finished in 45m 50.82s (- 39m 3.29s) (54 54.0%). train avg loss: 0.1839, val avg loss: 0.597
# Training for epoch 55 has started (lr=0.001). Found 1922 batch(es).
# Epoch 55 finished in 46m 36.68s (- 38m 8.2s) (55 55.0%). train avg loss: 0.169, val avg loss: 0.5832
# Training for epoch 56 has started (lr=0.001). Found 1922 batch(es).
# Epoch 56 finished in 47m 29.67s (- 37m 19.02s) (56 56.0%). train avg loss: 0.1721, val avg loss: 0.5605
# Training for epoch 57 has started (lr=0.001). Found 1922 batch(es).
# Epoch 57 finished in 48m 15.48s (- 36m 24.31s) (57 57.0%). train avg loss: 0.1789, val avg loss: 0.5725
# Training for epoch 58 has started (lr=0.001). Found 1922 batch(es).
# Epoch 58 finished in 49m 3.76s (- 35m 31.69s) (58 58.0%). train avg loss: 0.18, val avg loss: 0.5913
# Training for epoch 59 has started (lr=0.001). Found 1922 batch(es).
# Epoch 59 finished in 49m 50.48s (- 34m 38.13s) (59 59.0%). train avg loss: 0.1828, val avg loss: 0.5454
# Training for epoch 60 has started (lr=0.001). Found 1922 batch(es).
# Epoch 60 finished in 50m 35.59s (- 33m 43.73s) (60 60.0%). train avg loss: 0.1615, val avg loss: 0.5671
# Training for epoch 61 has started (lr=0.001). Found 1922 batch(es).
# Epoch 61 finished in 51m 23.12s (- 32m 51.18s) (61 61.0%). train avg loss: 0.1784, val avg loss: 0.5995
# Training for epoch 62 has started (lr=0.001). Found 1922 batch(es).
# Epoch 62 finished in 52m 10.18s (- 31m 58.5s) (62 62.0%). train avg loss: 0.1679, val avg loss: 0.5835
# Training for epoch 63 has started (lr=0.001). Found 1922 batch(es).
# Epoch 63 finished in 52m 57.44s (- 31m 6.11s) (63 63.0%). train avg loss: 0.1631, val avg loss: 0.6208
# Training for epoch 64 has started (lr=0.001). Found 1922 batch(es).
# Epoch 64 finished in 53m 43.13s (- 30m 13.01s) (64 64.0%). train avg loss: 0.1625, val avg loss: 0.5859
# Training for epoch 65 has started (lr=0.001). Found 1922 batch(es).
# Epoch 65 finished in 54m 28.79s (- 29m 20.12s) (65 65.0%). train avg loss: 0.1573, val avg loss: 0.5793
# Training for epoch 66 has started (lr=0.001). Found 1922 batch(es).
# Epoch 66 finished in 55m 16.66s (- 28m 28.58s) (66 66.0%). train avg loss: 0.1788, val avg loss: 0.6011
# Training for epoch 67 has started (lr=0.001). Found 1922 batch(es).
# Epoch 67 finished in 56m 5.63s (- 27m 37.7s) (67 67.0%). train avg loss: 0.1533, val avg loss: 0.5983
# Training for epoch 68 has started (lr=0.001). Found 1922 batch(es).
# Epoch 68 finished in 56m 52.37s (- 26m 45.82s) (68 68.0%). train avg loss: 0.153, val avg loss: 0.5754
# Training for epoch 69 has started (lr=0.001). Found 1922 batch(es).
# Epoch 69 finished in 57m 47.51s (- 25m 57.87s) (69 69.0%). train avg loss: 0.1563, val avg loss: 0.5434
# Training for epoch 70 has started (lr=0.001). Found 1922 batch(es).
# Epoch 70 finished in 58m 43.11s (- 25m 9.91s) (70 70.0%). train avg loss: 0.1512, val avg loss: 0.5804
# Training for epoch 71 has started (lr=0.001). Found 1922 batch(es).
# Epoch 71 finished in 59m 38.13s (- 24m 21.49s) (71 71.0%). train avg loss: 0.1728, val avg loss: 0.6335
# Training for epoch 72 has started (lr=0.001). Found 1922 batch(es).
# Epoch 72 finished in 60m 31.17s (- 23m 32.12s) (72 72.0%). train avg loss: 0.1473, val avg loss: 0.5394
# Training for epoch 73 has started (lr=0.001). Found 1922 batch(es).
# Epoch 73 finished in 61m 21.7s (- 22m 41.72s) (73 73.0%). train avg loss: 0.1593, val avg loss: 0.5655
# Training for epoch 74 has started (lr=0.001). Found 1922 batch(es).
# Epoch 74 finished in 62m 12.29s (- 21m 51.35s) (74 74.0%). train avg loss: 0.1402, val avg loss: 0.586
# Training for epoch 75 has started (lr=0.001). Found 1922 batch(es).
# Epoch 75 finished in 62m 57.52s (- 20m 59.17s) (75 75.0%). train avg loss: 0.1551, val avg loss: 0.5627
# Training for epoch 76 has started (lr=0.001). Found 1922 batch(es).
# Epoch 76 finished in 63m 43.46s (- 20m 7.41s) (76 76.0%). train avg loss: 0.1467, val avg loss: 0.5636
# Training for epoch 77 has started (lr=0.001). Found 1922 batch(es).
# Epoch 77 finished in 64m 31.34s (- 19m 16.37s) (77 77.0%). train avg loss: 0.1442, val avg loss: 0.5411
# Training for epoch 78 has started (lr=0.001). Found 1922 batch(es).
# Epoch 78 finished in 65m 17.65s (- 18m 24.98s) (78 78.0%). train avg loss: 0.1512, val avg loss: 0.58
# Training for epoch 79 has started (lr=0.001). Found 1922 batch(es).
# Epoch 79 finished in 66m 2.71s (- 17m 33.38s) (79 79.0%). train avg loss: 0.156, val avg loss: 0.5924
# Training for epoch 80 has started (lr=0.001). Found 1922 batch(es).
# Epoch 80 finished in 66m 48.84s (- 16m 42.21s) (80 80.0%). train avg loss: 0.1462, val avg loss: 0.5396
# Training for epoch 81 has started (lr=0.001). Found 1922 batch(es).
# Epoch 81 finished in 67m 34.43s (- 15m 51.04s) (81 81.0%). train avg loss: 0.1398, val avg loss: 0.5834
# Training for epoch 82 has started (lr=0.001). Found 1922 batch(es).
# Epoch 82 finished in 68m 19.49s (- 14m 59.89s) (82 82.0%). train avg loss: 0.1611, val avg loss: 0.5801
# Training for epoch 83 has started (lr=0.001). Found 1922 batch(es).
# Epoch 83 finished in 69m 5.66s (- 14m 9.11s) (83 83.0%). train avg loss: 0.1383, val avg loss: 0.5494
# Training for epoch 84 has started (lr=0.0005). Found 1922 batch(es).
# Epoch 84 finished in 69m 52.32s (- 13m 18.54s) (84 84.0%). train avg loss: 0.1121, val avg loss: 0.5259
# Training for epoch 85 has started (lr=0.0005). Found 1922 batch(es).
# Epoch 85 finished in 70m 39.36s (- 12m 28.12s) (85 85.0%). train avg loss: 0.1062, val avg loss: 0.5336
# Training for epoch 86 has started (lr=0.0005). Found 1922 batch(es).
# Epoch 86 finished in 71m 28.16s (- 11m 38.07s) (86 86.0%). train avg loss: 0.1031, val avg loss: 0.5173
# Training for epoch 87 has started (lr=0.0005). Found 1922 batch(es).
# Epoch 87 finished in 72m 15.05s (- 10m 47.77s) (87 87.0%). train avg loss: 0.1025, val avg loss: 0.5303
# Training for epoch 88 has started (lr=0.0005). Found 1922 batch(es).
# Epoch 88 finished in 73m 0.75s (- 9m 57.38s) (88 88.0%). train avg loss: 0.1013, val avg loss: 0.5482
# Training for epoch 89 has started (lr=0.0005). Found 1922 batch(es).
# Epoch 89 finished in 73m 47.31s (- 9m 7.2s) (89 89.0%). train avg loss: 0.0985, val avg loss: 0.5185
# Training for epoch 90 has started (lr=0.0005). Found 1922 batch(es).
# Epoch 90 finished in 74m 32.97s (- 8m 17.0s) (90 90.0%). train avg loss: 0.0941, val avg loss: 0.5369
# Training for epoch 91 has started (lr=0.0005). Found 1922 batch(es).
# Epoch 91 finished in 75m 17.43s (- 7m 26.78s) (91 91.0%). train avg loss: 0.0947, val avg loss: 0.5456
# Training for epoch 92 has started (lr=0.0005). Found 1922 batch(es).
# Epoch 92 finished in 76m 3.46s (- 6m 36.82s) (92 92.0%). train avg loss: 0.0896, val avg loss: 0.56
# Training for epoch 93 has started (lr=0.0005). Found 1922 batch(es).
# Epoch 93 finished in 76m 49.69s (- 5m 46.97s) (93 93.0%). train avg loss: 0.0892, val avg loss: 0.5597
# Training for epoch 94 has started (lr=0.0005). Found 1922 batch(es).
# Epoch 94 finished in 77m 38.07s (- 4m 57.32s) (94 94.0%). train avg loss: 0.0939, val avg loss: 0.5423
# Training for epoch 95 has started (lr=0.0005). Found 1922 batch(es).
# Epoch 95 finished in 78m 25.28s (- 4m 7.65s) (95 95.0%). train avg loss: 0.0921, val avg loss: 0.5242
# Training for epoch 96 has started (lr=0.0005). Found 1922 batch(es).
# Epoch 96 finished in 79m 11.82s (- 3m 17.99s) (96 96.0%). train avg loss: 0.092, val avg loss: 0.5494
# Training for epoch 97 has started (lr=0.0005). Found 1922 batch(es).
# Epoch 97 finished in 79m 58.94s (- 2m 28.42s) (97 97.0%). train avg loss: 0.0917, val avg loss: 0.5674
# Training for epoch 98 has started (lr=0.00025). Found 1922 batch(es).
# Epoch 98 finished in 80m 45.7s (- 1m 38.89s) (98 98.0%). train avg loss: 0.0781, val avg loss: 0.5246
# Training for epoch 99 has started (lr=0.00025). Found 1922 batch(es).
# Epoch 99 finished in 81m 31.55s (- 0m 49.41s) (99 99.0%). train avg loss: 0.0733, val avg loss: 0.545
# Training for epoch 100 has started (lr=0.00025). Found 1922 batch(es).
# Epoch 100 finished in 82m 16.95s (- 0m 0.0s) (100 100.0%). train avg loss: 0.0725, val avg loss: 0.5392

# %% [markdown]
# ## Visualize training loss

# %%
def show_plot(**kwargs) :
  plt.figure()
  fig, ax = plt.subplots()
  # This locator puts ticks at regular intervals
  loc = ticker.MultipleLocator(base=.2)
  ax.yaxis.set_major_locator(loc)
  plt.title("Loss")
  legends = []
  for k, v in kwargs.items() :
    plt.plot(v)
    plt.xlabel("Epoch")
    legends.append(k)
    if k == "val" :
      # Find the minimum value and its index
      min_value = min(v)
      min_index = v.index(min_value)
      # Plot a red dot at the minimum value
      plt.plot(min_index, min_value, "ro")
      # Add text box in the middle of the plot showing the minimum value
      plt.text(min_index-5, min_value-.125, f"{min_value:.4f}", bbox=dict(facecolor="white", alpha=.5))
  plt.legend(legends)

show_plot(train=train_losses, val=val_losses)

# %% [markdown]
# ## Evaluate the model

# %% [markdown]
# ### Helper functions to evaluate encoder-decoder attention model performance

# %%
def evaluate(word, max_length=MAX_LENGTH) :
  # Convert word to tensor with batch dimension
  input_variable = variable_from_word(test_g2p_dataset, word, grp_type=GRP_TYPE) # Already in [seq_len, 1]

  # Run through encoder
  encoder_hidden = encoder.init_hidden(batch_size=1)
  encoder_outputs, encoder_hidden = encoder(input_variable, encoder_hidden)
  # Prepare decoder inputs
  decoder_input = torch.LongTensor([[SOS_TOKEN]]) # [1, 1]
  decoder_context = torch.zeros(1, decoder.hidden_size)
  decoder_hidden = encoder_hidden # Use last hidden state from encoder to start decoder
  if USE_CUDA :
    decoder_input = decoder_input.cuda()
    decoder_context = decoder_context.cuda()

  decoded_phonemes = []
  attentions = torch.zeros(max_length, max_length)
  for di in range(max_length) :
    decoder_output, decoder_context, decoder_hidden, attn_weights = decoder(
      decoder_input, decoder_context, decoder_hidden, encoder_outputs
    )
    # Store attention
    attentions[di, :attn_weights.size(2)] += attn_weights.squeeze(0).squeeze(0).cpu().data
    # Get most likely token
    topv, topi = decoder_output.data.topk(1)
    ni = topi[0][0]
    if ni.item() == EOS_TOKEN :
      decoded_phonemes.append("<EOS>")
      break
    else :
      decoded_phonemes.append(test_g2p_dataset.index2phoneme[ni.item()])
    # Next input is predicted token
    decoder_input = torch.LongTensor([[ni.item()]])
    if USE_CUDA :
      decoder_input = decoder_input.cuda()

  return decoded_phonemes, attentions[:di+1, 1:len(encoder_outputs)]

def evaluate_randomly() :
  pair = random.choice(pairs)
  word, arpabet_phoneme_sequence, lang = pair

  output_phonemes, decoder_attns = evaluate(word)
  try :
    output_phonemes.remove("<EOS>")
  except ValueError as e :
    pass
  output_phoneme_sequence = ' '.join(output_phonemes)
  label_phonemes = arpabet_phoneme_sequence.split()

  print('>', word)
  print('=', label_phonemes)
  print('<', output_phoneme_sequence, output_phonemes)
  print('')
  return pair, output_phonemes, decoder_attns

# %% [markdown]
# ### Using `val` set (optional)

# %%
# Total Phone Error Rate (PER)
total_per = .0
for pair in val_pairs :
  word, arpabet_phoneme_sequence, lang = pair
  output_phonemes, decoder_attns = evaluate(word)
  try :
    output_phonemes.remove("<EOS>")
  except ValueError as e :
    pass
  total_per += wer(
    arpabet_phoneme_sequence,
    ' '.join(output_phonemes)
  )
average_per = total_per / len(val_pairs)
print(f"Phone error rate (PER) on val set: {average_per*100}%")
# Out:
# Phone error rate (PER) on val set: 11.900243717117826%

# %% [markdown]
# ### Using randomly chosen words

# %%
pair, output_phonemes, decoder_attns = evaluate_randomly()
plt.matshow(decoder_attns.numpy())
# Out:
# > alliedsignal
# = ['EH', 'L', 'AY', 'D', 'S', 'IY', 'Q', 'N', 'AX', 'L']
# < EH L IY D S IY Q N AX L ['EH', 'L', 'IY', 'D', 'S', 'IY', 'Q', 'N', 'AX', 'L']
